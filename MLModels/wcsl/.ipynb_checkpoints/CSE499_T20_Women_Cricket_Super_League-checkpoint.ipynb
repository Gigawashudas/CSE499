# %% [markdown]
# # Import Library

# %%
import warnings
warnings.filterwarnings("ignore")

import math
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm
import pickle
import csv

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display_html

# %% [markdown]
# # Data Exploration

# %%
filenames = []
for file in os.listdir('F:/AI ML DL Projects/CSE499 ML Project/ml project data/wcsl/data/'):
    filenames.append(os.path.join('F:/AI ML DL Projects/CSE499 ML Project/ml project data/wcsl/data/', file))

# %%
filenames[0:5]
# Out:
# ['F:/AI ML DL Projects/CSE499 ML Project/ml project data/wcsl/data/1035535.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/wcsl/data/1035537.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/wcsl/data/1093476.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/wcsl/data/1093477.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/wcsl/data/1093478.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
# 100%|██████████| 95/95 [00:22<00:00,  4.17it/s]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Loughborough Lightn...               0.92
# 0   [{'1st innings': {'team': 'Western Storm', 'de...               0.92
# 0   [{'1st innings': {'team': 'Western Storm', 'de...               0.92
# 0   [{'1st innings': {'team': 'Yorkshire Diamonds'...               0.92
# 0   [{'1st innings': {'team': 'Loughborough Lightn...               0.92
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Lancashire Thunder'...               0.92
# 0   [{'1st innings': {'team': 'Loughborough Lightn...               0.92
# 0   [{'1st innings': {'team': 'Southern Vipers', '...               0.92
# 0   [{'1st innings': {'team': 'Southern Vipers', '...               0.92
# 0   [{'1st innings': {'team': 'Yorkshire Diamonds'...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
# 0    2022-03-18              2                    6    Chelmsford
# 0    2022-03-18              2                    6    Chelmsford
# 0    2022-03-18              1                    6   Southampton
# 0    2022-03-18              1                    6         Leeds
# 0    2022-03-18              1                    6       Taunton
# ..          ...            ...                  ...           ...
# 0    2022-03-18              2                    6     Guildford
# 0    2022-03-18              2                    6  Loughborough
# 0    2022-03-18              2                    6       Taunton
# 0    2022-03-18              2                    6   Southampton
# 0    2022-03-18              2                    6         Leeds
#
#                 info.competition    info.dates info.gender info.match_type  \
# 0   Women's Cricket Super League  [2016-08-21]      female             T20
# 0   Women's Cricket Super League  [2016-08-21]      female             T20
# 0   Women's Cricket Super League  [2017-08-10]      female             T20
# 0   Women's Cricket Super League  [2017-08-11]      female             T20
# 0   Women's Cricket Super League  [2017-08-12]      female             T20
# ..                           ...           ...         ...             ...
# 0   Women's Cricket Super League  [2016-08-09]      female             T20
# 0   Women's Cricket Super League  [2016-08-12]      female             T20
# 0   Women's Cricket Super League  [2016-08-12]      female             T20
# 0   Women's Cricket Super League  [2016-08-14]      female             T20
# 0   Women's Cricket Super League  [2016-08-14]      female             T20
#
#     ... info.registry.people.GK Davis  info.registry.people.AJ Blackwell  \
# 0   ...                           NaN                                NaN
# 0   ...                           NaN                                NaN
# 0   ...                           NaN                                NaN
# 0   ...                           NaN                                NaN
# 0   ...                           NaN                                NaN
# ..  ...                           ...                                ...
# 0   ...                           NaN                                NaN
# 0   ...                           NaN                                NaN
# 0   ...                           NaN                                NaN
# 0   ...                           NaN                                NaN
# 0   ...                           NaN                           b9164a9b
#
#     info.registry.people.S Ismail info.registry.people.BL Morgan  \
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# ..                            ...                            ...
# 0                             NaN                       648bc30f
# 0                             NaN                       648bc30f
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                        108c4c09                            NaN
#
#    info.registry.people.DJS Dottin info.registry.people.L Marshall  \
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# ..                             ...                             ...
# 0                         53bee17f                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
#
#    info.registry.people.L Spragg info.registry.people.S Butler  \
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# ..                           ...                           ...
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                      7156272d
#
#    info.registry.people.IV Collis info.registry.people.LK Newton
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# ..                            ...                            ...
# 0                             NaN                       01fcf20f
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
#
# [95 rows x 190 columns]

# %% [markdown]
# # data store

# %%
#data store as pickle file
pickle.dump(final_df, open('cse499_wcsl_female.pkl','wb'))

# %% [markdown]
# # data load

# %%
final_df = pickle.load(open('cse499_wcsl_female.pkl','rb'))
final_df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Loughborough Lightn...               0.92
# 0  [{'1st innings': {'team': 'Western Storm', 'de...               0.92
# 0  [{'1st innings': {'team': 'Western Storm', 'de...               0.92
# 0  [{'1st innings': {'team': 'Yorkshire Diamonds'...               0.92
# 0  [{'1st innings': {'team': 'Loughborough Lightn...               0.92
#
#   meta.created  meta.revision  info.balls_per_over    info.city  \
# 0   2022-03-18              2                    6   Chelmsford
# 0   2022-03-18              2                    6   Chelmsford
# 0   2022-03-18              1                    6  Southampton
# 0   2022-03-18              1                    6        Leeds
# 0   2022-03-18              1                    6      Taunton
#
#                info.competition    info.dates info.gender info.match_type  \
# 0  Women's Cricket Super League  [2016-08-21]      female             T20
# 0  Women's Cricket Super League  [2016-08-21]      female             T20
# 0  Women's Cricket Super League  [2017-08-10]      female             T20
# 0  Women's Cricket Super League  [2017-08-11]      female             T20
# 0  Women's Cricket Super League  [2017-08-12]      female             T20
#
#    ... info.registry.people.GK Davis  info.registry.people.AJ Blackwell  \
# 0  ...                           NaN                                NaN
# 0  ...                           NaN                                NaN
# 0  ...                           NaN                                NaN
# 0  ...                           NaN                                NaN
# 0  ...                           NaN                                NaN
#
#    info.registry.people.S Ismail info.registry.people.BL Morgan  \
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
#
#   info.registry.people.DJS Dottin info.registry.people.L Marshall  \
# 0                             NaN                             NaN
# 0                             NaN                             NaN
# 0                             NaN                             NaN
# 0                             NaN                             NaN
# 0                             NaN                             NaN
#
#   info.registry.people.L Spragg info.registry.people.S Butler  \
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
#
#   info.registry.people.IV Collis info.registry.people.LK Newton
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
#
# [5 rows x 190 columns]

# %% [markdown]
# # Data Pre-Processing and Analysis

# %%
final_df = final_df[[
    'match_id',
    'innings',
    'info.dates',
    'info.gender',
    'info.match_type',
    'info.teams',
    'info.toss.winner',
    'info.toss.decision',
    'info.outcome.winner',
    'info.outcome.by.runs',
    'info.outcome.by.wickets',
    'info.overs',
    'info.umpires',
    'info.venue',
    'info.city'
]]

final_df.head()
# Out:
#    match_id                                            innings    info.dates  \
# 0         1  [{'1st innings': {'team': 'Loughborough Lightn...  [2016-08-21]
# 0         2  [{'1st innings': {'team': 'Western Storm', 'de...  [2016-08-21]
# 0         3  [{'1st innings': {'team': 'Western Storm', 'de...  [2017-08-10]
# 0         4  [{'1st innings': {'team': 'Yorkshire Diamonds'...  [2017-08-11]
# 0         5  [{'1st innings': {'team': 'Loughborough Lightn...  [2017-08-12]
#
#   info.gender info.match_type                                info.teams  \
# 0      female             T20   [Loughborough Lightning, Western Storm]
# 0      female             T20          [Western Storm, Southern Vipers]
# 0      female             T20          [Western Storm, Southern Vipers]
# 0      female             T20  [Yorkshire Diamonds, Lancashire Thunder]
# 0      female             T20   [Loughborough Lightning, Western Storm]
#
#      info.toss.winner info.toss.decision info.outcome.winner  \
# 0       Western Storm              field       Western Storm
# 0     Southern Vipers              field     Southern Vipers
# 0     Southern Vipers              field     Southern Vipers
# 0  Lancashire Thunder              field  Yorkshire Diamonds
# 0       Western Storm              field       Western Storm
#
#    info.outcome.by.runs  info.outcome.by.wickets  info.overs  \
# 0                   NaN                      5.0          20
# 0                   NaN                      7.0          20
# 0                   NaN                      9.0          20
# 0                  28.0                      NaN          20
# 0                   NaN                      5.0          20
#
#                     info.umpires  \
# 0     [BJ Debenham, Tom Lungley]
# 0       [Chris Watts, RJ Warren]
# 0  [DJ Millns, SJ O'Shaughnessy]
# 0          [M Burns, NL Bainton]
# 0       [ID Blackwell, NGB Cook]
#
#                                      info.venue    info.city
# 0                     County Ground, Chelmsford   Chelmsford
# 0                     County Ground, Chelmsford   Chelmsford
# 0                    The Rose Bowl, Southampton  Southampton
# 0                             Headingley, Leeds        Leeds
# 0  The Cooper Associates County Ground, Taunton      Taunton

# %%
final_df['info.gender'].value_counts()
# Out:
# female    95
# Name: info.gender, dtype: int64

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    95
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    95
# Name: info.overs, dtype: int64

# %%
# Remove 50 over match data
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df.shape
# Out:
# (95, 13)

# %% [markdown]
# # extract first & second innings data

# %%
# No Result Matches
final_df[final_df['info.outcome.winner'].isnull()]
# Out:
#    match_id                                            innings    info.dates  \
# 0        41  [{'1st innings': {'team': 'Southern Vipers', '...  [2018-08-11]
# 0        62  [{'1st innings': {'team': 'Lancashire Thunder'...  [2019-08-15]
#
#   info.gender                             info.teams    info.toss.winner  \
# 0      female       [Southern Vipers, Western Storm]       Western Storm
# 0      female  [Lancashire Thunder, Southern Vipers]  Lancashire Thunder
#
#   info.toss.decision info.outcome.winner  info.outcome.by.runs  \
# 0              field                 NaN                   NaN
# 0                bat                 NaN                   NaN
#
#    info.outcome.by.wickets               info.umpires              info.venue  \
# 0                      NaN   [Chris Watts, Rob White]  County Ground, Bristol
# 0                      NaN  [Mark Newell, MV Waldron]     County Ground, Hove
#
#   info.city
# 0   Bristol
# 0  Brighton

# %% [markdown]
# # remove no result matches

# %%
final_df = final_df.dropna(subset=['info.outcome.winner'])
final_df.shape
# Out:
# (93, 13)

# %%
final_df.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'non_striker': 'D van Niekerk',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'legbyes': 1},
#    'batsman': 'GA Elwiss'}},
#  {0.2: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {0.3: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {0.4: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {0.5: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {0.6: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {1.1: {'non_striker': 'D van Niekerk',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GA Elwiss'}},
#  {1.2: {'non_striker': 'D van Niekerk',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GA Elwiss'}},
#  {1.3: {'non_striker': 'GA Elwiss',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {1.4: {'non_striker': 'GA Elwiss',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {1.5: {'non_striker': 'GA Elwiss',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {1.6: {'non_striker': 'GA Elwiss',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {2.1: {'non_striker': 'D van Niekerk',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GA Elwiss'}},
#  {2.2: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'D van Niekerk'}},
#  {2.3: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'D van Niekerk'}},
#  {2.4: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {2.5: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'D van Niekerk'}},
#  {2.6: {'non_striker': 'GA Elwiss',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'D van Niekerk'}},
#  {3.1: {'non_striker': 'GA Elwiss',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'D van Niekerk'}},
#  {3.2: {'non_striker': 'D van Niekerk',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GA Elwiss'}},
#  {3.3: {'non_striker': 'D van Niekerk',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GA Elwiss'}},
#  {3.4: {'non_striker': 'D van Niekerk',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GA Elwiss'}},
#  {3.5: {'non_striker': 'D van Niekerk',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GA Elwiss'}},
#  {3.6: {'non_striker': 'D van Niekerk',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'GA Elwiss'}},
#  {4.1: {'non_striker': 'GA Elwiss',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {4.2: {'non_striker': 'GA Elwiss',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk'}},
#  {4.3: {'non_striker': 'GA Elwiss',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D van Niekerk',
#    'wicket': {'player_out': 'D van Niekerk', 'kind': 'bowled'}}},
#  {4.4: {'non_striker': 'GA Elwiss',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {4.5: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GA Elwiss',
#    'wicket': {'player_out': 'GA Elwiss', 'kind': 'lbw'}}},
#  {4.6: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'EA Perry'}},
#  {5.1: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {5.2: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {5.3: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {5.4: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 3, 'batsman': 3},
#    'batsman': 'SFM Devine'}},
#  {5.5: {'non_striker': 'SFM Devine',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {5.6: {'non_striker': 'SFM Devine',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {6.1: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {6.2: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {6.3: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {6.4: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {6.5: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {6.6: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {7.1: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {7.2: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {7.3: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {7.4: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {7.5: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {7.6: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'EA Perry'}},
#  {8.1: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {8.2: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {8.3: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {8.4: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {8.5: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {8.6: {'non_striker': 'SFM Devine',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'EA Perry'}},
#  {9.1: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {9.2: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {9.3: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {9.4: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {9.5: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'SFM Devine'}},
#  {9.6: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {10.1: {'non_striker': 'EA Perry',
#    'bowler': 'GM Hennessy',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'SFM Devine'}},
#  {10.2: {'non_striker': 'EA Perry',
#    'bowler': 'GM Hennessy',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {10.3: {'non_striker': 'SFM Devine',
#    'bowler': 'GM Hennessy',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {10.4: {'non_striker': 'SFM Devine',
#    'bowler': 'GM Hennessy',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'EA Perry'}},
#  {10.5: {'non_striker': 'SFM Devine',
#    'bowler': 'GM Hennessy',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {10.6: {'non_striker': 'SFM Devine',
#    'bowler': 'GM Hennessy',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {11.1: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'legbyes': 1},
#    'batsman': 'EA Perry'}},
#  {11.2: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {11.3: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {11.4: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {11.5: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {11.6: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {12.1: {'non_striker': 'SFM Devine',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {12.2: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {12.3: {'non_striker': 'SFM Devine',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'EA Perry'}},
#  {12.4: {'non_striker': 'SFM Devine',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {12.5: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {12.6: {'non_striker': 'SFM Devine',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {13.1: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {13.2: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {13.3: {'non_striker': 'EA Perry',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {13.4: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'EA Perry'}},
#  {13.5: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {13.6: {'non_striker': 'SFM Devine',
#    'bowler': 'JM Dibble',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {14.1: {'non_striker': 'SFM Devine',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'legbyes': 1},
#    'batsman': 'EA Perry'}},
#  {14.2: {'non_striker': 'EA Perry',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {14.3: {'non_striker': 'EA Perry',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {14.4: {'non_striker': 'EA Perry',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {14.5: {'non_striker': 'SFM Devine',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {14.6: {'non_striker': 'EA Perry',
#    'bowler': 'FR Davies',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SFM Devine'}},
#  {15.1: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine'}},
#  {15.2: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SFM Devine',
#    'wicket': {'player_out': 'SFM Devine',
#     'fielders': ['FR Davies'],
#     'kind': 'caught'}}},
#  {15.3: {'non_striker': 'AE Jones',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {15.4: {'non_striker': 'AE Jones',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {15.5: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'AE Jones'}},
#  {15.6: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'AE Jones'}},
#  {16.1: {'non_striker': 'EA Perry',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'AE Jones'}},
#  {16.2: {'non_striker': 'EA Perry',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'AE Jones'}},
#  {16.3: {'non_striker': 'AE Jones',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {16.4: {'non_striker': 'AE Jones',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {16.5: {'non_striker': 'EA Perry',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'AE Jones'}},
#  {16.6: {'non_striker': 'AE Jones',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {17.1: {'non_striker': 'AE Jones',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry',
#    'wicket': {'player_out': 'AE Jones',
#     'fielders': ['SN Luff'],
#     'kind': 'run out'}}},
#  {17.2: {'non_striker': 'E Jones',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'EA Perry'}},
#  {17.3: {'non_striker': 'E Jones',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'EA Perry',
#    'wicket': {'player_out': 'E Jones',
#     'fielders': ['SN Luff'],
#     'kind': 'run out'}}},
#  {17.4: {'non_striker': 'EA Perry',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'PJ Scholfield'}},
#  {17.5: {'non_striker': 'PJ Scholfield',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'EA Perry'}},
#  {17.6: {'non_striker': 'PJ Scholfield',
#    'bowler': 'HC Knight',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'EA Perry'}},
#  {18.1: {'non_striker': 'EA Perry',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'PJ Scholfield'}},
#  {18.2: {'non_striker': 'EA Perry',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'PJ Scholfield'}},
#  {18.3: {'non_striker': 'PJ Scholfield',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'EA Perry'}},
#  {18.4: {'non_striker': 'EA Perry',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'PJ Scholfield',
#    'wicket': {'player_out': 'PJ Scholfield',
#     'fielders': ['RH Priest'],
#     'kind': 'stumped'}}},
#  {18.5: {'non_striker': 'EA Perry',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'TF Brookes'}},
#  {18.6: {'non_striker': 'TF Brookes',
#    'bowler': 'A Shrubsole',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'EA Perry'}},
#  {19.1: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'TF Brookes'}},
#  {19.2: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'TF Brookes'}},
#  {19.3: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'TF Brookes'}},
#  {19.4: {'non_striker': 'EA Perry',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'TF Brookes',
#    'wicket': {'player_out': 'TF Brookes',
#     'fielders': ["C O'Keefe"],
#     'kind': 'caught'}}},
#  {19.5: {'non_striker': 'SB Odedra',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'EA Perry'}},
#  {19.6: {'non_striker': 'SB Odedra',
#    'bowler': 'SR Taylor',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'EA Perry'}}]

# %%
count = 0
delivery_df_1st_innings = pd.DataFrame()
for index, row in final_df.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    winner = []
    win_by_runs = []
    win_by_wickets = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            winner.append(row['info.outcome.winner'])
            win_by_runs.append(row['info.outcome.by.runs'])
            win_by_wickets.append(row['info.outcome.by.wickets'])
            ball_of_match.append(key)
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'winner':winner,
            'win_by_runs':win_by_runs,
            'win_by_wickets':win_by_wickets,
            'ball':ball_of_match,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df_1st_innings = delivery_df_1st_innings.append(loop_df)

# %%
delivery_df_1st_innings.head()
# Out:
#    match_id                                    teams            batting_team  \
# 0         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
# 1         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
# 2         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
# 3         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
# 4         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
#
#           winner  win_by_runs  win_by_wickets  ball  runs player_dismissed  \
# 0  Western Storm          NaN             5.0   0.1     1                0
# 1  Western Storm          NaN             5.0   0.2     0                0
# 2  Western Storm          NaN             5.0   0.3     0                0
# 3  Western Storm          NaN             5.0   0.4     0                0
# 4  Western Storm          NaN             5.0   0.5     0                0
#
#          city                      venue
# 0  Chelmsford  County Ground, Chelmsford
# 1  Chelmsford  County Ground, Chelmsford
# 2  Chelmsford  County Ground, Chelmsford
# 3  Chelmsford  County Ground, Chelmsford
# 4  Chelmsford  County Ground, Chelmsford

# %%
count = 0
delivery_df_2nd_innings = pd.DataFrame()
for index, row in final_df.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    winner = []
    win_by_runs = []
    win_by_wickets = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][1]['2nd innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][1]['2nd innings']['team'])
            teams.append(row['info.teams'])
            winner.append(row['info.outcome.winner'])
            win_by_runs.append(row['info.outcome.by.runs'])
            win_by_wickets.append(row['info.outcome.by.wickets'])
            ball_of_match.append(key)
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'winner':winner,
            'win_by_runs':win_by_runs,
            'win_by_wickets':win_by_wickets,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df_2nd_innings = delivery_df_2nd_innings.append(loop_df)

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id                                    teams         winner  \
# 0         1  [Loughborough Lightning, Western Storm]  Western Storm
# 1         1  [Loughborough Lightning, Western Storm]  Western Storm
# 2         1  [Loughborough Lightning, Western Storm]  Western Storm
# 3         1  [Loughborough Lightning, Western Storm]  Western Storm
# 4         1  [Loughborough Lightning, Western Storm]  Western Storm
#
#    win_by_runs  win_by_wickets   batting_team  ball  runs player_dismissed  \
# 0          NaN             5.0  Western Storm   0.1     0                0
# 1          NaN             5.0  Western Storm   0.2     0                0
# 2          NaN             5.0  Western Storm   0.3     0                0
# 3          NaN             5.0  Western Storm   0.4     0                0
# 4          NaN             5.0  Western Storm   0.5     0                0
#
#          city                      venue
# 0  Chelmsford  County Ground, Chelmsford
# 1  Chelmsford  County Ground, Chelmsford
# 2  Chelmsford  County Ground, Chelmsford
# 3  Chelmsford  County Ground, Chelmsford
# 4  Chelmsford  County Ground, Chelmsford

# %%
run_data = delivery_df_1st_innings.groupby(['match_id', 'runs'])['runs'].count().reset_index(name="count")

# %%
run_data.head()
# Out:
#    match_id  runs  count
# 0         1     0     53
# 1         1     1     45
# 2         1     2      6
# 3         1     3      1
# 4         1     4     13

# %% [markdown]
# # batting and bowling team separation

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
# First Innings
delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings.apply(bowl,axis=1)

delivery_df_1st_innings.head()
# Out:
#    match_id                                    teams            batting_team  \
# 0         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
# 1         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
# 2         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
# 3         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
# 4         1  [Loughborough Lightning, Western Storm]  Loughborough Lightning
#
#           winner  win_by_runs  win_by_wickets  ball  runs player_dismissed  \
# 0  Western Storm          NaN             5.0   0.1     1                0
# 1  Western Storm          NaN             5.0   0.2     0                0
# 2  Western Storm          NaN             5.0   0.3     0                0
# 3  Western Storm          NaN             5.0   0.4     0                0
# 4  Western Storm          NaN             5.0   0.5     0                0
#
#          city                      venue   bowling_team
# 0  Chelmsford  County Ground, Chelmsford  Western Storm
# 1  Chelmsford  County Ground, Chelmsford  Western Storm
# 2  Chelmsford  County Ground, Chelmsford  Western Storm
# 3  Chelmsford  County Ground, Chelmsford  Western Storm
# 4  Chelmsford  County Ground, Chelmsford  Western Storm

# %%
# Second Innings 
delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings.apply(bowl,axis=1)

delivery_df_2nd_innings.head()
# Out:
#    match_id                                    teams         winner  \
# 0         1  [Loughborough Lightning, Western Storm]  Western Storm
# 1         1  [Loughborough Lightning, Western Storm]  Western Storm
# 2         1  [Loughborough Lightning, Western Storm]  Western Storm
# 3         1  [Loughborough Lightning, Western Storm]  Western Storm
# 4         1  [Loughborough Lightning, Western Storm]  Western Storm
#
#    win_by_runs  win_by_wickets   batting_team  ball  runs player_dismissed  \
# 0          NaN             5.0  Western Storm   0.1     0                0
# 1          NaN             5.0  Western Storm   0.2     0                0
# 2          NaN             5.0  Western Storm   0.3     0                0
# 3          NaN             5.0  Western Storm   0.4     0                0
# 4          NaN             5.0  Western Storm   0.5     0                0
#
#          city                      venue            bowling_team
# 0  Chelmsford  County Ground, Chelmsford  Loughborough Lightning
# 1  Chelmsford  County Ground, Chelmsford  Loughborough Lightning
# 2  Chelmsford  County Ground, Chelmsford  Loughborough Lightning
# 3  Chelmsford  County Ground, Chelmsford  Loughborough Lightning
# 4  Chelmsford  County Ground, Chelmsford  Loughborough Lightning

# %%
# Drop columns
delivery_df_1st_innings.drop(columns=['teams'],inplace=True)
delivery_df_2nd_innings.drop(columns=['teams'],inplace=True)

# %%
delivery_df_1st_innings['batting_team'].unique()
# Out:
# array(['Loughborough Lightning', 'Western Storm', 'Yorkshire Diamonds',
#        'Southern Vipers', 'Surrey Stars', 'Lancashire Thunder'],
#       dtype=object)

# %%
# First Innings
# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Thunder','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Thunder','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Royals','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Royals','Sylhet Strikers')

# Second Innings
# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Thunder','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Thunder','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Royals','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Royals','Sylhet Strikers')

# %%
delivery_df_2nd_innings['batting_team'].unique()
# Out:
# array(['Western Storm', 'Southern Vipers', 'Lancashire Thunder',
#        'Surrey Stars', 'Loughborough Lightning', 'Yorkshire Diamonds'],
#       dtype=object)

# %% [markdown]
# # venue and city

# %%
delivery_df_2nd_innings.isnull().sum()
# Out:
# match_id               0
# winner                 0
# win_by_runs         5329
# win_by_wickets      4625
# batting_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                   0
# venue                  0
# bowling_team           0
# dtype: int64

# %%
delivery_df_1st_innings['venue'].unique()
# Out:
# array(['County Ground, Chelmsford', 'The Rose Bowl, Southampton',
#        'Headingley, Leeds',
#        'The Cooper Associates County Ground, Taunton',
#        'Kennington Oval, London', 'County Ground, Derby',
#        'Old Trafford, Manchester', 'Haslegrave Ground, Loughborough',
#        'Stanley Park, Blackpool', 'Clifton Park Ground, York',
#        'Aigburth, Liverpool', 'Arundel Castle Cricket Club Ground',
#        'County Ground, Bristol', 'County Ground, Hove',
#        'Woodbridge Road, Guildford', 'Trafalgar Road Ground, Southport',
#        'College Ground, Cheltenham',
#        'North Marine Road Ground, Scarborough', 'Edgbaston, Birmingham',
#        'York Cricket Club', 'Boughton Hall Cricket Club Ground, Chester',
#        'Trent Bridge, Nottingham', 'County Ground, Taunton'], dtype=object)

# %%
delivery_df_1st_innings['city'].unique()
# Out:
# array(['Chelmsford', 'Southampton', 'Leeds', 'Taunton', 'London', 'Derby',
#        'Manchester', 'Loughborough', 'Blackpool', 'York', 'Liverpool',
#        'Arundel', 'Bristol', 'Brighton', 'Guildford', 'Southport',
#        'Cheltenham', 'Scarborough', 'Birmingham', 'Chester', 'Nottingham'],
#       dtype=object)

# %%
delivery_df_2nd_innings[delivery_df_2nd_innings['city'].isnull()]['venue'].value_counts()
# Out:
# Series([], Name: venue, dtype: int64)

# %%
# First Innings
# cities = np.where(delivery_df_1st_innings['city'].isnull(), delivery_df_1st_innings['venue'].str.split().apply(lambda x:x[0]), delivery_df_1st_innings['city'])
# delivery_df_1st_innings['city'] = cities

# Second Innings
# cities = np.where(delivery_df_2nd_innings['city'].isnull(), delivery_df_2nd_innings['venue'].str.split().apply(lambda x:x[0]), delivery_df_2nd_innings['city'])
# delivery_df_2nd_innings['city'] = cities

# %%
# Drop Venue Column

# First Innings
delivery_df_1st_innings.drop(columns=['venue'],inplace=True)
# Second Innings
delivery_df_2nd_innings.drop(columns=['venue'],inplace=True)

# %%
delivery_df_1st_innings['city'].value_counts()
# Out:
# Loughborough    1430
# Southampton     1352
# Taunton          899
# Brighton         880
# Leeds            861
# Guildford        820
# London           733
# York             609
# Manchester       502
# Bristol          501
# Liverpool        496
# Blackpool        430
# Arundel          368
# Scarborough      254
# Chelmsford       243
# Derby            126
# Chester          124
# Birmingham       123
# Cheltenham       122
# Nottingham       121
# Southport        106
# Name: city, dtype: int64

# %%
delivery_df_2nd_innings['city'].value_counts()
# Out:
# Loughborough    1302
# Southampton     1190
# Brighton         832
# Taunton          827
# Leeds            783
# London           699
# Guildford        680
# York             512
# Bristol          464
# Liverpool        451
# Manchester       427
# Blackpool        407
# Arundel          273
# Scarborough      242
# Chelmsford       239
# Chester          126
# Derby            125
# Nottingham       100
# Cheltenham        96
# Southport         95
# Birmingham        84
# Name: city, dtype: int64

# %%
# Keeping only those venues where played atleast 5 matches

# First Innings
eligible_cities = delivery_df_1st_innings['city'].value_counts()[delivery_df_1st_innings['city'].value_counts() > 300].index.tolist()
delivery_df_1st_innings = delivery_df_1st_innings[delivery_df_1st_innings['city'].isin(eligible_cities)]

# Second Innings
eligible_cities = delivery_df_2nd_innings['city'].value_counts()[delivery_df_2nd_innings['city'].value_counts() > 300].index.tolist()
delivery_df_2nd_innings = delivery_df_2nd_innings[delivery_df_2nd_innings['city'].isin(eligible_cities)]

# %%
delivery_df_1st_innings['city'].unique()
# Out:
# array(['Southampton', 'Leeds', 'Taunton', 'London', 'Manchester',
#        'Loughborough', 'Blackpool', 'York', 'Liverpool', 'Arundel',
#        'Bristol', 'Brighton', 'Guildford'], dtype=object)

# %% [markdown]
# # current score

# %%
# First Innings
delivery_df_1st_innings['current_score'] = delivery_df_1st_innings.groupby('match_id').cumsum()['runs']

# Second Innings
delivery_df_2nd_innings['current_score'] = delivery_df_2nd_innings.groupby('match_id').cumsum()['runs']

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id           winner  win_by_runs  win_by_wickets     batting_team  \
# 0         3  Southern Vipers          NaN             9.0  Southern Vipers
# 1         3  Southern Vipers          NaN             9.0  Southern Vipers
# 2         3  Southern Vipers          NaN             9.0  Southern Vipers
# 3         3  Southern Vipers          NaN             9.0  Southern Vipers
# 4         3  Southern Vipers          NaN             9.0  Southern Vipers
#
#    ball  runs player_dismissed         city   bowling_team  current_score
# 0   0.1     0                0  Southampton  Western Storm              0
# 1   0.2     0                0  Southampton  Western Storm              0
# 2   0.3     0                0  Southampton  Western Storm              0
# 3   0.4     0                0  Southampton  Western Storm              0
# 4   0.5     0                0  Southampton  Western Storm              0

# %% [markdown]
# # wicket left

# %%
# First Innings
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings['player_dismissed'].astype('int')
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings.groupby('match_id').cumsum()['player_dismissed']
delivery_df_1st_innings['wickets_left'] = 10 - delivery_df_1st_innings['player_dismissed']

delivery_df_1st_innings.head()
# Out:
#    match_id   batting_team           winner  win_by_runs  win_by_wickets  \
# 0         3  Western Storm  Southern Vipers          NaN             9.0
# 1         3  Western Storm  Southern Vipers          NaN             9.0
# 2         3  Western Storm  Southern Vipers          NaN             9.0
# 3         3  Western Storm  Southern Vipers          NaN             9.0
# 4         3  Western Storm  Southern Vipers          NaN             9.0
#
#    ball  runs  player_dismissed         city     bowling_team  current_score  \
# 0   0.1     1                 0  Southampton  Southern Vipers              1
# 1   0.2     1                 0  Southampton  Southern Vipers              2
# 2   0.3     0                 0  Southampton  Southern Vipers              2
# 3   0.4     1                 0  Southampton  Southern Vipers              3
# 4   0.5     0                 0  Southampton  Southern Vipers              3
#
#    wickets_left
# 0            10
# 1            10
# 2            10
# 3            10
# 4            10

# %%
# Second Innings
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings['player_dismissed'].astype('int')
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings.groupby('match_id').cumsum()['player_dismissed']
delivery_df_2nd_innings['wickets_left'] = 10 - delivery_df_2nd_innings['player_dismissed']

delivery_df_2nd_innings.head()
# Out:
#    match_id           winner  win_by_runs  win_by_wickets     batting_team  \
# 0         3  Southern Vipers          NaN             9.0  Southern Vipers
# 1         3  Southern Vipers          NaN             9.0  Southern Vipers
# 2         3  Southern Vipers          NaN             9.0  Southern Vipers
# 3         3  Southern Vipers          NaN             9.0  Southern Vipers
# 4         3  Southern Vipers          NaN             9.0  Southern Vipers
#
#    ball  runs  player_dismissed         city   bowling_team  current_score  \
# 0   0.1     0                 0  Southampton  Western Storm              0
# 1   0.2     0                 0  Southampton  Western Storm              0
# 2   0.3     0                 0  Southampton  Western Storm              0
# 3   0.4     0                 0  Southampton  Western Storm              0
# 4   0.5     0                 0  Southampton  Western Storm              0
#
#    wickets_left
# 0            10
# 1            10
# 2            10
# 3            10
# 4            10

# %% [markdown]
# # bowl delivered & bowl left

# %%
# First Innings
delivery_df_1st_innings['over'] = delivery_df_1st_innings['ball'].apply(lambda x:str(x).split(".")[0])
delivery_df_1st_innings['ball_no'] = delivery_df_1st_innings['ball'].apply(lambda x:str(x).split(".")[1])
delivery_df_1st_innings['balls_bowled'] = (delivery_df_1st_innings['over'].astype('int')*6) + delivery_df_1st_innings['ball_no'].astype('int')
delivery_df_1st_innings['balls_left'] = 120 - delivery_df_1st_innings['balls_bowled']
delivery_df_1st_innings['balls_left'] = delivery_df_1st_innings['balls_left'].apply(lambda x:0 if x<0 else x)

delivery_df_1st_innings.head()
# Out:
#    match_id   batting_team           winner  win_by_runs  win_by_wickets  \
# 0         3  Western Storm  Southern Vipers          NaN             9.0
# 1         3  Western Storm  Southern Vipers          NaN             9.0
# 2         3  Western Storm  Southern Vipers          NaN             9.0
# 3         3  Western Storm  Southern Vipers          NaN             9.0
# 4         3  Western Storm  Southern Vipers          NaN             9.0
#
#    ball  runs  player_dismissed         city     bowling_team  current_score  \
# 0   0.1     1                 0  Southampton  Southern Vipers              1
# 1   0.2     1                 0  Southampton  Southern Vipers              2
# 2   0.3     0                 0  Southampton  Southern Vipers              2
# 3   0.4     1                 0  Southampton  Southern Vipers              3
# 4   0.5     0                 0  Southampton  Southern Vipers              3
#
#    wickets_left over ball_no  balls_bowled  balls_left
# 0            10    0       1             1         119
# 1            10    0       2             2         118
# 2            10    0       3             3         117
# 3            10    0       4             4         116
# 4            10    0       5             5         115

# %%
# Second Innings
delivery_df_2nd_innings['over'] = delivery_df_2nd_innings['ball'].apply(lambda x:str(x).split(".")[0])
delivery_df_2nd_innings['ball_no'] = delivery_df_2nd_innings['ball'].apply(lambda x:str(x).split(".")[1])
delivery_df_2nd_innings['balls_bowled'] = (delivery_df_2nd_innings['over'].astype('int')*6) + delivery_df_2nd_innings['ball_no'].astype('int')
delivery_df_2nd_innings['balls_left'] = 120 - delivery_df_2nd_innings['balls_bowled']
delivery_df_2nd_innings['balls_left'] = delivery_df_2nd_innings['balls_left'].apply(lambda x:0 if x<0 else x)

delivery_df_2nd_innings.head()
# Out:
#    match_id           winner  win_by_runs  win_by_wickets     batting_team  \
# 0         3  Southern Vipers          NaN             9.0  Southern Vipers
# 1         3  Southern Vipers          NaN             9.0  Southern Vipers
# 2         3  Southern Vipers          NaN             9.0  Southern Vipers
# 3         3  Southern Vipers          NaN             9.0  Southern Vipers
# 4         3  Southern Vipers          NaN             9.0  Southern Vipers
#
#    ball  runs  player_dismissed         city   bowling_team  current_score  \
# 0   0.1     0                 0  Southampton  Western Storm              0
# 1   0.2     0                 0  Southampton  Western Storm              0
# 2   0.3     0                 0  Southampton  Western Storm              0
# 3   0.4     0                 0  Southampton  Western Storm              0
# 4   0.5     0                 0  Southampton  Western Storm              0
#
#    wickets_left over ball_no  balls_bowled  balls_left
# 0            10    0       1             1         119
# 1            10    0       2             2         118
# 2            10    0       3             3         117
# 3            10    0       4             4         116
# 4            10    0       5             5         115

# %% [markdown]
# # current run rate

# %%
# First Innings
delivery_df_1st_innings['crr'] = round((delivery_df_1st_innings['current_score']*6)/delivery_df_1st_innings['balls_bowled'], 2)

# Second Innings
delivery_df_2nd_innings['crr'] = round((delivery_df_2nd_innings['current_score']*6)/delivery_df_2nd_innings['balls_bowled'], 2)

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id           winner  win_by_runs  win_by_wickets     batting_team  \
# 0         3  Southern Vipers          NaN             9.0  Southern Vipers
# 1         3  Southern Vipers          NaN             9.0  Southern Vipers
# 2         3  Southern Vipers          NaN             9.0  Southern Vipers
# 3         3  Southern Vipers          NaN             9.0  Southern Vipers
# 4         3  Southern Vipers          NaN             9.0  Southern Vipers
#
#    ball  runs  player_dismissed         city   bowling_team  current_score  \
# 0   0.1     0                 0  Southampton  Western Storm              0
# 1   0.2     0                 0  Southampton  Western Storm              0
# 2   0.3     0                 0  Southampton  Western Storm              0
# 3   0.4     0                 0  Southampton  Western Storm              0
# 4   0.5     0                 0  Southampton  Western Storm              0
#
#    wickets_left over ball_no  balls_bowled  balls_left  crr
# 0            10    0       1             1         119  0.0
# 1            10    0       2             2         118  0.0
# 2            10    0       3             3         117  0.0
# 3            10    0       4             4         116  0.0
# 4            10    0       5             5         115  0.0

# %% [markdown]
# # Score and Win Probabilty (before the start of the match and during the first innings)

# %% [markdown]
# # total score counting according to match

# %%
total_df = delivery_df_1st_innings.groupby('match_id').sum()['runs'].reset_index()
score_probability_output = delivery_df_1st_innings.merge(total_df,on='match_id')

score_probability_output.head()
# Out:
#    match_id   batting_team           winner  win_by_runs  win_by_wickets  \
# 0         3  Western Storm  Southern Vipers          NaN             9.0
# 1         3  Western Storm  Southern Vipers          NaN             9.0
# 2         3  Western Storm  Southern Vipers          NaN             9.0
# 3         3  Western Storm  Southern Vipers          NaN             9.0
# 4         3  Western Storm  Southern Vipers          NaN             9.0
#
#    ball  runs_x  player_dismissed         city     bowling_team  \
# 0   0.1       1                 0  Southampton  Southern Vipers
# 1   0.2       1                 0  Southampton  Southern Vipers
# 2   0.3       0                 0  Southampton  Southern Vipers
# 3   0.4       1                 0  Southampton  Southern Vipers
# 4   0.5       0                 0  Southampton  Southern Vipers
#
#    current_score  wickets_left over ball_no  balls_bowled  balls_left  crr  \
# 0              1            10    0       1             1         119  6.0
# 1              2            10    0       2             2         118  6.0
# 2              2            10    0       3             3         117  4.0
# 3              3            10    0       4             4         116  4.5
# 4              3            10    0       5             5         115  3.6
#
#    runs_y
# 0      70
# 1      70
# 2      70
# 3      70
# 4      70

# %% [markdown]
# # counting runs in remaining balls

# %%
score_probability_output['runs_in_remaining_ball'] = score_probability_output['runs_y'] - score_probability_output['current_score']

score_probability_output.head()
# Out:
#    match_id   batting_team           winner  win_by_runs  win_by_wickets  \
# 0         3  Western Storm  Southern Vipers          NaN             9.0
# 1         3  Western Storm  Southern Vipers          NaN             9.0
# 2         3  Western Storm  Southern Vipers          NaN             9.0
# 3         3  Western Storm  Southern Vipers          NaN             9.0
# 4         3  Western Storm  Southern Vipers          NaN             9.0
#
#    ball  runs_x  player_dismissed         city     bowling_team  \
# 0   0.1       1                 0  Southampton  Southern Vipers
# 1   0.2       1                 0  Southampton  Southern Vipers
# 2   0.3       0                 0  Southampton  Southern Vipers
# 3   0.4       1                 0  Southampton  Southern Vipers
# 4   0.5       0                 0  Southampton  Southern Vipers
#
#    current_score  wickets_left over ball_no  balls_bowled  balls_left  crr  \
# 0              1            10    0       1             1         119  6.0
# 1              2            10    0       2             2         118  6.0
# 2              2            10    0       3             3         117  4.0
# 3              3            10    0       4             4         116  4.5
# 4              3            10    0       5             5         115  3.6
#
#    runs_y  runs_in_remaining_ball
# 0      70                      69
# 1      70                      68
# 2      70                      68
# 3      70                      67
# 4      70                      67

# %% [markdown]
# # consider batting team win

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

score_probability_output['result_first_innings'] = score_probability_output.apply(result, axis=1)

score_probability_output.head()
# Out:
#    match_id   batting_team           winner  win_by_runs  win_by_wickets  \
# 0         3  Western Storm  Southern Vipers          NaN             9.0
# 1         3  Western Storm  Southern Vipers          NaN             9.0
# 2         3  Western Storm  Southern Vipers          NaN             9.0
# 3         3  Western Storm  Southern Vipers          NaN             9.0
# 4         3  Western Storm  Southern Vipers          NaN             9.0
#
#    ball  runs_x  player_dismissed         city     bowling_team  \
# 0   0.1       1                 0  Southampton  Southern Vipers
# 1   0.2       1                 0  Southampton  Southern Vipers
# 2   0.3       0                 0  Southampton  Southern Vipers
# 3   0.4       1                 0  Southampton  Southern Vipers
# 4   0.5       0                 0  Southampton  Southern Vipers
#
#    current_score  wickets_left over ball_no  balls_bowled  balls_left  crr  \
# 0              1            10    0       1             1         119  6.0
# 1              2            10    0       2             2         118  6.0
# 2              2            10    0       3             3         117  4.0
# 3              3            10    0       4             4         116  4.5
# 4              3            10    0       5             5         115  3.6
#
#    runs_y  runs_in_remaining_ball  result_first_innings
# 0      70                      69                     0
# 1      70                      68                     0
# 2      70                      68                     0
# 3      70                      67                     0
# 4      70                      67                     0

# %% [markdown]
# # final data for score probabilty

# %%
final_score_probability_df = score_probability_output[['batting_team','bowling_team','city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left','crr', 'runs_in_remaining_ball']]
final_score_probability_df.head()
# Out:
#     batting_team     bowling_team         city  current_score  balls_bowled  \
# 0  Western Storm  Southern Vipers  Southampton              1             1
# 1  Western Storm  Southern Vipers  Southampton              2             2
# 2  Western Storm  Southern Vipers  Southampton              2             3
# 3  Western Storm  Southern Vipers  Southampton              3             4
# 4  Western Storm  Southern Vipers  Southampton              3             5
#
#    balls_left  wickets_left  crr  runs_in_remaining_ball
# 0         119            10  6.0                      69
# 1         118            10  6.0                      68
# 2         117            10  4.0                      68
# 3         116            10  4.5                      67
# 4         115            10  3.6                      67

# %%
final_score_probability_df = final_score_probability_df[final_score_probability_df['balls_left'] != 0]
final_score_probability_df
# Out:
#             batting_team     bowling_team         city  current_score  \
# 0          Western Storm  Southern Vipers  Southampton              1
# 1          Western Storm  Southern Vipers  Southampton              2
# 2          Western Storm  Southern Vipers  Southampton              2
# 3          Western Storm  Southern Vipers  Southampton              3
# 4          Western Storm  Southern Vipers  Southampton              3
# ...                  ...              ...          ...            ...
# 9875  Yorkshire Diamonds    Western Storm        Leeds            118
# 9876  Yorkshire Diamonds    Western Storm        Leeds            118
# 9877  Yorkshire Diamonds    Western Storm        Leeds            118
# 9878  Yorkshire Diamonds    Western Storm        Leeds            118
# 9879  Yorkshire Diamonds    Western Storm        Leeds            118
#
#       balls_bowled  balls_left  wickets_left   crr  runs_in_remaining_ball
# 0                1         119            10  6.00                      69
# 1                2         118            10  6.00                      68
# 2                3         117            10  4.00                      68
# 3                4         116            10  4.50                      67
# 4                5         115            10  3.60                      67
# ...            ...         ...           ...   ...                     ...
# 9875           115           5             3  6.16                       0
# 9876           116           4             2  6.10                       0
# 9877           117           3             2  6.05                       0
# 9878           118           2             2  6.00                       0
# 9879           119           1             1  5.95                       0
#
# [9792 rows x 9 columns]

# %% [markdown]
# # final innings score probability data extraction

# %%
pickle.dump(final_score_probability_df, open('wcsl_womens_first_innings_score.pkl','wb'))

# %% [markdown]
# # win probabilty

# %%
final_win_probability_df = score_probability_output[[
    'batting_team',
    'bowling_team',
    'city',
    'runs_y',
    'result_first_innings'
]]

final_win_probability_df.head()
# Out:
#     batting_team     bowling_team         city  runs_y  result_first_innings
# 0  Western Storm  Southern Vipers  Southampton      70                     0
# 1  Western Storm  Southern Vipers  Southampton      70                     0
# 2  Western Storm  Southern Vipers  Southampton      70                     0
# 3  Western Storm  Southern Vipers  Southampton      70                     0
# 4  Western Storm  Southern Vipers  Southampton      70                     0

# %% [markdown]
# # final first innings win data extraction

# %%
pickle.dump(final_win_probability_df, open('wcsl_womens_first_innings_win.pkl','wb'))

# %% [markdown]
# # Win Probabilty (during the second innings)

# %% [markdown]
# # target runs from first innings

# %%
total_score_df = delivery_df_1st_innings.groupby([
    'match_id',
]).sum()['runs'].reset_index()

total_score_df.head()
# Out:
#    match_id  runs
# 0         3    70
# 1         4   162
# 2         5   108
# 3         6   100
# 4         8   133

# %%
total_score_df['target_runs'] = total_score_df['runs'] + 1
total_score_df.drop(columns=['runs'], inplace=True)

total_score_df.head()
# Out:
#    match_id  target_runs
# 0         3           71
# 1         4          163
# 2         5          109
# 3         6          101
# 4         8          134

# %% [markdown]
# # merge with second innings data

# %%
final_2nd_innings_win_df = delivery_df_2nd_innings.merge(total_score_df, on='match_id')
final_2nd_innings_win_df.head()
# Out:
#    match_id           winner  win_by_runs  win_by_wickets     batting_team  \
# 0         3  Southern Vipers          NaN             9.0  Southern Vipers
# 1         3  Southern Vipers          NaN             9.0  Southern Vipers
# 2         3  Southern Vipers          NaN             9.0  Southern Vipers
# 3         3  Southern Vipers          NaN             9.0  Southern Vipers
# 4         3  Southern Vipers          NaN             9.0  Southern Vipers
#
#    ball  runs  player_dismissed         city   bowling_team  current_score  \
# 0   0.1     0                 0  Southampton  Western Storm              0
# 1   0.2     0                 0  Southampton  Western Storm              0
# 2   0.3     0                 0  Southampton  Western Storm              0
# 3   0.4     0                 0  Southampton  Western Storm              0
# 4   0.5     0                 0  Southampton  Western Storm              0
#
#    wickets_left over ball_no  balls_bowled  balls_left  crr  target_runs
# 0            10    0       1             1         119  0.0           71
# 1            10    0       2             2         118  0.0           71
# 2            10    0       3             3         117  0.0           71
# 3            10    0       4             4         116  0.0           71
# 4            10    0       5             5         115  0.0           71

# %% [markdown]
# # runs left

# %%
final_2nd_innings_win_df['runs_left'] = final_2nd_innings_win_df['target_runs'] - final_2nd_innings_win_df['current_score']
final_2nd_innings_win_df.head()
# Out:
#    match_id           winner  win_by_runs  win_by_wickets     batting_team  \
# 0         3  Southern Vipers          NaN             9.0  Southern Vipers
# 1         3  Southern Vipers          NaN             9.0  Southern Vipers
# 2         3  Southern Vipers          NaN             9.0  Southern Vipers
# 3         3  Southern Vipers          NaN             9.0  Southern Vipers
# 4         3  Southern Vipers          NaN             9.0  Southern Vipers
#
#    ball  runs  player_dismissed         city   bowling_team  current_score  \
# 0   0.1     0                 0  Southampton  Western Storm              0
# 1   0.2     0                 0  Southampton  Western Storm              0
# 2   0.3     0                 0  Southampton  Western Storm              0
# 3   0.4     0                 0  Southampton  Western Storm              0
# 4   0.5     0                 0  Southampton  Western Storm              0
#
#    wickets_left over ball_no  balls_bowled  balls_left  crr  target_runs  \
# 0            10    0       1             1         119  0.0           71
# 1            10    0       2             2         118  0.0           71
# 2            10    0       3             3         117  0.0           71
# 3            10    0       4             4         116  0.0           71
# 4            10    0       5             5         115  0.0           71
#
#    runs_left
# 0         71
# 1         71
# 2         71
# 3         71
# 4         71

# %% [markdown]
# # required run rate

# %%
final_2nd_innings_win_df['rrr'] = round((final_2nd_innings_win_df['runs_left']*6)/final_2nd_innings_win_df['balls_left'], 2)

final_2nd_innings_win_df.head()
# Out:
#    match_id           winner  win_by_runs  win_by_wickets     batting_team  \
# 0         3  Southern Vipers          NaN             9.0  Southern Vipers
# 1         3  Southern Vipers          NaN             9.0  Southern Vipers
# 2         3  Southern Vipers          NaN             9.0  Southern Vipers
# 3         3  Southern Vipers          NaN             9.0  Southern Vipers
# 4         3  Southern Vipers          NaN             9.0  Southern Vipers
#
#    ball  runs  player_dismissed         city   bowling_team  current_score  \
# 0   0.1     0                 0  Southampton  Western Storm              0
# 1   0.2     0                 0  Southampton  Western Storm              0
# 2   0.3     0                 0  Southampton  Western Storm              0
# 3   0.4     0                 0  Southampton  Western Storm              0
# 4   0.5     0                 0  Southampton  Western Storm              0
#
#    wickets_left over ball_no  balls_bowled  balls_left  crr  target_runs  \
# 0            10    0       1             1         119  0.0           71
# 1            10    0       2             2         118  0.0           71
# 2            10    0       3             3         117  0.0           71
# 3            10    0       4             4         116  0.0           71
# 4            10    0       5             5         115  0.0           71
#
#    runs_left   rrr
# 0         71  3.58
# 1         71  3.61
# 2         71  3.64
# 3         71  3.67
# 4         71  3.70

# %%
final_2nd_innings_win_df.isnull().sum()
# Out:
# match_id               0
# winner                 0
# win_by_runs         4289
# win_by_wickets      4285
# batting_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                   0
# bowling_team           0
# current_score          0
# wickets_left           0
# over                   0
# ball_no                0
# balls_bowled           0
# balls_left             0
# crr                    0
# target_runs            0
# runs_left              0
# rrr                    1
# dtype: int64

# %%
final_2nd_innings_win_df = final_2nd_innings_win_df[final_2nd_innings_win_df['balls_left'] != 0]

# %%
final_2nd_innings_win_df.isnull().sum()
# Out:
# match_id               0
# winner                 0
# win_by_runs         4288
# win_by_wickets      4272
# batting_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                   0
# bowling_team           0
# current_score          0
# wickets_left           0
# over                   0
# ball_no                0
# balls_bowled           0
# balls_left             0
# crr                    0
# target_runs            0
# runs_left              0
# rrr                    0
# dtype: int64

# %% [markdown]
# # consider batting team win

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

final_2nd_innings_win_df['result'] = final_2nd_innings_win_df.apply(result, axis=1)

final_2nd_innings_win_df.head()
# Out:
#    match_id           winner  win_by_runs  win_by_wickets     batting_team  \
# 0         3  Southern Vipers          NaN             9.0  Southern Vipers
# 1         3  Southern Vipers          NaN             9.0  Southern Vipers
# 2         3  Southern Vipers          NaN             9.0  Southern Vipers
# 3         3  Southern Vipers          NaN             9.0  Southern Vipers
# 4         3  Southern Vipers          NaN             9.0  Southern Vipers
#
#    ball  runs  player_dismissed         city   bowling_team  ...  \
# 0   0.1     0                 0  Southampton  Western Storm  ...
# 1   0.2     0                 0  Southampton  Western Storm  ...
# 2   0.3     0                 0  Southampton  Western Storm  ...
# 3   0.4     0                 0  Southampton  Western Storm  ...
# 4   0.5     0                 0  Southampton  Western Storm  ...
#
#    wickets_left  over ball_no balls_bowled  balls_left  crr  target_runs  \
# 0            10     0       1            1         119  0.0           71
# 1            10     0       2            2         118  0.0           71
# 2            10     0       3            3         117  0.0           71
# 3            10     0       4            4         116  0.0           71
# 4            10     0       5            5         115  0.0           71
#
#    runs_left   rrr  result
# 0         71  3.58       1
# 1         71  3.61       1
# 2         71  3.64       1
# 3         71  3.67       1
# 4         71  3.70       1
#
# [5 rows x 21 columns]

# %% [markdown]
# # final data for second innings win

# %%
final_2nd_innings_win_df = final_2nd_innings_win_df[[
    'batting_team',
    'bowling_team',
    'city',
    'current_score',
    'target_runs',
    'runs_left',
    'balls_left',
    'wickets_left',
    'crr',
    'rrr',
    'result'
]]

final_2nd_innings_win_df.head()
# Out:
#       batting_team   bowling_team         city  current_score  target_runs  \
# 0  Southern Vipers  Western Storm  Southampton              0           71
# 1  Southern Vipers  Western Storm  Southampton              0           71
# 2  Southern Vipers  Western Storm  Southampton              0           71
# 3  Southern Vipers  Western Storm  Southampton              0           71
# 4  Southern Vipers  Western Storm  Southampton              0           71
#
#    runs_left  balls_left  wickets_left  crr   rrr  result
# 0         71         119            10  0.0  3.58       1
# 1         71         118            10  0.0  3.61       1
# 2         71         117            10  0.0  3.64       1
# 3         71         116            10  0.0  3.67       1
# 4         71         115            10  0.0  3.70       1

# %% [markdown]
# # final second innings win data extraction

# %%
pickle.dump(final_2nd_innings_win_df, open('wcsl_womens_second_innings_win.pkl','wb'))

# %% [markdown]
# # Machine Learning Model

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, accuracy_score, confusion_matrix, classification_report

from sklearn.model_selection import train_test_split

# %% [markdown]
# # score probability

# %%
#load data
score_portability_df = pickle.load(open('wcsl_womens_first_innings_score.pkl','rb'))
score_portability_df.shape
# Out:
# (9792, 9)

# %%
score_portability_df.to_csv(r'wcsl_womens_first_innings_score.csv', index=False, header=True)
score_portability_df = pd.read_csv(r'wcsl_womens_first_innings_score.csv')

# %%
score_portability_df
# Out:
#             batting_team     bowling_team         city  current_score  \
# 0          Western Storm  Southern Vipers  Southampton              1
# 1          Western Storm  Southern Vipers  Southampton              2
# 2          Western Storm  Southern Vipers  Southampton              2
# 3          Western Storm  Southern Vipers  Southampton              3
# 4          Western Storm  Southern Vipers  Southampton              3
# ...                  ...              ...          ...            ...
# 9787  Yorkshire Diamonds    Western Storm        Leeds            118
# 9788  Yorkshire Diamonds    Western Storm        Leeds            118
# 9789  Yorkshire Diamonds    Western Storm        Leeds            118
# 9790  Yorkshire Diamonds    Western Storm        Leeds            118
# 9791  Yorkshire Diamonds    Western Storm        Leeds            118
#
#       balls_bowled  balls_left  wickets_left   crr  runs_in_remaining_ball
# 0                1         119            10  6.00                      69
# 1                2         118            10  6.00                      68
# 2                3         117            10  4.00                      68
# 3                4         116            10  4.50                      67
# 4                5         115            10  3.60                      67
# ...            ...         ...           ...   ...                     ...
# 9787           115           5             3  6.16                       0
# 9788           116           4             2  6.10                       0
# 9789           117           3             2  6.05                       0
# 9790           118           2             2  6.00                       0
# 9791           119           1             1  5.95                       0
#
# [9792 rows x 9 columns]

# %%
score_portability_df.isnull().sum()
# Out:
# batting_team              0
# bowling_team              0
# city                      0
# current_score             0
# balls_bowled              0
# balls_left                0
# wickets_left              0
# crr                       0
# runs_in_remaining_ball    0
# dtype: int64

# %%
X = score_portability_df.drop(columns=['runs_in_remaining_ball'])
y = score_portability_df['runs_in_remaining_ball'].values

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.05, random_state=1)

# %%
X_train
# Out:
#                 batting_team        bowling_team          city  current_score  \
# 3666  Loughborough Lightning        Surrey Stars     Guildford              1
# 1198            Surrey Stars       Western Storm        London             27
# 8962            Surrey Stars       Western Storm       Bristol             29
# 1995            Surrey Stars     Southern Vipers     Guildford             79
# 6868           Western Storm     Southern Vipers       Bristol             98
# ...                      ...                 ...           ...            ...
# 2895  Loughborough Lightning  Yorkshire Diamonds  Loughborough            112
# 7813  Loughborough Lightning     Southern Vipers   Southampton            133
# 905             Surrey Stars     Southern Vipers   Southampton            107
# 5192  Loughborough Lightning       Western Storm  Loughborough            119
# 235       Yorkshire Diamonds  Lancashire Thunder         Leeds            152
#
#       balls_bowled  balls_left  wickets_left   crr
# 3666             5         115            10  1.20
# 1198            26          94             9  6.23
# 8962            27          93             9  6.44
# 1995            77          43             6  6.16
# 6868            77          43             8  7.64
# ...            ...         ...           ...   ...
# 2895            91          29             6  7.38
# 7813           105          15             6  7.60
# 905             96          24             5  6.69
# 5192           117           3             5  6.10
# 235            115           5             6  7.93
#
# [9302 rows x 8 columns]

# %%
y_train
# Out:
# array([ 99, 142, 132, ...,  20,   6,  10], dtype=int64)

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'), ['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %% [markdown]
# # XgBoosting

# %%
pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2', StandardScaler()),
    ('step3', XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=20, random_state=1))
])

pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', StandardScaler()),
#                 ('step3',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, early_stopping_rou...
#                               feature_types=None, gamma=None, gpu_id=None,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=0.2,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=20, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=1000,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, random_state=1, ...))])

# %%
y_pred = pipe.predict(X_test)
print('R-Square Score: '+str(r2_score(y_test, y_pred)))
print('Mean Absolute Error: '+str(mean_absolute_error(y_test, y_pred)))
# Out:
# R-Square Score: 0.990508122281075
# Mean Absolute Error: 2.1773145568614103

# %%
predictions_xgb = pipe.predict(X_test)
sample_xgb = pd.DataFrame(predictions_xgb, columns=['Predict'])
sample_xgb['Actual']=y_test
sample_xgb.head(20)
# Out:
#        Predict  Actual
# 0    79.306274      80
# 1    48.522842      49
# 2    13.419706      14
# 3    71.180855      70
# 4    67.831940      67
# 5    60.001797      60
# 6   111.990181     109
# 7    88.561920      76
# 8    68.083130      68
# 9    16.874887      15
# 10   42.469742      41
# 11  113.733131     116
# 12   26.832558      25
# 13   58.633324      59
# 14   26.659161      28
# 15   25.915043      28
# 16   37.243084      38
# 17  153.670303     154
# 18   42.911587      43
# 19   77.825333      74

# %%
score_portability_df['city'].unique()
# Out:
# array(['Southampton', 'Leeds', 'Taunton', 'London', 'Manchester',
#        'Loughborough', 'Blackpool', 'York', 'Liverpool', 'Arundel',
#        'Bristol', 'Brighton', 'Guildford'], dtype=object)

# %%
score_portability_df['batting_team'].unique()
# Out:
# array(['Western Storm', 'Yorkshire Diamonds', 'Loughborough Lightning',
#        'Surrey Stars', 'Lancashire Thunder', 'Southern Vipers'],
#       dtype=object)

# %% [markdown]
# # result count first way

# %%
input_df = pd.DataFrame({'batting_team': ['Lancashire Thunder'], 'bowling_team': ['Southern Vipers'], 'city': ['Southampton'], 'current_score': [120], 'balls_bowled': [108], 'balls_left': [12], 'wickets_left': [6], 'crr': [9.44]})
result = pipe.predict(input_df)[0]

#math.floor(result)
print('Probable Score: '+str(math.floor(result + 120)-8)+ ' to '+str(math.floor(result + 120)+4))
# Out:
# Probable Score: 135 to 147

# %% [markdown]
# # result count second way

# %%
result = pipe.predict(pd.DataFrame([['Peshawar Zalmi', 'Quetta Gladiators', 'Sharjah', 60, 90, 30, 10, 4.0]], columns=['batting_team', 'bowling_team', 'city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left', 'crr']))

#math.floor(result)
print('Probable Score: '+str(math.floor(result + 60)-8)+ ' to '+str(math.floor(result + 60)+2))
# Out:
# Probable Score: 99 to 109

# %% [markdown]
# # Random Forest

# %%
pipe_rf = Pipeline(steps=[
    ('step1', trf),
    ('step2', StandardScaler()),
    ('step3', RandomForestRegressor())
])

pipe_rf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', StandardScaler()),
#                 ('step3', RandomForestRegressor())])

# %%
y_pred_rf = pipe_rf.predict(X_test)
print('R-Square Score: '+str(r2_score(y_test, y_pred_rf)))
print('Mean Absolute Error: '+str(mean_absolute_error(y_test, y_pred_rf)))
# Out:
# R-Square Score: 0.9886262768130677
# Mean Absolute Error: 2.609300583090379

# %%
predictions_rf = pipe_rf.predict(X_test)
sample_rf = pd.DataFrame(predictions_rf, columns=['Predict'])
sample_rf['Actual']=y_test
sample_rf.head(20)
# Out:
#        Predict  Actual
# 0    78.830000      80
# 1    49.370000      49
# 2    15.670000      14
# 3    68.360000      70
# 4    67.470000      67
# 5    59.590000      60
# 6   108.356667     109
# 7    92.780000      76
# 8    74.210000      68
# 9    16.810000      15
# 10   42.240000      41
# 11  115.630000     116
# 12   26.070000      25
# 13   58.270000      59
# 14   28.890000      28
# 15   24.870000      28
# 16   40.580000      38
# 17  149.880000     154
# 18   44.120000      43
# 19   74.000000      74

# %%
result = pipe_rf.predict(pd.DataFrame([['Auckland', 'Central Districts', 'New Plymouth', 60, 90, 30, 10, 4.0]], columns=['batting_team', 'bowling_team', 'city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left', 'crr']))

#math.floor(result)
print('Probable Score: '+str(math.floor(result + 60)-8)+ ' to '+str(math.floor(result + 60)+2))
# Out:
# Probable Score: 97 to 107

# %% [markdown]
# # Comparison Tables "Predict and Actual"

# %%
def display_dfs(dfs, gap=50, justify='center'):
    html = ""
    for title, df in dfs.items():  
        df_html = df._repr_html_()
        cur_html = f'<div> <h4>{title}</h4> {df_html}</div>'
        html +=  cur_html
    html= f"""
    <div style="display:flex; gap:{gap}px; justify-content:{justify};">
        {html}
    </div>
    """
    display_html(html, raw=True)


dfs = {'XGBoost Regressor': sample_xgb.head(20), 
       'Random Forest Regressor': sample_rf.head(20)}
# dfs = {'Model-1': sample3.head(20),
#        'Model-2': sample4.head(20),
#        'Model-3': sample5.head(20),
#        'Model-4': sample6.head(20)}
display_dfs(dfs, justify='flex-start')
# Out:
#     <div style="display:flex; gap:50px; justify-content:flex-start;">
#         <div> <h4>XGBoost Regressor</h4> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predict</th>
#       <th>Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>79.306274</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>48.522842</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13.419706</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>71.180855</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>67.831940</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>60.001797</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>111.990181</td>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>88.561920</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>68.083130</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>16.874887</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>42.469742</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>113.733131</td>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>26.832558</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>58.633324</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>26.659161</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>25.915043</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>37.243084</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>153.670303</td>
#       <td>154</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>42.911587</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>77.825333</td>
#       <td>74</td>
#     </tr>
#   </tbody>
# </table>
# </div></div><div> <h4>Random Forest Regressor</h4> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predict</th>
#       <th>Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>78.830000</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>49.370000</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15.670000</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>68.360000</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>67.470000</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>59.590000</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>108.356667</td>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>92.780000</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>74.210000</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>16.810000</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>42.240000</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>115.630000</td>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>26.070000</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>58.270000</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>28.890000</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>24.870000</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>40.580000</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>149.880000</td>
#       <td>154</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>44.120000</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>74.000000</td>
#       <td>74</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#     </div>

# %% [markdown]
# # Comparison Graph

# %% [markdown]
# # Xgboost Regression

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.set(font_scale=1)

sns.regplot(data=sample_xgb, x='Actual', y='Predict',
            scatter_kws=dict(color='green', s=12, alpha=0.4),
            line_kws=dict(color='black', alpha=0.8), ).set(title='XGBoost Regressor')
# Out:
# [Text(0.5, 1.0, 'XGBoost Regressor')]

# %% [markdown]
# # Random Forest Regression

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.set(font_scale=1)

sns.regplot(data=sample_rf, x='Actual', y='Predict',
            scatter_kws=dict(color='green', s=12, alpha=0.4),
            line_kws=dict(color='black', alpha=0.8), ).set(title='Random Forest Regressor')
# Out:
# [Text(0.5, 1.0, 'Random Forest Regressor')]

# %%
plt.rcParams["figure.figsize"] = (18, 14) 

plt.subplot(2,2,1)
plt.title("XGBoost Regressor", fontsize=16)
plt.scatter(sample_xgb['Actual'], sample_xgb['Predict'], c='g')
plt.grid()

plt.subplot(2,2,2)
plt.title("Random Forest Regressor", fontsize=16)
plt.scatter(sample_rf['Actual'], sample_rf['Predict'], c='g')
plt.grid()

# %% [markdown]
# # model extraction

# %%
#Model Extraction
pickle.dump(pipe, open('wcsl_womens_score_prediction_final_model.pkl','wb'))

# %% [markdown]
# # win probability (first innings)

# %%
#load data
first_innings_win_portability_df = pickle.load(open('wcsl_womens_first_innings_win.pkl','rb'))
first_innings_win_portability_df
# Out:
#             batting_team     bowling_team         city  runs_y  \
# 0          Western Storm  Southern Vipers  Southampton      70
# 1          Western Storm  Southern Vipers  Southampton      70
# 2          Western Storm  Southern Vipers  Southampton      70
# 3          Western Storm  Southern Vipers  Southampton      70
# 4          Western Storm  Southern Vipers  Southampton      70
# ...                  ...              ...          ...     ...
# 9876  Yorkshire Diamonds    Western Storm        Leeds     118
# 9877  Yorkshire Diamonds    Western Storm        Leeds     118
# 9878  Yorkshire Diamonds    Western Storm        Leeds     118
# 9879  Yorkshire Diamonds    Western Storm        Leeds     118
# 9880  Yorkshire Diamonds    Western Storm        Leeds     118
#
#       result_first_innings
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 9876                     0
# 9877                     0
# 9878                     0
# 9879                     0
# 9880                     0
#
# [9881 rows x 5 columns]

# %%
first_innings_win_portability_df.to_csv(r'wcsl_womens_first_innings_win.csv', index=False, header=True)
first_innings_win_portability_df = pd.read_csv(r'wcsl_womens_first_innings_win.csv')
first_innings_win_portability_df
# Out:
#             batting_team     bowling_team         city  runs_y  \
# 0          Western Storm  Southern Vipers  Southampton      70
# 1          Western Storm  Southern Vipers  Southampton      70
# 2          Western Storm  Southern Vipers  Southampton      70
# 3          Western Storm  Southern Vipers  Southampton      70
# 4          Western Storm  Southern Vipers  Southampton      70
# ...                  ...              ...          ...     ...
# 9876  Yorkshire Diamonds    Western Storm        Leeds     118
# 9877  Yorkshire Diamonds    Western Storm        Leeds     118
# 9878  Yorkshire Diamonds    Western Storm        Leeds     118
# 9879  Yorkshire Diamonds    Western Storm        Leeds     118
# 9880  Yorkshire Diamonds    Western Storm        Leeds     118
#
#       result_first_innings
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 9876                     0
# 9877                     0
# 9878                     0
# 9879                     0
# 9880                     0
#
# [9881 rows x 5 columns]

# %%
X1 = first_innings_win_portability_df.drop(columns=['result_first_innings'])
y1 = first_innings_win_portability_df['result_first_innings'].values

X1_train,X1_test,y1_train,y1_test = train_test_split(X1, y1, test_size=0.1, random_state=1)

# %%
X1_train
# Out:
#                 batting_team            bowling_team          city  runs_y
# 1883         Southern Vipers           Western Storm      Brighton     145
# 946       Yorkshire Diamonds           Western Storm          York     160
# 1262            Surrey Stars           Western Storm        London     169
# 5733      Yorkshire Diamonds  Loughborough Lightning         Leeds     121
# 1939            Surrey Stars         Southern Vipers     Guildford     141
# ...                      ...                     ...           ...     ...
# 2895  Loughborough Lightning      Yorkshire Diamonds  Loughborough     143
# 7813  Loughborough Lightning         Southern Vipers   Southampton     163
# 905             Surrey Stars         Southern Vipers   Southampton     127
# 5192  Loughborough Lightning           Western Storm  Loughborough     125
# 235       Yorkshire Diamonds      Lancashire Thunder         Leeds     162
#
# [8892 rows x 4 columns]

# %%
trf1 = ColumnTransformer([
    ('trf1', OneHotEncoder(sparse=False, drop='first'),['batting_team', 'bowling_team', 'city'])
]
,remainder='passthrough')

# %%
pipe1 = Pipeline(steps=[
    ('step1',trf1),
    ('step2', LogisticRegression()) #solver='liblinear'
])

pipe1.fit(X1_train, y1_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression())])

# %%
y1_pred = pipe1.predict(X1_test)

print('Accuracy Score: '+str(accuracy_score(y1_test,y1_pred)*100))
# Out:
# Accuracy Score: 90.79878665318503

# %%
confusion_matrix_lr = confusion_matrix(y1_test, y1_pred)
confusion_matrix_lr
# Out:
# array([[486,  51],
#        [ 40, 412]], dtype=int64)

# %%
print(classification_report(y1_test, y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91       537
#            1       0.89      0.91      0.90       452
#
#     accuracy                           0.91       989
#    macro avg       0.91      0.91      0.91       989
# weighted avg       0.91      0.91      0.91       989

# %%
pipe1.predict_proba(X1_test)[4]
# Out:
# array([9.9997928e-01, 2.0720035e-05])

# %%
plt.rcParams["figure.figsize"] = (10, 6) 

ax = sns.heatmap(confusion_matrix_lr/np.sum(confusion_matrix_lr), annot=True, fmt='.2%', cmap='Blues')
# ax.set_title('Logistic Regression\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Lose','Win'])
ax.yaxis.set_ticklabels(['Lose','Win'])
## Display the visualization of the Confusion Matrix.
plt.show()

# %%
input_df = pd.DataFrame({'batting_team': ['Peshawar Zalmi'], 'bowling_team': ['Quetta Gladiators'], 'city': ['Sharjah'], 'runs_y': [190]})
result = pipe1.predict_proba(input_df)

loss = result[0][1]
win = result[0][0]

print('win: '+str(round(win*100))+'%')
print('loss: '+str(round(loss*100))+'%')
# Out:
# win: 42%
# loss: 58%

# %% [markdown]
# # Model Extraction

# %%
#Model Extraction
pickle.dump(pipe1, open('wcsl_1st_innings_win_prediction_final_model.pkl','wb'))

# %% [markdown]
# # win probability (second innings)

# %%
#load data
second_innings_win_portability_df = pickle.load(open('wcsl_womens_second_innings_win.pkl','rb'))
second_innings_win_portability_df
# Out:
#          batting_team        bowling_team         city  current_score  \
# 0     Southern Vipers       Western Storm  Southampton              0
# 1     Southern Vipers       Western Storm  Southampton              0
# 2     Southern Vipers       Western Storm  Southampton              0
# 3     Southern Vipers       Western Storm  Southampton              0
# 4     Southern Vipers       Western Storm  Southampton              0
# ...               ...                 ...          ...            ...
# 8569    Western Storm  Yorkshire Diamonds        Leeds            117
# 8570    Western Storm  Yorkshire Diamonds        Leeds            117
# 8571    Western Storm  Yorkshire Diamonds        Leeds            117
# 8572    Western Storm  Yorkshire Diamonds        Leeds            118
# 8573    Western Storm  Yorkshire Diamonds        Leeds            119
#
#       target_runs  runs_left  balls_left  wickets_left   crr   rrr  result
# 0              71         71         119            10  0.00  3.58       1
# 1              71         71         118            10  0.00  3.61       1
# 2              71         71         117            10  0.00  3.64       1
# 3              71         71         116            10  0.00  3.67       1
# 4              71         71         115            10  0.00  3.70       1
# ...           ...        ...         ...           ...   ...   ...     ...
# 8569          119          2          25             7  7.39  0.48       1
# 8570          119          2          24             7  7.31  0.50       1
# 8571          119          2          23             6  7.24  0.52       1
# 8572          119          1          22             6  7.22  0.27       1
# 8573          119          0          21             6  7.21  0.00       1
#
# [8560 rows x 11 columns]

# %%
second_innings_win_portability_df.to_csv(r'wcsl_womens_second_innings_win.csv', index=False, header=True)
second_innings_win_portability_df = pd.read_csv(r'wcsl_womens_second_innings_win.csv')
second_innings_win_portability_df
# Out:
#          batting_team        bowling_team         city  current_score  \
# 0     Southern Vipers       Western Storm  Southampton              0
# 1     Southern Vipers       Western Storm  Southampton              0
# 2     Southern Vipers       Western Storm  Southampton              0
# 3     Southern Vipers       Western Storm  Southampton              0
# 4     Southern Vipers       Western Storm  Southampton              0
# ...               ...                 ...          ...            ...
# 8555    Western Storm  Yorkshire Diamonds        Leeds            117
# 8556    Western Storm  Yorkshire Diamonds        Leeds            117
# 8557    Western Storm  Yorkshire Diamonds        Leeds            117
# 8558    Western Storm  Yorkshire Diamonds        Leeds            118
# 8559    Western Storm  Yorkshire Diamonds        Leeds            119
#
#       target_runs  runs_left  balls_left  wickets_left   crr   rrr  result
# 0              71         71         119            10  0.00  3.58       1
# 1              71         71         118            10  0.00  3.61       1
# 2              71         71         117            10  0.00  3.64       1
# 3              71         71         116            10  0.00  3.67       1
# 4              71         71         115            10  0.00  3.70       1
# ...           ...        ...         ...           ...   ...   ...     ...
# 8555          119          2          25             7  7.39  0.48       1
# 8556          119          2          24             7  7.31  0.50       1
# 8557          119          2          23             6  7.24  0.52       1
# 8558          119          1          22             6  7.22  0.27       1
# 8559          119          0          21             6  7.21  0.00       1
#
# [8560 rows x 11 columns]

# %%
X2 = second_innings_win_portability_df.drop(columns=['result'])
y2 = second_innings_win_portability_df['result'].values

X2_train,X2_test,y2_train,y2_test = train_test_split(X2, y2, test_size=0.1, random_state=1)

# %%
X2_train
# Out:
#                 batting_team            bowling_team        city  \
# 3465            Surrey Stars         Southern Vipers    Brighton
# 5937      Lancashire Thunder  Loughborough Lightning  Manchester
# 6371      Yorkshire Diamonds         Southern Vipers        York
# 4928  Loughborough Lightning      Yorkshire Diamonds       Leeds
# 6443      Yorkshire Diamonds         Southern Vipers        York
# ...                      ...                     ...         ...
# 2895      Lancashire Thunder            Surrey Stars  Manchester
# 7813           Western Storm            Surrey Stars     Bristol
# 905          Southern Vipers      Lancashire Thunder   Liverpool
# 5192      Lancashire Thunder      Yorkshire Diamonds   Liverpool
# 235            Western Storm  Loughborough Lightning     Taunton
#
#       current_score  target_runs  runs_left  balls_left  wickets_left   crr  \
# 3465             70          148         78          47             8  5.75
# 5937             34          158        124          89            10  6.58
# 6371             28          185        157         101             9  8.84
# 4928             14          122        108         108            10  7.00
# 6443            132          185         53          30             5  8.80
# ...             ...          ...        ...         ...           ...   ...
# 2895             86          168         82          36             6  6.14
# 7813             17          162        145          96             7  4.25
# 905               1           88         87         119            10  6.00
# 5192             68          152         84          54             8  6.18
# 235              46          109         63          64             8  4.93
#
#         rrr
# 3465   9.96
# 5937   8.36
# 6371   9.33
# 4928   6.00
# 6443  10.60
# ...     ...
# 2895  13.67
# 7813   9.06
# 905    4.39
# 5192   9.33
# 235    5.91
#
# [7704 rows x 10 columns]

# %%
trf2 = ColumnTransformer([
    ('trf2', OneHotEncoder(sparse=False, drop='first'),['batting_team', 'bowling_team', 'city'])
]
,remainder='passthrough')

# %%
pipe2 = Pipeline(steps=[
    ('step1',trf2),
    ('step2',LogisticRegression()) #solver='liblinear'
])

pipe2.fit(X2_train,y2_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf2',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression())])

# %%
y2_pred = pipe2.predict(X2_test)
print('Accuracy Score: '+str(accuracy_score(y2_test, y2_pred)*100))
# Out:
# Accuracy Score: 90.42056074766354

# %%
confusion_matrix1 = confusion_matrix(y2_test, y2_pred)
confusion_matrix1
# Out:
# array([[392,  45],
#        [ 37, 382]], dtype=int64)

# %%
print(classification_report(y2_test, y2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91       437
#            1       0.89      0.91      0.90       419
#
#     accuracy                           0.90       856
#    macro avg       0.90      0.90      0.90       856
# weighted avg       0.90      0.90      0.90       856

# %%
pipe2.predict_proba(X2_test)[10]
# Out:
# array([9.99993188e-01, 6.81239343e-06])

# %%
plt.rcParams["figure.figsize"] = (10, 6) 

ax = sns.heatmap(confusion_matrix1/np.sum(confusion_matrix1), annot=True, fmt='.2%', cmap='Blues')
# ax.set_title('Model-1\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Lose','Win'])
ax.yaxis.set_ticklabels(['Lose','Win'])
## Display the visualization of the Confusion Matrix.
plt.show()

# %%
input_df = pd.DataFrame({'batting_team': ['Peshawar Zalmi'], 'bowling_team': ['Quetta Gladiators'], 'city': ['Sharjah'], 'current_score':[159], 'target_runs':[169], 'runs_left':[10], 'balls_left': [2], 'wickets_left':[7], 'crr':[8.08], 'rrr': [30.0]})
result = pipe2.predict_proba(input_df)

loss = result[0][0]
win = result[0][1]

print('win: '+str(round(win*100))+'%')
print('loss: '+str(round(loss*100))+'%')
# Out:
# win: 5%
# loss: 95%

# %% [markdown]
# # Model Extraction

# %%
#Model Extraction
pickle.dump(pipe2, open('wcsl_2nd_innings_win_prediction_final_model.pkl','wb'))
