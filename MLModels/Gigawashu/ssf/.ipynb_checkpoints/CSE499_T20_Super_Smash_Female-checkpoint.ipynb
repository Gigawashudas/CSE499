# %% [markdown]
# # Import Library

# %%
import warnings
warnings.filterwarnings("ignore")

import math
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm
import pickle
import csv

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display_html

# %% [markdown]
# # Data Exploration

# %%
filenames = []
for file in os.listdir('F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssf/data/'):
    filenames.append(os.path.join('F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssf/data/', file))

# %%
filenames[0:5]
# Out:
# ['F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssf/data/1197793.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssf/data/1197794.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssf/data/1197795.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssf/data/1197796.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssf/data/1197797.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
# 100%|██████████| 106/106 [00:26<00:00,  3.98it/s]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Otago', 'deliveries...               0.91
# 0   [{'1st innings': {'team': 'Wellington', 'deliv...               0.91
# 0   [{'1st innings': {'team': 'Central Districts',...               0.91
# 0   [{'1st innings': {'team': 'Northern Districts'...               0.91
# 0   [{'1st innings': {'team': 'Canterbury', 'deliv...               0.91
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Canterbury', 'deliv...               0.92
# 0   [{'1st innings': {'team': 'Auckland', 'deliver...               0.92
# 0   [{'1st innings': {'team': 'Canterbury', 'deliv...               0.92
# 0   [{'1st innings': {'team': 'Otago', 'deliveries...               0.92
# 0   [{'1st innings': {'team': 'Canterbury', 'deliv...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
# 0    2021-01-29              1                    6        Napier
# 0    2021-01-29              1                    6    Wellington
# 0    2021-01-29              1                    6      Auckland
# 0    2021-01-29              1                    6  Christchurch
# 0    2021-01-29              1                    6    Wellington
# ..          ...            ...                  ...           ...
# 0    2023-02-05              1                    6  Christchurch
# 0    2023-02-05              1                    6    Wellington
# 0    2023-02-06              1                    6       Dunedin
# 0    2023-02-09              1                    6       Dunedin
# 0    2023-02-14              1                    6  Christchurch
#
#                         info.competition    info.dates info.gender  \
# 0   New Zealand Cricket Women's Twenty20  [2020-01-02]      female
# 0   New Zealand Cricket Women's Twenty20  [2020-01-03]      female
# 0   New Zealand Cricket Women's Twenty20  [2020-01-04]      female
# 0   New Zealand Cricket Women's Twenty20  [2020-01-05]      female
# 0   New Zealand Cricket Women's Twenty20  [2020-01-09]      female
# ..                                   ...           ...         ...
# 0                    Women's Super Smash  [2023-02-04]      female
# 0                    Women's Super Smash  [2023-02-05]      female
# 0                    Women's Super Smash  [2023-02-06]      female
# 0                    Women's Super Smash  [2023-02-09]      female
# 0                    Women's Super Smash  [2023-02-11]      female
#
#    info.match_type  ... info.registry.people.T Semmens  \
# 0              T20  ...                            NaN
# 0              T20  ...                            NaN
# 0              T20  ...                            NaN
# 0              T20  ...                            NaN
# 0              T20  ...                            NaN
# ..             ...  ...                            ...
# 0              T20  ...                            NaN
# 0              T20  ...                            NaN
# 0              T20  ...                            NaN
# 0              T20  ...                            NaN
# 0              T20  ...                            NaN
#
#     info.registry.people.OA Boivin  info.registry.people.CR Knott  \
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# ..                             ...                            ...
# 0                              NaN                            NaN
# 0                         f5a175e4                       d7ff1adc
# 0                              NaN                            NaN
# 0                              NaN                            NaN
# 0                              NaN                       d7ff1adc
#
#    info.registry.people.L Harris info.registry.people.PA Chatterji  \
# 0                            NaN                               NaN
# 0                            NaN                               NaN
# 0                            NaN                               NaN
# 0                            NaN                               NaN
# 0                            NaN                               NaN
# ..                           ...                               ...
# 0                            NaN                               NaN
# 0                       36e2dc83                               NaN
# 0                            NaN                               NaN
# 0                            NaN                               NaN
# 0                       36e2dc83                               NaN
#
#    info.registry.people.KL Gordon info.registry.people.LCN Smith  \
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# ..                            ...                            ...
# 0                        00823a96                       340202b0
# 0                             NaN                            NaN
# 0                        00823a96                       340202b0
# 0                        00823a96                       340202b0
# 0                             NaN                            NaN
#
#    info.registry.people.AJ Parr-Thomson info.registry.people.KM Chandler  \
# 0                                   NaN                              NaN
# 0                                   NaN                              NaN
# 0                                   NaN                              NaN
# 0                                   NaN                              NaN
# 0                                   NaN                              NaN
# ..                                  ...                              ...
# 0                                   NaN                              NaN
# 0                              6a28ef18                         32221cdb
# 0                                   NaN                              NaN
# 0                                   NaN                              NaN
# 0                                   NaN                         32221cdb
#
#    info.registry.people.AG Hotton
# 0                             NaN
# 0                             NaN
# 0                             NaN
# 0                             NaN
# 0                             NaN
# ..                            ...
# 0                             NaN
# 0                             NaN
# 0                             NaN
# 0                        32c6f715
# 0                        32c6f715
#
# [106 rows x 210 columns]

# %% [markdown]
# # data store

# %%
#data store as pickle file
pickle.dump(final_df, open('cse499_ssf_female.pkl','wb'))

# %% [markdown]
# # data load

# %%
final_df = pickle.load(open('cse499_ssf_female.pkl','rb'))
final_df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Otago', 'deliveries...               0.91
# 0  [{'1st innings': {'team': 'Wellington', 'deliv...               0.91
# 0  [{'1st innings': {'team': 'Central Districts',...               0.91
# 0  [{'1st innings': {'team': 'Northern Districts'...               0.91
# 0  [{'1st innings': {'team': 'Canterbury', 'deliv...               0.91
#
#   meta.created  meta.revision  info.balls_per_over     info.city  \
# 0   2021-01-29              1                    6        Napier
# 0   2021-01-29              1                    6    Wellington
# 0   2021-01-29              1                    6      Auckland
# 0   2021-01-29              1                    6  Christchurch
# 0   2021-01-29              1                    6    Wellington
#
#                        info.competition    info.dates info.gender  \
# 0  New Zealand Cricket Women's Twenty20  [2020-01-02]      female
# 0  New Zealand Cricket Women's Twenty20  [2020-01-03]      female
# 0  New Zealand Cricket Women's Twenty20  [2020-01-04]      female
# 0  New Zealand Cricket Women's Twenty20  [2020-01-05]      female
# 0  New Zealand Cricket Women's Twenty20  [2020-01-09]      female
#
#   info.match_type  ... info.registry.people.T Semmens  \
# 0             T20  ...                            NaN
# 0             T20  ...                            NaN
# 0             T20  ...                            NaN
# 0             T20  ...                            NaN
# 0             T20  ...                            NaN
#
#    info.registry.people.OA Boivin  info.registry.people.CR Knott  \
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
#
#   info.registry.people.L Harris info.registry.people.PA Chatterji  \
# 0                           NaN                               NaN
# 0                           NaN                               NaN
# 0                           NaN                               NaN
# 0                           NaN                               NaN
# 0                           NaN                               NaN
#
#   info.registry.people.KL Gordon info.registry.people.LCN Smith  \
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
#
#   info.registry.people.AJ Parr-Thomson info.registry.people.KM Chandler  \
# 0                                  NaN                              NaN
# 0                                  NaN                              NaN
# 0                                  NaN                              NaN
# 0                                  NaN                              NaN
# 0                                  NaN                              NaN
#
#   info.registry.people.AG Hotton
# 0                            NaN
# 0                            NaN
# 0                            NaN
# 0                            NaN
# 0                            NaN
#
# [5 rows x 210 columns]

# %% [markdown]
# # Data Pre-Processing and Analysis

# %%
final_df = final_df[[
    'match_id',
    'innings',
    'info.dates',
    'info.gender',
    'info.match_type',
    'info.teams',
    'info.toss.winner',
    'info.toss.decision',
    'info.outcome.winner',
    'info.outcome.by.runs',
    'info.outcome.by.wickets',
    'info.overs',
    'info.umpires',
    'info.venue',
    'info.city'
]]

final_df.head()
# Out:
#    match_id                                            innings    info.dates  \
# 0         1  [{'1st innings': {'team': 'Otago', 'deliveries...  [2020-01-02]
# 0         2  [{'1st innings': {'team': 'Wellington', 'deliv...  [2020-01-03]
# 0         3  [{'1st innings': {'team': 'Central Districts',...  [2020-01-04]
# 0         4  [{'1st innings': {'team': 'Northern Districts'...  [2020-01-05]
# 0         5  [{'1st innings': {'team': 'Canterbury', 'deliv...  [2020-01-09]
#
#   info.gender info.match_type                        info.teams  \
# 0      female             T20        [Otago, Central Districts]
# 0      female             T20  [Wellington, Northern Districts]
# 0      female             T20     [Central Districts, Auckland]
# 0      female             T20  [Northern Districts, Canterbury]
# 0      female             T20          [Canterbury, Wellington]
#
#     info.toss.winner info.toss.decision info.outcome.winner  \
# 0              Otago                bat               Otago
# 0         Wellington                bat          Wellington
# 0  Central Districts                bat   Central Districts
# 0         Canterbury              field          Canterbury
# 0         Canterbury                bat          Wellington
#
#    info.outcome.by.runs  info.outcome.by.wickets  info.overs  \
# 0                  72.0                      NaN          20
# 0                  57.0                      NaN          20
# 0                  14.0                      NaN          20
# 0                   NaN                      4.0          20
# 0                   NaN                      8.0          20
#
#                    info.umpires            info.venue     info.city
# 0       [C Black, Glen Walklin]           McLean Park        Napier
# 0      [GA Stirrat, Kim Cotton]         Basin Reserve    Wellington
# 0   [Damian Morrow, ED Sanders]  Eden Park Outer Oval      Auckland
# 0  [KS Jagannathan, Kim Cotton]           Hagley Oval  Christchurch
# 0       [C Black, Glen Walklin]         Basin Reserve    Wellington

# %%
final_df['info.gender'].value_counts()
# Out:
# female    106
# Name: info.gender, dtype: int64

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    106
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    106
# Name: info.overs, dtype: int64

# %%
# Remove 50 over match data
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df.shape
# Out:
# (106, 13)

# %% [markdown]
# # extract first & second innings data

# %%
# No Result Matches
final_df[final_df['info.outcome.winner'].isnull()]
# Out:
#    match_id                                            innings    info.dates  \
# 0        21  [{'1st innings': {'team': 'Canterbury', 'deliv...  [2021-01-03]
# 0        89  [{'1st innings': {'team': 'Northern Districts'...  [2023-01-06]
#
#   info.gender                   info.teams info.toss.winner  \
# 0      female       [Canterbury, Auckland]         Auckland
# 0      female  [Northern Districts, Otago]            Otago
#
#   info.toss.decision info.outcome.winner  info.outcome.by.runs  \
# 0              field                 NaN                   NaN
# 0              field                 NaN                   NaN
#
#    info.outcome.by.wickets              info.umpires             info.venue  \
# 0                      NaN  [A Stanley, JAK Bromley]   Eden Park Outer Oval
# 0                      NaN        [CM Brown, C High]  Seddon Park, Hamilton
#
#   info.city
# 0  Auckland
# 0  Hamilton

# %% [markdown]
# # remove no result matches

# %%
final_df = final_df.dropna(subset=['info.outcome.winner'])
final_df.shape
# Out:
# (104, 13)

# %%
final_df.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'SW Bates',
#    'batsman': 'MR Cowan'}},
#  {0.2: {'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'SW Bates',
#    'batsman': 'MR Cowan'}},
#  {0.3: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates'}},
#  {0.4: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'SW Bates'}},
#  {0.5: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates'}},
#  {0.6: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates'}},
#  {1.1: {'non_striker': 'SW Bates',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'MR Cowan'}},
#  {1.2: {'non_striker': 'SW Bates',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {1.3: {'non_striker': 'SW Bates',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {1.4: {'non_striker': 'SW Bates',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {1.5: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates'}},
#  {1.6: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SW Bates'}},
#  {2.1: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'SW Bates'}},
#  {2.2: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates'}},
#  {2.3: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'SW Bates'}},
#  {2.4: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SW Bates'}},
#  {2.5: {'non_striker': 'SW Bates',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {2.6: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'SW Bates'}},
#  {3.1: {'non_striker': 'SW Bates',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {3.2: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates'}},
#  {3.3: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates'}},
#  {3.4: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates'}},
#  {3.5: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'SW Bates'}},
#  {3.6: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SW Bates'}},
#  {4.1: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'SW Bates'}},
#  {4.2: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SW Bates'}},
#  {4.3: {'non_striker': 'SW Bates',
#    'bowler': 'CL Green',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'MR Cowan'}},
#  {4.4: {'non_striker': 'SW Bates',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {4.5: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SW Bates'}},
#  {4.6: {'non_striker': 'SW Bates',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {4.7: {'non_striker': 'SW Bates',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'MR Cowan'}},
#  {5.1: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SW Bates',
#    'wicket': {'player_out': 'SW Bates', 'kind': 'bowled'}}},
#  {5.2: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {5.3: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {5.4: {'non_striker': 'HNK Jensen',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {5.5: {'non_striker': 'HNK Jensen',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {5.6: {'non_striker': 'HNK Jensen',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'MR Cowan'}},
#  {6.1: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'HNK Jensen'}},
#  {6.2: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {6.3: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {6.4: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {6.5: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {6.6: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {6.7: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {7.1: {'non_striker': 'HNK Jensen',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {7.2: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {7.3: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {7.4: {'non_striker': 'HNK Jensen',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {7.5: {'non_striker': 'HNK Jensen',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {7.6: {'non_striker': 'HNK Jensen',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {8.1: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {8.2: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {8.3: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {8.4: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {8.5: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {8.6: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {9.1: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {9.2: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {9.3: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {9.4: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {9.5: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'HNK Jensen'}},
#  {9.6: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {10.1: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'MR Cowan'}},
#  {10.2: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {10.3: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {10.4: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {10.5: {'non_striker': 'HNK Jensen',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {10.6: {'non_striker': 'MR Cowan',
#    'bowler': 'CL Green',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {11.1: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {11.2: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {11.3: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'HNK Jensen'}},
#  {11.4: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {11.5: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'MR Cowan'}},
#  {11.6: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {11.7: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {12.1: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Hansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {12.2: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Hansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {12.3: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Hansen',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'HNK Jensen'}},
#  {12.4: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Hansen',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {12.5: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Hansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {12.6: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Hansen',
#    'runs': {'extras': 2, 'total': 2, 'batsman': 0},
#    'extras': {'byes': 1, 'noballs': 1},
#    'batsman': 'MR Cowan'}},
#  {12.7: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Hansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {13.1: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'MR Cowan'}},
#  {13.2: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {13.3: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {13.4: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {13.5: {'non_striker': 'MR Cowan',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'HNK Jensen'}},
#  {13.6: {'non_striker': 'HNK Jensen',
#    'bowler': 'MJ Greig',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'MR Cowan'}},
#  {14.1: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'HNK Jensen'}},
#  {14.2: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {14.3: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {14.4: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {14.5: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'HNK Jensen'}},
#  {14.6: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {14.7: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {15.1: {'non_striker': 'HNK Jensen',
#    'bowler': 'MS Rees',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {15.2: {'non_striker': 'MR Cowan',
#    'bowler': 'MS Rees',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen'}},
#  {15.3: {'non_striker': 'MR Cowan',
#    'bowler': 'MS Rees',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {15.4: {'non_striker': 'MR Cowan',
#    'bowler': 'MS Rees',
#    'runs': {'extras': 2, 'total': 2, 'batsman': 0},
#    'extras': {'wides': 2},
#    'batsman': 'HNK Jensen'}},
#  {15.5: {'non_striker': 'HNK Jensen',
#    'bowler': 'MS Rees',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {15.6: {'non_striker': 'MR Cowan',
#    'bowler': 'MS Rees',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {15.7: {'non_striker': 'MR Cowan',
#    'bowler': 'MS Rees',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {16.1: {'non_striker': 'HNK Jensen',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {16.2: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'HNK Jensen'}},
#  {16.3: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'HNK Jensen',
#    'wicket': {'player_out': 'HNK Jensen', 'kind': 'bowled'}}},
#  {16.4: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'KJ Martin'}},
#  {16.5: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'KJ Martin'}},
#  {16.6: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'KJ Martin'}},
#  {17.1: {'non_striker': 'KJ Martin',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'MR Cowan'}},
#  {17.2: {'non_striker': 'KJ Martin',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'MR Cowan'}},
#  {17.3: {'non_striker': 'KJ Martin',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'MR Cowan'}},
#  {17.4: {'non_striker': 'KJ Martin',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {17.5: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'KJ Martin'}},
#  {17.6: {'non_striker': 'MR Cowan',
#    'bowler': 'JM Watkin',
#    'runs': {'extras': 0, 'total': 3, 'batsman': 3},
#    'batsman': 'KJ Martin'}},
#  {18.1: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'KJ Martin'}},
#  {18.2: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'KJ Martin',
#    'wicket': {'player_out': 'KJ Martin',
#     'fielders': ['NC Dodd'],
#     'kind': 'caught'}}},
#  {18.3: {'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'A Wellington',
#    'batsman': 'MR Cowan'}},
#  {18.4: {'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'A Wellington',
#    'batsman': 'MR Cowan'}},
#  {18.5: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'A Wellington'}},
#  {18.6: {'non_striker': 'MR Cowan',
#    'bowler': 'HM Rowe',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'A Wellington'}},
#  {19.1: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'A Wellington'}},
#  {19.2: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 3, 'batsman': 3},
#    'batsman': 'A Wellington'}},
#  {19.3: {'non_striker': 'A Wellington',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'MR Cowan'}},
#  {19.4: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'A Wellington'}},
#  {19.5: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'A Wellington'}},
#  {19.6: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 1, 'total': 5, 'batsman': 4},
#    'extras': {'noballs': 1},
#    'batsman': 'A Wellington'}},
#  {19.7: {'non_striker': 'MR Cowan',
#    'bowler': 'RA Mair',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'A Wellington'}}]

# %%
count = 0
delivery_df_1st_innings = pd.DataFrame()
for index, row in final_df.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    winner = []
    win_by_runs = []
    win_by_wickets = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            winner.append(row['info.outcome.winner'])
            win_by_runs.append(row['info.outcome.by.runs'])
            win_by_wickets.append(row['info.outcome.by.wickets'])
            ball_of_match.append(key)
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'winner':winner,
            'win_by_runs':win_by_runs,
            'win_by_wickets':win_by_wickets,
            'ball':ball_of_match,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df_1st_innings = delivery_df_1st_innings.append(loop_df)

# %%
delivery_df_1st_innings.head()
# Out:
#    match_id                       teams batting_team winner  win_by_runs  \
# 0         1  [Otago, Central Districts]        Otago  Otago         72.0
# 1         1  [Otago, Central Districts]        Otago  Otago         72.0
# 2         1  [Otago, Central Districts]        Otago  Otago         72.0
# 3         1  [Otago, Central Districts]        Otago  Otago         72.0
# 4         1  [Otago, Central Districts]        Otago  Otago         72.0
#
#    win_by_wickets  ball  runs player_dismissed    city        venue
# 0             NaN   0.1     0                0  Napier  McLean Park
# 1             NaN   0.2     1                0  Napier  McLean Park
# 2             NaN   0.3     0                0  Napier  McLean Park
# 3             NaN   0.4     4                0  Napier  McLean Park
# 4             NaN   0.5     0                0  Napier  McLean Park

# %%
count = 0
delivery_df_2nd_innings = pd.DataFrame()
for index, row in final_df.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    winner = []
    win_by_runs = []
    win_by_wickets = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][1]['2nd innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][1]['2nd innings']['team'])
            teams.append(row['info.teams'])
            winner.append(row['info.outcome.winner'])
            win_by_runs.append(row['info.outcome.by.runs'])
            win_by_wickets.append(row['info.outcome.by.wickets'])
            ball_of_match.append(key)
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'winner':winner,
            'win_by_runs':win_by_runs,
            'win_by_wickets':win_by_wickets,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df_2nd_innings = delivery_df_2nd_innings.append(loop_df)

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id                       teams winner  win_by_runs  win_by_wickets  \
# 0         1  [Otago, Central Districts]  Otago         72.0             NaN
# 1         1  [Otago, Central Districts]  Otago         72.0             NaN
# 2         1  [Otago, Central Districts]  Otago         72.0             NaN
# 3         1  [Otago, Central Districts]  Otago         72.0             NaN
# 4         1  [Otago, Central Districts]  Otago         72.0             NaN
#
#         batting_team  ball  runs player_dismissed    city        venue
# 0  Central Districts   0.1     4                0  Napier  McLean Park
# 1  Central Districts   0.2     1                0  Napier  McLean Park
# 2  Central Districts   0.3     0                0  Napier  McLean Park
# 3  Central Districts   0.4     0                0  Napier  McLean Park
# 4  Central Districts   0.5     0                0  Napier  McLean Park

# %%
run_data = delivery_df_1st_innings.groupby(['match_id', 'runs'])['runs'].count().reset_index(name="count")

# %%
run_data.head()
# Out:
#    match_id  runs  count
# 0         1     0     48
# 1         1     1     40
# 2         1     2      9
# 3         1     3      2
# 4         1     4     25

# %% [markdown]
# # batting and bowling team separation

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
# First Innings
delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings.apply(bowl,axis=1)

delivery_df_1st_innings.head()
# Out:
#    match_id                       teams batting_team winner  win_by_runs  \
# 0         1  [Otago, Central Districts]        Otago  Otago         72.0
# 1         1  [Otago, Central Districts]        Otago  Otago         72.0
# 2         1  [Otago, Central Districts]        Otago  Otago         72.0
# 3         1  [Otago, Central Districts]        Otago  Otago         72.0
# 4         1  [Otago, Central Districts]        Otago  Otago         72.0
#
#    win_by_wickets  ball  runs player_dismissed    city        venue  \
# 0             NaN   0.1     0                0  Napier  McLean Park
# 1             NaN   0.2     1                0  Napier  McLean Park
# 2             NaN   0.3     0                0  Napier  McLean Park
# 3             NaN   0.4     4                0  Napier  McLean Park
# 4             NaN   0.5     0                0  Napier  McLean Park
#
#         bowling_team
# 0  Central Districts
# 1  Central Districts
# 2  Central Districts
# 3  Central Districts
# 4  Central Districts

# %%
# Second Innings 
delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings.apply(bowl,axis=1)

delivery_df_2nd_innings.head()
# Out:
#    match_id                       teams winner  win_by_runs  win_by_wickets  \
# 0         1  [Otago, Central Districts]  Otago         72.0             NaN
# 1         1  [Otago, Central Districts]  Otago         72.0             NaN
# 2         1  [Otago, Central Districts]  Otago         72.0             NaN
# 3         1  [Otago, Central Districts]  Otago         72.0             NaN
# 4         1  [Otago, Central Districts]  Otago         72.0             NaN
#
#         batting_team  ball  runs player_dismissed    city        venue  \
# 0  Central Districts   0.1     4                0  Napier  McLean Park
# 1  Central Districts   0.2     1                0  Napier  McLean Park
# 2  Central Districts   0.3     0                0  Napier  McLean Park
# 3  Central Districts   0.4     0                0  Napier  McLean Park
# 4  Central Districts   0.5     0                0  Napier  McLean Park
#
#   bowling_team
# 0        Otago
# 1        Otago
# 2        Otago
# 3        Otago
# 4        Otago

# %%
# Drop columns
delivery_df_1st_innings.drop(columns=['teams'],inplace=True)
delivery_df_2nd_innings.drop(columns=['teams'],inplace=True)

# %%
delivery_df_1st_innings['batting_team'].unique()
# Out:
# array(['Otago', 'Wellington', 'Central Districts', 'Northern Districts',
#        'Canterbury', 'Auckland'], dtype=object)

# %%
# First Innings
# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Thunder','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Thunder','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Royals','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Royals','Sylhet Strikers')

# Second Innings
# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Thunder','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Thunder','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Royals','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Royals','Sylhet Strikers')

# %%
delivery_df_2nd_innings['batting_team'].unique()
# Out:
# array(['Central Districts', 'Northern Districts', 'Auckland',
#        'Canterbury', 'Wellington', 'Otago'], dtype=object)

# %% [markdown]
# # venue and city

# %%
delivery_df_2nd_innings.isnull().sum()
# Out:
# match_id               0
# winner                 0
# win_by_runs         4823
# win_by_wickets      6496
# batting_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                   0
# venue                  0
# bowling_team           0
# dtype: int64

# %%
delivery_df_1st_innings['venue'].unique()
# Out:
# array(['McLean Park', 'Basin Reserve', 'Eden Park Outer Oval',
#        'Hagley Oval', 'University Oval', 'Bay Oval', 'Molyneux Park',
#        'Pukekura Park', 'Seddon Park', 'Hagley Oval, Christchurch',
#        'Eden Park Outer Oval, Auckland', 'University Oval, Dunedin',
#        'Seddon Park, Hamilton', 'Basin Reserve, Wellington',
#        'McLean Park, Napier', 'Bay Oval, Mount Maunganui',
#        'Fitzherbert Park, Palmerston North',
#        'John Davies Oval, Queenstown', 'Pukekura Park, New Plymouth',
#        'Eden Park, Auckland', 'Cobham Oval (New), Whangarei',
#        'Saxton Oval, Nelson'], dtype=object)

# %%
delivery_df_1st_innings['city'].unique()
# Out:
# array(['Napier', 'Wellington', 'Auckland', 'Christchurch', 'Dunedin',
#        'Mount Maunganui', 'Alexandra', 'New Plymouth', 'Hamilton',
#        'Palmerston North', 'Queenstown', 'Whangarei', 'Nelson'],
#       dtype=object)

# %%
delivery_df_2nd_innings[delivery_df_2nd_innings['city'].isnull()]['venue'].value_counts()
# Out:
# Series([], Name: venue, dtype: int64)

# %%
# First Innings
# cities = np.where(delivery_df_1st_innings['city'].isnull(), delivery_df_1st_innings['venue'].str.split().apply(lambda x:x[0]), delivery_df_1st_innings['city'])
# delivery_df_1st_innings['city'] = cities

# Second Innings
# cities = np.where(delivery_df_2nd_innings['city'].isnull(), delivery_df_2nd_innings['venue'].str.split().apply(lambda x:x[0]), delivery_df_2nd_innings['city'])
# delivery_df_2nd_innings['city'] = cities

# %%
# Drop Venue Column

# First Innings
delivery_df_1st_innings.drop(columns=['venue'],inplace=True)
# Second Innings
delivery_df_2nd_innings.drop(columns=['venue'],inplace=True)

# %%
delivery_df_1st_innings['city'].value_counts()
# Out:
# Wellington          2358
# Christchurch        2244
# Auckland            2137
# Dunedin             1437
# New Plymouth        1051
# Hamilton             709
# Mount Maunganui      708
# Queenstown           505
# Napier               489
# Alexandra            256
# Palmerston North     248
# Nelson               125
# Whangarei             98
# Name: city, dtype: int64

# %%
delivery_df_2nd_innings['city'].value_counts()
# Out:
# Christchurch        2119
# Wellington          2049
# Auckland            1957
# Dunedin             1314
# New Plymouth         987
# Mount Maunganui      698
# Hamilton             676
# Queenstown           481
# Napier               415
# Palmerston North     245
# Alexandra            224
# Nelson               115
# Whangarei             39
# Name: city, dtype: int64

# %%
# Keeping only those venues where played atleast 5 matches

# First Innings
eligible_cities = delivery_df_1st_innings['city'].value_counts()[delivery_df_1st_innings['city'].value_counts() > 300].index.tolist()
delivery_df_1st_innings = delivery_df_1st_innings[delivery_df_1st_innings['city'].isin(eligible_cities)]

# Second Innings
eligible_cities = delivery_df_2nd_innings['city'].value_counts()[delivery_df_2nd_innings['city'].value_counts() > 300].index.tolist()
delivery_df_2nd_innings = delivery_df_2nd_innings[delivery_df_2nd_innings['city'].isin(eligible_cities)]

# %%
delivery_df_1st_innings['city'].unique()
# Out:
# array(['Napier', 'Wellington', 'Auckland', 'Christchurch', 'Dunedin',
#        'Mount Maunganui', 'New Plymouth', 'Hamilton', 'Queenstown'],
#       dtype=object)

# %% [markdown]
# # current score

# %%
# First Innings
delivery_df_1st_innings['current_score'] = delivery_df_1st_innings.groupby('match_id').cumsum()['runs']

# Second Innings
delivery_df_2nd_innings['current_score'] = delivery_df_2nd_innings.groupby('match_id').cumsum()['runs']

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id winner  win_by_runs  win_by_wickets       batting_team  ball  \
# 0         1  Otago         72.0             NaN  Central Districts   0.1
# 1         1  Otago         72.0             NaN  Central Districts   0.2
# 2         1  Otago         72.0             NaN  Central Districts   0.3
# 3         1  Otago         72.0             NaN  Central Districts   0.4
# 4         1  Otago         72.0             NaN  Central Districts   0.5
#
#    runs player_dismissed    city bowling_team  current_score
# 0     4                0  Napier        Otago              4
# 1     1                0  Napier        Otago              5
# 2     0                0  Napier        Otago              5
# 3     0                0  Napier        Otago              5
# 4     0                0  Napier        Otago              5

# %% [markdown]
# # wicket left

# %%
# First Innings
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings['player_dismissed'].astype('int')
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings.groupby('match_id').cumsum()['player_dismissed']
delivery_df_1st_innings['wickets_left'] = 10 - delivery_df_1st_innings['player_dismissed']

delivery_df_1st_innings.head()
# Out:
#    match_id batting_team winner  win_by_runs  win_by_wickets  ball  runs  \
# 0         1        Otago  Otago         72.0             NaN   0.1     0
# 1         1        Otago  Otago         72.0             NaN   0.2     1
# 2         1        Otago  Otago         72.0             NaN   0.3     0
# 3         1        Otago  Otago         72.0             NaN   0.4     4
# 4         1        Otago  Otago         72.0             NaN   0.5     0
#
#    player_dismissed    city       bowling_team  current_score  wickets_left
# 0                 0  Napier  Central Districts              0            10
# 1                 0  Napier  Central Districts              1            10
# 2                 0  Napier  Central Districts              1            10
# 3                 0  Napier  Central Districts              5            10
# 4                 0  Napier  Central Districts              5            10

# %%
# Second Innings
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings['player_dismissed'].astype('int')
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings.groupby('match_id').cumsum()['player_dismissed']
delivery_df_2nd_innings['wickets_left'] = 10 - delivery_df_2nd_innings['player_dismissed']

delivery_df_2nd_innings.head()
# Out:
#    match_id winner  win_by_runs  win_by_wickets       batting_team  ball  \
# 0         1  Otago         72.0             NaN  Central Districts   0.1
# 1         1  Otago         72.0             NaN  Central Districts   0.2
# 2         1  Otago         72.0             NaN  Central Districts   0.3
# 3         1  Otago         72.0             NaN  Central Districts   0.4
# 4         1  Otago         72.0             NaN  Central Districts   0.5
#
#    runs  player_dismissed    city bowling_team  current_score  wickets_left
# 0     4                 0  Napier        Otago              4            10
# 1     1                 0  Napier        Otago              5            10
# 2     0                 0  Napier        Otago              5            10
# 3     0                 0  Napier        Otago              5            10
# 4     0                 0  Napier        Otago              5            10

# %% [markdown]
# # bowl delivered & bowl left

# %%
# First Innings
delivery_df_1st_innings['over'] = delivery_df_1st_innings['ball'].apply(lambda x:str(x).split(".")[0])
delivery_df_1st_innings['ball_no'] = delivery_df_1st_innings['ball'].apply(lambda x:str(x).split(".")[1])
delivery_df_1st_innings['balls_bowled'] = (delivery_df_1st_innings['over'].astype('int')*6) + delivery_df_1st_innings['ball_no'].astype('int')
delivery_df_1st_innings['balls_left'] = 120 - delivery_df_1st_innings['balls_bowled']
delivery_df_1st_innings['balls_left'] = delivery_df_1st_innings['balls_left'].apply(lambda x:0 if x<0 else x)

delivery_df_1st_innings.head()
# Out:
#    match_id batting_team winner  win_by_runs  win_by_wickets  ball  runs  \
# 0         1        Otago  Otago         72.0             NaN   0.1     0
# 1         1        Otago  Otago         72.0             NaN   0.2     1
# 2         1        Otago  Otago         72.0             NaN   0.3     0
# 3         1        Otago  Otago         72.0             NaN   0.4     4
# 4         1        Otago  Otago         72.0             NaN   0.5     0
#
#    player_dismissed    city       bowling_team  current_score  wickets_left  \
# 0                 0  Napier  Central Districts              0            10
# 1                 0  Napier  Central Districts              1            10
# 2                 0  Napier  Central Districts              1            10
# 3                 0  Napier  Central Districts              5            10
# 4                 0  Napier  Central Districts              5            10
#
#   over ball_no  balls_bowled  balls_left
# 0    0       1             1         119
# 1    0       2             2         118
# 2    0       3             3         117
# 3    0       4             4         116
# 4    0       5             5         115

# %%
# Second Innings
delivery_df_2nd_innings['over'] = delivery_df_2nd_innings['ball'].apply(lambda x:str(x).split(".")[0])
delivery_df_2nd_innings['ball_no'] = delivery_df_2nd_innings['ball'].apply(lambda x:str(x).split(".")[1])
delivery_df_2nd_innings['balls_bowled'] = (delivery_df_2nd_innings['over'].astype('int')*6) + delivery_df_2nd_innings['ball_no'].astype('int')
delivery_df_2nd_innings['balls_left'] = 120 - delivery_df_2nd_innings['balls_bowled']
delivery_df_2nd_innings['balls_left'] = delivery_df_2nd_innings['balls_left'].apply(lambda x:0 if x<0 else x)

delivery_df_2nd_innings.head()
# Out:
#    match_id winner  win_by_runs  win_by_wickets       batting_team  ball  \
# 0         1  Otago         72.0             NaN  Central Districts   0.1
# 1         1  Otago         72.0             NaN  Central Districts   0.2
# 2         1  Otago         72.0             NaN  Central Districts   0.3
# 3         1  Otago         72.0             NaN  Central Districts   0.4
# 4         1  Otago         72.0             NaN  Central Districts   0.5
#
#    runs  player_dismissed    city bowling_team  current_score  wickets_left  \
# 0     4                 0  Napier        Otago              4            10
# 1     1                 0  Napier        Otago              5            10
# 2     0                 0  Napier        Otago              5            10
# 3     0                 0  Napier        Otago              5            10
# 4     0                 0  Napier        Otago              5            10
#
#   over ball_no  balls_bowled  balls_left
# 0    0       1             1         119
# 1    0       2             2         118
# 2    0       3             3         117
# 3    0       4             4         116
# 4    0       5             5         115

# %% [markdown]
# # current run rate

# %%
# First Innings
delivery_df_1st_innings['crr'] = round((delivery_df_1st_innings['current_score']*6)/delivery_df_1st_innings['balls_bowled'], 2)

# Second Innings
delivery_df_2nd_innings['crr'] = round((delivery_df_2nd_innings['current_score']*6)/delivery_df_2nd_innings['balls_bowled'], 2)

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id winner  win_by_runs  win_by_wickets       batting_team  ball  \
# 0         1  Otago         72.0             NaN  Central Districts   0.1
# 1         1  Otago         72.0             NaN  Central Districts   0.2
# 2         1  Otago         72.0             NaN  Central Districts   0.3
# 3         1  Otago         72.0             NaN  Central Districts   0.4
# 4         1  Otago         72.0             NaN  Central Districts   0.5
#
#    runs  player_dismissed    city bowling_team  current_score  wickets_left  \
# 0     4                 0  Napier        Otago              4            10
# 1     1                 0  Napier        Otago              5            10
# 2     0                 0  Napier        Otago              5            10
# 3     0                 0  Napier        Otago              5            10
# 4     0                 0  Napier        Otago              5            10
#
#   over ball_no  balls_bowled  balls_left   crr
# 0    0       1             1         119  24.0
# 1    0       2             2         118  15.0
# 2    0       3             3         117  10.0
# 3    0       4             4         116   7.5
# 4    0       5             5         115   6.0

# %% [markdown]
# # Score and Win Probabilty (before the start of the match and during the first innings)

# %% [markdown]
# # total score counting according to match

# %%
total_df = delivery_df_1st_innings.groupby('match_id').sum()['runs'].reset_index()
score_probability_output = delivery_df_1st_innings.merge(total_df,on='match_id')

score_probability_output.head()
# Out:
#    match_id batting_team winner  win_by_runs  win_by_wickets  ball  runs_x  \
# 0         1        Otago  Otago         72.0             NaN   0.1       0
# 1         1        Otago  Otago         72.0             NaN   0.2       1
# 2         1        Otago  Otago         72.0             NaN   0.3       0
# 3         1        Otago  Otago         72.0             NaN   0.4       4
# 4         1        Otago  Otago         72.0             NaN   0.5       0
#
#    player_dismissed    city       bowling_team  current_score  wickets_left  \
# 0                 0  Napier  Central Districts              0            10
# 1                 0  Napier  Central Districts              1            10
# 2                 0  Napier  Central Districts              1            10
# 3                 0  Napier  Central Districts              5            10
# 4                 0  Napier  Central Districts              5            10
#
#   over ball_no  balls_bowled  balls_left  crr  runs_y
# 0    0       1             1         119  0.0     181
# 1    0       2             2         118  3.0     181
# 2    0       3             3         117  2.0     181
# 3    0       4             4         116  7.5     181
# 4    0       5             5         115  6.0     181

# %% [markdown]
# # counting runs in remaining balls

# %%
score_probability_output['runs_in_remaining_ball'] = score_probability_output['runs_y'] - score_probability_output['current_score']

score_probability_output.head()
# Out:
#    match_id batting_team winner  win_by_runs  win_by_wickets  ball  runs_x  \
# 0         1        Otago  Otago         72.0             NaN   0.1       0
# 1         1        Otago  Otago         72.0             NaN   0.2       1
# 2         1        Otago  Otago         72.0             NaN   0.3       0
# 3         1        Otago  Otago         72.0             NaN   0.4       4
# 4         1        Otago  Otago         72.0             NaN   0.5       0
#
#    player_dismissed    city       bowling_team  current_score  wickets_left  \
# 0                 0  Napier  Central Districts              0            10
# 1                 0  Napier  Central Districts              1            10
# 2                 0  Napier  Central Districts              1            10
# 3                 0  Napier  Central Districts              5            10
# 4                 0  Napier  Central Districts              5            10
#
#   over ball_no  balls_bowled  balls_left  crr  runs_y  runs_in_remaining_ball
# 0    0       1             1         119  0.0     181                     181
# 1    0       2             2         118  3.0     181                     180
# 2    0       3             3         117  2.0     181                     180
# 3    0       4             4         116  7.5     181                     176
# 4    0       5             5         115  6.0     181                     176

# %% [markdown]
# # consider batting team win

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

score_probability_output['result_first_innings'] = score_probability_output.apply(result, axis=1)

score_probability_output.head()
# Out:
#    match_id batting_team winner  win_by_runs  win_by_wickets  ball  runs_x  \
# 0         1        Otago  Otago         72.0             NaN   0.1       0
# 1         1        Otago  Otago         72.0             NaN   0.2       1
# 2         1        Otago  Otago         72.0             NaN   0.3       0
# 3         1        Otago  Otago         72.0             NaN   0.4       4
# 4         1        Otago  Otago         72.0             NaN   0.5       0
#
#    player_dismissed    city       bowling_team  current_score  wickets_left  \
# 0                 0  Napier  Central Districts              0            10
# 1                 0  Napier  Central Districts              1            10
# 2                 0  Napier  Central Districts              1            10
# 3                 0  Napier  Central Districts              5            10
# 4                 0  Napier  Central Districts              5            10
#
#   over ball_no  balls_bowled  balls_left  crr  runs_y  runs_in_remaining_ball  \
# 0    0       1             1         119  0.0     181                     181
# 1    0       2             2         118  3.0     181                     180
# 2    0       3             3         117  2.0     181                     180
# 3    0       4             4         116  7.5     181                     176
# 4    0       5             5         115  6.0     181                     176
#
#    result_first_innings
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %% [markdown]
# # final data for score probabilty

# %%
final_score_probability_df = score_probability_output[['batting_team','bowling_team','city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left','crr', 'runs_in_remaining_ball']]
final_score_probability_df.head()
# Out:
#   batting_team       bowling_team    city  current_score  balls_bowled  \
# 0        Otago  Central Districts  Napier              0             1
# 1        Otago  Central Districts  Napier              1             2
# 2        Otago  Central Districts  Napier              1             3
# 3        Otago  Central Districts  Napier              5             4
# 4        Otago  Central Districts  Napier              5             5
#
#    balls_left  wickets_left  crr  runs_in_remaining_ball
# 0         119            10  0.0                     181
# 1         118            10  3.0                     180
# 2         117            10  2.0                     180
# 3         116            10  7.5                     176
# 4         115            10  6.0                     176

# %%
final_score_probability_df = final_score_probability_df[final_score_probability_df['balls_left'] != 0]
final_score_probability_df
# Out:
#       batting_team       bowling_team          city  current_score  \
# 0            Otago  Central Districts        Napier              0
# 1            Otago  Central Districts        Napier              1
# 2            Otago  Central Districts        Napier              1
# 3            Otago  Central Districts        Napier              5
# 4            Otago  Central Districts        Napier              5
# ...            ...                ...           ...            ...
# 11632   Canterbury         Wellington  Christchurch            139
# 11633   Canterbury         Wellington  Christchurch            139
# 11634   Canterbury         Wellington  Christchurch            140
# 11635   Canterbury         Wellington  Christchurch            141
# 11636   Canterbury         Wellington  Christchurch            143
#
#        balls_bowled  balls_left  wickets_left   crr  runs_in_remaining_ball
# 0                 1         119            10  0.00                     181
# 1                 2         118            10  3.00                     180
# 2                 3         117            10  2.00                     180
# 3                 4         116            10  7.50                     176
# 4                 5         115            10  6.00                     176
# ...             ...         ...           ...   ...                     ...
# 11632           115           5             3  7.25                       6
# 11633           116           4             2  7.19                       6
# 11634           117           3             1  7.18                       5
# 11635           118           2             1  7.17                       4
# 11636           119           1             1  7.21                       2
#
# [11545 rows x 9 columns]

# %% [markdown]
# # final innings score probability data extraction

# %%
pickle.dump(final_score_probability_df, open('ssf_womens_first_innings_score.pkl','wb'))

# %% [markdown]
# # win probabilty

# %%
final_win_probability_df = score_probability_output[[
    'batting_team',
    'bowling_team',
    'city',
    'runs_y',
    'result_first_innings'
]]

final_win_probability_df.head()
# Out:
#   batting_team       bowling_team    city  runs_y  result_first_innings
# 0        Otago  Central Districts  Napier     181                     1
# 1        Otago  Central Districts  Napier     181                     1
# 2        Otago  Central Districts  Napier     181                     1
# 3        Otago  Central Districts  Napier     181                     1
# 4        Otago  Central Districts  Napier     181                     1

# %% [markdown]
# # final first innings win data extraction

# %%
pickle.dump(final_win_probability_df, open('ssf_womens_first_innings_win.pkl','wb'))

# %% [markdown]
# # Win Probabilty (during the second innings)

# %% [markdown]
# # target runs from first innings

# %%
total_score_df = delivery_df_1st_innings.groupby([
    'match_id',
]).sum()['runs'].reset_index()

total_score_df.head()
# Out:
#    match_id  runs
# 0         1   181
# 1         2   183
# 2         3   138
# 3         4   125
# 4         5    96

# %%
total_score_df['target_runs'] = total_score_df['runs'] + 1
total_score_df.drop(columns=['runs'], inplace=True)

total_score_df.head()
# Out:
#    match_id  target_runs
# 0         1          182
# 1         2          184
# 2         3          139
# 3         4          126
# 4         5           97

# %% [markdown]
# # merge with second innings data

# %%
final_2nd_innings_win_df = delivery_df_2nd_innings.merge(total_score_df, on='match_id')
final_2nd_innings_win_df.head()
# Out:
#    match_id winner  win_by_runs  win_by_wickets       batting_team  ball  \
# 0         1  Otago         72.0             NaN  Central Districts   0.1
# 1         1  Otago         72.0             NaN  Central Districts   0.2
# 2         1  Otago         72.0             NaN  Central Districts   0.3
# 3         1  Otago         72.0             NaN  Central Districts   0.4
# 4         1  Otago         72.0             NaN  Central Districts   0.5
#
#    runs  player_dismissed    city bowling_team  current_score  wickets_left  \
# 0     4                 0  Napier        Otago              4            10
# 1     1                 0  Napier        Otago              5            10
# 2     0                 0  Napier        Otago              5            10
# 3     0                 0  Napier        Otago              5            10
# 4     0                 0  Napier        Otago              5            10
#
#   over ball_no  balls_bowled  balls_left   crr  target_runs
# 0    0       1             1         119  24.0          182
# 1    0       2             2         118  15.0          182
# 2    0       3             3         117  10.0          182
# 3    0       4             4         116   7.5          182
# 4    0       5             5         115   6.0          182

# %% [markdown]
# # runs left

# %%
final_2nd_innings_win_df['runs_left'] = final_2nd_innings_win_df['target_runs'] - final_2nd_innings_win_df['current_score']
final_2nd_innings_win_df.head()
# Out:
#    match_id winner  win_by_runs  win_by_wickets       batting_team  ball  \
# 0         1  Otago         72.0             NaN  Central Districts   0.1
# 1         1  Otago         72.0             NaN  Central Districts   0.2
# 2         1  Otago         72.0             NaN  Central Districts   0.3
# 3         1  Otago         72.0             NaN  Central Districts   0.4
# 4         1  Otago         72.0             NaN  Central Districts   0.5
#
#    runs  player_dismissed    city bowling_team  current_score  wickets_left  \
# 0     4                 0  Napier        Otago              4            10
# 1     1                 0  Napier        Otago              5            10
# 2     0                 0  Napier        Otago              5            10
# 3     0                 0  Napier        Otago              5            10
# 4     0                 0  Napier        Otago              5            10
#
#   over ball_no  balls_bowled  balls_left   crr  target_runs  runs_left
# 0    0       1             1         119  24.0          182        178
# 1    0       2             2         118  15.0          182        177
# 2    0       3             3         117  10.0          182        177
# 3    0       4             4         116   7.5          182        177
# 4    0       5             5         115   6.0          182        177

# %% [markdown]
# # required run rate

# %%
final_2nd_innings_win_df['rrr'] = round((final_2nd_innings_win_df['runs_left']*6)/final_2nd_innings_win_df['balls_left'], 2)

final_2nd_innings_win_df.head()
# Out:
#    match_id winner  win_by_runs  win_by_wickets       batting_team  ball  \
# 0         1  Otago         72.0             NaN  Central Districts   0.1
# 1         1  Otago         72.0             NaN  Central Districts   0.2
# 2         1  Otago         72.0             NaN  Central Districts   0.3
# 3         1  Otago         72.0             NaN  Central Districts   0.4
# 4         1  Otago         72.0             NaN  Central Districts   0.5
#
#    runs  player_dismissed    city bowling_team  current_score  wickets_left  \
# 0     4                 0  Napier        Otago              4            10
# 1     1                 0  Napier        Otago              5            10
# 2     0                 0  Napier        Otago              5            10
# 3     0                 0  Napier        Otago              5            10
# 4     0                 0  Napier        Otago              5            10
#
#   over ball_no  balls_bowled  balls_left   crr  target_runs  runs_left   rrr
# 0    0       1             1         119  24.0          182        178  8.97
# 1    0       2             2         118  15.0          182        177  9.00
# 2    0       3             3         117  10.0          182        177  9.08
# 3    0       4             4         116   7.5          182        177  9.16
# 4    0       5             5         115   6.0          182        177  9.23

# %%
final_2nd_innings_win_df.isnull().sum()
# Out:
# match_id               0
# winner                 0
# win_by_runs         4571
# win_by_wickets      6125
# batting_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                   0
# bowling_team           0
# current_score          0
# wickets_left           0
# over                   0
# ball_no                0
# balls_bowled           0
# balls_left             0
# crr                    0
# target_runs            0
# runs_left              0
# rrr                    1
# dtype: int64

# %%
final_2nd_innings_win_df = final_2nd_innings_win_df[final_2nd_innings_win_df['balls_left'] != 0]

# %%
final_2nd_innings_win_df.isnull().sum()
# Out:
# match_id               0
# winner                 0
# win_by_runs         4570
# win_by_wickets      6093
# batting_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                   0
# bowling_team           0
# current_score          0
# wickets_left           0
# over                   0
# ball_no                0
# balls_bowled           0
# balls_left             0
# crr                    0
# target_runs            0
# runs_left              0
# rrr                    0
# dtype: int64

# %% [markdown]
# # consider batting team win

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

final_2nd_innings_win_df['result'] = final_2nd_innings_win_df.apply(result, axis=1)

final_2nd_innings_win_df.head()
# Out:
#    match_id winner  win_by_runs  win_by_wickets       batting_team  ball  \
# 0         1  Otago         72.0             NaN  Central Districts   0.1
# 1         1  Otago         72.0             NaN  Central Districts   0.2
# 2         1  Otago         72.0             NaN  Central Districts   0.3
# 3         1  Otago         72.0             NaN  Central Districts   0.4
# 4         1  Otago         72.0             NaN  Central Districts   0.5
#
#    runs  player_dismissed    city bowling_team  ...  wickets_left  over  \
# 0     4                 0  Napier        Otago  ...            10     0
# 1     1                 0  Napier        Otago  ...            10     0
# 2     0                 0  Napier        Otago  ...            10     0
# 3     0                 0  Napier        Otago  ...            10     0
# 4     0                 0  Napier        Otago  ...            10     0
#
#   ball_no balls_bowled  balls_left   crr  target_runs  runs_left   rrr  result
# 0       1            1         119  24.0          182        178  8.97       0
# 1       2            2         118  15.0          182        177  9.00       0
# 2       3            3         117  10.0          182        177  9.08       0
# 3       4            4         116   7.5          182        177  9.16       0
# 4       5            5         115   6.0          182        177  9.23       0
#
# [5 rows x 21 columns]

# %% [markdown]
# # final data for second innings win

# %%
final_2nd_innings_win_df = final_2nd_innings_win_df[[
    'batting_team',
    'bowling_team',
    'city',
    'current_score',
    'target_runs',
    'runs_left',
    'balls_left',
    'wickets_left',
    'crr',
    'rrr',
    'result'
]]

final_2nd_innings_win_df.head()
# Out:
#         batting_team bowling_team    city  current_score  target_runs  \
# 0  Central Districts        Otago  Napier              4          182
# 1  Central Districts        Otago  Napier              5          182
# 2  Central Districts        Otago  Napier              5          182
# 3  Central Districts        Otago  Napier              5          182
# 4  Central Districts        Otago  Napier              5          182
#
#    runs_left  balls_left  wickets_left   crr   rrr  result
# 0        178         119            10  24.0  8.97       0
# 1        177         118            10  15.0  9.00       0
# 2        177         117            10  10.0  9.08       0
# 3        177         116            10   7.5  9.16       0
# 4        177         115            10   6.0  9.23       0

# %% [markdown]
# # final second innings win data extraction

# %%
pickle.dump(final_2nd_innings_win_df, open('ssf_womens_second_innings_win.pkl','wb'))

# %% [markdown]
# # Machine Learning Model

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, accuracy_score, confusion_matrix, classification_report

from sklearn.model_selection import train_test_split

# %% [markdown]
# # score probability

# %%
#load data
score_portability_df = pickle.load(open('ssf_womens_first_innings_score.pkl','rb'))
score_portability_df.shape
# Out:
# (11545, 9)

# %%
score_portability_df.to_csv(r'ssf_womens_first_innings_score.csv', index=False, header=True)
score_portability_df = pd.read_csv(r'ssf_womens_first_innings_score.csv')

# %%
score_portability_df
# Out:
#       batting_team       bowling_team          city  current_score  \
# 0            Otago  Central Districts        Napier              0
# 1            Otago  Central Districts        Napier              1
# 2            Otago  Central Districts        Napier              1
# 3            Otago  Central Districts        Napier              5
# 4            Otago  Central Districts        Napier              5
# ...            ...                ...           ...            ...
# 11540   Canterbury         Wellington  Christchurch            139
# 11541   Canterbury         Wellington  Christchurch            139
# 11542   Canterbury         Wellington  Christchurch            140
# 11543   Canterbury         Wellington  Christchurch            141
# 11544   Canterbury         Wellington  Christchurch            143
#
#        balls_bowled  balls_left  wickets_left   crr  runs_in_remaining_ball
# 0                 1         119            10  0.00                     181
# 1                 2         118            10  3.00                     180
# 2                 3         117            10  2.00                     180
# 3                 4         116            10  7.50                     176
# 4                 5         115            10  6.00                     176
# ...             ...         ...           ...   ...                     ...
# 11540           115           5             3  7.25                       6
# 11541           116           4             2  7.19                       6
# 11542           117           3             1  7.18                       5
# 11543           118           2             1  7.17                       4
# 11544           119           1             1  7.21                       2
#
# [11545 rows x 9 columns]

# %%
score_portability_df.isnull().sum()
# Out:
# batting_team              0
# bowling_team              0
# city                      0
# current_score             0
# balls_bowled              0
# balls_left                0
# wickets_left              0
# crr                       0
# runs_in_remaining_ball    0
# dtype: int64

# %%
X = score_portability_df.drop(columns=['runs_in_remaining_ball'])
y = score_portability_df['runs_in_remaining_ball'].values

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.05, random_state=1)

# %%
X_train
# Out:
#              batting_team        bowling_team             city  current_score  \
# 9957   Northern Districts          Canterbury     Christchurch              1
# 994    Northern Districts          Canterbury  Mount Maunganui              8
# 3354   Northern Districts          Canterbury         Hamilton            109
# 1990           Wellington  Northern Districts  Mount Maunganui            109
# 1332                Otago            Auckland         Auckland             87
# ...                   ...                 ...              ...            ...
# 7813           Canterbury  Northern Districts     Christchurch             59
# 10955  Northern Districts   Central Districts         Hamilton             18
# 905              Auckland          Wellington       Wellington             47
# 5192                Otago   Central Districts          Dunedin            102
# 235            Wellington  Northern Districts       Wellington            144
#
#        balls_bowled  balls_left  wickets_left   crr
# 9957              5         115            10  1.20
# 994               8         112            10  6.00
# 3354            105          15             5  6.23
# 1990            100          20             6  6.54
# 1332             98          22             6  5.33
# ...             ...         ...           ...   ...
# 7813             45          75             9  7.87
# 10955            14         106             8  7.71
# 905              42          78             9  6.71
# 5192             93          27             8  6.58
# 235             106          14             7  8.15
#
# [10967 rows x 8 columns]

# %%
y_train
# Out:
# array([100, 102,  15, ...,  92,  32,  39], dtype=int64)

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'), ['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %% [markdown]
# # XgBoosting

# %%
pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2', StandardScaler()),
    ('step3', XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=20, random_state=1))
])

pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', StandardScaler()),
#                 ('step3',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, early_stopping_rou...
#                               feature_types=None, gamma=None, gpu_id=None,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=0.2,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=20, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=1000,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, random_state=1, ...))])

# %%
y_pred = pipe.predict(X_test)
print('R-Square Score: '+str(r2_score(y_test, y_pred)))
print('Mean Absolute Error: '+str(mean_absolute_error(y_test, y_pred)))
# Out:
# R-Square Score: 0.9825882665188155
# Mean Absolute Error: 2.145821901650577

# %%
predictions_xgb = pipe.predict(X_test)
sample_xgb = pd.DataFrame(predictions_xgb, columns=['Predict'])
sample_xgb['Actual']=y_test
sample_xgb.head(20)
# Out:
#        Predict  Actual
# 0   115.377129     116
# 1   110.684120     110
# 2   137.455399     138
# 3   113.038055     113
# 4    56.079830      53
# 5    72.698479      74
# 6    82.973747      81
# 7    30.299917      31
# 8    13.783436      14
# 9    23.154036      21
# 10   60.661682      62
# 11   25.617722      27
# 12   92.601334      91
# 13   67.473137      67
# 14   42.175869      43
# 15   59.950394      59
# 16   14.888746      15
# 17   34.033112      35
# 18   70.646622      70
# 19  113.029083     113

# %%
score_portability_df['city'].unique()
# Out:
# array(['Napier', 'Wellington', 'Auckland', 'Christchurch', 'Dunedin',
#        'Mount Maunganui', 'New Plymouth', 'Hamilton', 'Queenstown'],
#       dtype=object)

# %%
score_portability_df['batting_team'].unique()
# Out:
# array(['Otago', 'Wellington', 'Central Districts', 'Northern Districts',
#        'Canterbury', 'Auckland'], dtype=object)

# %% [markdown]
# # result count first way

# %%
input_df = pd.DataFrame({'batting_team': ['Peshawar Zalmi'], 'bowling_team': ['Quetta Gladiators'], 'city': ['Sharjah'], 'current_score': [170], 'balls_bowled': [108], 'balls_left': [12], 'wickets_left': [6], 'crr': [9.44]})
result = pipe.predict(input_df)[0]

#math.floor(result)
print('Probable Score: '+str(math.floor(result + 170)-8)+ ' to '+str(math.floor(result + 170)+4))
# Out:
# Probable Score: 185 to 197

# %% [markdown]
# # result count second way

# %%
result = pipe.predict(pd.DataFrame([['Peshawar Zalmi', 'Quetta Gladiators', 'Sharjah', 60, 90, 30, 10, 4.0]], columns=['batting_team', 'bowling_team', 'city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left', 'crr']))

#math.floor(result)
print('Probable Score: '+str(math.floor(result + 60)-8)+ ' to '+str(math.floor(result + 60)+2))
# Out:
# Probable Score: 99 to 109

# %% [markdown]
# # Random Forest

# %%
pipe_rf = Pipeline(steps=[
    ('step1', trf),
    ('step2', StandardScaler()),
    ('step3', RandomForestRegressor())
])

pipe_rf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', StandardScaler()),
#                 ('step3', RandomForestRegressor())])

# %%
y_pred_rf = pipe_rf.predict(X_test)
print('R-Square Score: '+str(r2_score(y_test, y_pred_rf)))
print('Mean Absolute Error: '+str(mean_absolute_error(y_test, y_pred_rf)))
# Out:
# R-Square Score: 0.9820637524568232
# Mean Absolute Error: 2.384681084198385

# %%
predictions_rf = pipe_rf.predict(X_test)
sample_rf = pd.DataFrame(predictions_rf, columns=['Predict'])
sample_rf['Actual']=y_test
sample_rf.head(20)
# Out:
#     Predict  Actual
# 0    114.55     116
# 1    108.20     110
# 2    137.71     138
# 3    113.16     113
# 4     52.74      53
# 5     74.37      74
# 6     79.73      81
# 7     30.61      31
# 8     13.41      14
# 9     22.57      21
# 10    58.35      62
# 11    25.69      27
# 12    90.87      91
# 13    68.32      67
# 14    43.05      43
# 15    58.87      59
# 16    16.54      15
# 17    32.51      35
# 18    71.54      70
# 19   113.81     113

# %%
result = pipe_rf.predict(pd.DataFrame([['Auckland', 'Central Districts', 'New Plymouth', 60, 90, 30, 10, 4.0]], columns=['batting_team', 'bowling_team', 'city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left', 'crr']))

#math.floor(result)
print('Probable Score: '+str(math.floor(result + 60)-8)+ ' to '+str(math.floor(result + 60)+2))
# Out:
# Probable Score: 95 to 105

# %% [markdown]
# # Comparison Tables "Predict and Actual"

# %%
def display_dfs(dfs, gap=50, justify='center'):
    html = ""
    for title, df in dfs.items():  
        df_html = df._repr_html_()
        cur_html = f'<div> <h4>{title}</h4> {df_html}</div>'
        html +=  cur_html
    html= f"""
    <div style="display:flex; gap:{gap}px; justify-content:{justify};">
        {html}
    </div>
    """
    display_html(html, raw=True)


dfs = {'XGBoost Regressor': sample_xgb.head(20), 
       'Random Forest Regressor': sample_rf.head(20)}
# dfs = {'Model-1': sample3.head(20),
#        'Model-2': sample4.head(20),
#        'Model-3': sample5.head(20),
#        'Model-4': sample6.head(20)}
display_dfs(dfs, justify='flex-start')
# Out:
#     <div style="display:flex; gap:50px; justify-content:flex-start;">
#         <div> <h4>XGBoost Regressor</h4> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predict</th>
#       <th>Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>115.377129</td>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>110.684120</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>137.455399</td>
#       <td>138</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>113.038055</td>
#       <td>113</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>56.079830</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>72.698479</td>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>82.973747</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>30.299917</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>13.783436</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>23.154036</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>60.661682</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>25.617722</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>92.601334</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>67.473137</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>42.175869</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>59.950394</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>14.888746</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>34.033112</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>70.646622</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>113.029083</td>
#       <td>113</td>
#     </tr>
#   </tbody>
# </table>
# </div></div><div> <h4>Random Forest Regressor</h4> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predict</th>
#       <th>Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>114.55</td>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>108.20</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>137.71</td>
#       <td>138</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>113.16</td>
#       <td>113</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>52.74</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>74.37</td>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>79.73</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>30.61</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>13.41</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>22.57</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>58.35</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>25.69</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>90.87</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>68.32</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>43.05</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>58.87</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16.54</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>32.51</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>71.54</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>113.81</td>
#       <td>113</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#     </div>

# %% [markdown]
# # Comparison Graph

# %%
plt.rcParams["figure.figsize"] = (18, 14) 

plt.subplot(2,2,1)
plt.title("XGBoost Regressor", fontsize=16)
plt.scatter(sample_xgb['Actual'], sample_xgb['Predict'], c='g')
plt.grid()

plt.subplot(2,2,2)
plt.title("Random Forest Regressor", fontsize=16)
plt.scatter(sample_rf['Actual'], sample_rf['Predict'], c='g')
plt.grid()

# %% [markdown]
# # model extraction

# %%
#Model Extraction
pickle.dump(pipe, open('ssf_womens_score_prediction_final_model.pkl','wb'))

# %% [markdown]
# # win probability (first innings)

# %%
#load data
first_innings_win_portability_df = pickle.load(open('ssf_womens_first_innings_win.pkl','rb'))
first_innings_win_portability_df
# Out:
#       batting_team       bowling_team          city  runs_y  \
# 0            Otago  Central Districts        Napier     181
# 1            Otago  Central Districts        Napier     181
# 2            Otago  Central Districts        Napier     181
# 3            Otago  Central Districts        Napier     181
# 4            Otago  Central Districts        Napier     181
# ...            ...                ...           ...     ...
# 11633   Canterbury         Wellington  Christchurch     145
# 11634   Canterbury         Wellington  Christchurch     145
# 11635   Canterbury         Wellington  Christchurch     145
# 11636   Canterbury         Wellington  Christchurch     145
# 11637   Canterbury         Wellington  Christchurch     145
#
#        result_first_innings
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 11633                     1
# 11634                     1
# 11635                     1
# 11636                     1
# 11637                     1
#
# [11638 rows x 5 columns]

# %%
first_innings_win_portability_df.to_csv(r'ssf_womens_first_innings_win.csv', index=False, header=True)
first_innings_win_portability_df = pd.read_csv(r'ssf_womens_first_innings_win.csv')
first_innings_win_portability_df
# Out:
#       batting_team       bowling_team          city  runs_y  \
# 0            Otago  Central Districts        Napier     181
# 1            Otago  Central Districts        Napier     181
# 2            Otago  Central Districts        Napier     181
# 3            Otago  Central Districts        Napier     181
# 4            Otago  Central Districts        Napier     181
# ...            ...                ...           ...     ...
# 11633   Canterbury         Wellington  Christchurch     145
# 11634   Canterbury         Wellington  Christchurch     145
# 11635   Canterbury         Wellington  Christchurch     145
# 11636   Canterbury         Wellington  Christchurch     145
# 11637   Canterbury         Wellington  Christchurch     145
#
#        result_first_innings
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 11633                     1
# 11634                     1
# 11635                     1
# 11636                     1
# 11637                     1
#
# [11638 rows x 5 columns]

# %%
X1 = first_innings_win_portability_df.drop(columns=['result_first_innings'])
y1 = first_innings_win_portability_df['result_first_innings'].values

X1_train,X1_test,y1_train,y1_test = train_test_split(X1, y1, test_size=0.1, random_state=1)

# %%
X1_train
# Out:
#             batting_team        bowling_team          city  runs_y
# 8040   Central Districts            Auckland      Auckland     135
# 4611            Auckland          Wellington      Auckland     117
# 11531         Canterbury          Wellington  Christchurch     145
# 4137          Wellington   Central Districts    Wellington     162
# 9943          Canterbury            Auckland      Auckland     137
# ...                  ...                 ...           ...     ...
# 7813            Auckland               Otago      Auckland     106
# 10955  Central Districts               Otago       Dunedin     108
# 905             Auckland          Wellington    Wellington     139
# 5192               Otago   Central Districts       Dunedin     134
# 235           Wellington  Northern Districts    Wellington     183
#
# [10474 rows x 4 columns]

# %%
trf1 = ColumnTransformer([
    ('trf1', OneHotEncoder(sparse=False, drop='first'),['batting_team', 'bowling_team', 'city'])
]
,remainder='passthrough')

# %%
pipe1 = Pipeline(steps=[
    ('step1',trf1),
    ('step2', LogisticRegression()) #solver='liblinear'
])

pipe1.fit(X1_train, y1_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression())])

# %%
y1_pred = pipe1.predict(X1_test)

print('Accuracy Score: '+str(accuracy_score(y1_test,y1_pred)*100))
# Out:
# Accuracy Score: 86.5979381443299

# %%
confusion_matrix_lr = confusion_matrix(y1_test, y1_pred)
confusion_matrix_lr
# Out:
# array([[446, 100],
#        [ 56, 562]], dtype=int64)

# %%
print(classification_report(y1_test, y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85       546
#            1       0.85      0.91      0.88       618
#
#     accuracy                           0.87      1164
#    macro avg       0.87      0.86      0.86      1164
# weighted avg       0.87      0.87      0.87      1164

# %%
pipe1.predict_proba(X1_test)[4]
# Out:
# array([0.23426689, 0.76573311])

# %%
plt.rcParams["figure.figsize"] = (10, 6) 

ax = sns.heatmap(confusion_matrix_lr/np.sum(confusion_matrix_lr), annot=True, fmt='.2%', cmap='Blues')
# ax.set_title('Logistic Regression\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Lose','Win'])
ax.yaxis.set_ticklabels(['Lose','Win'])
## Display the visualization of the Confusion Matrix.
plt.show()

# %%
input_df = pd.DataFrame({'batting_team': ['Peshawar Zalmi'], 'bowling_team': ['Quetta Gladiators'], 'city': ['Sharjah'], 'runs_y': [190]})
result = pipe1.predict_proba(input_df)

loss = result[0][1]
win = result[0][0]

print('win: '+str(round(win*100))+'%')
print('loss: '+str(round(loss*100))+'%')
# Out:
# win: 42%
# loss: 58%

# %% [markdown]
# # Model Extraction

# %%
#Model Extraction
pickle.dump(pipe1, open('ssf_1st_innings_win_prediction_final_model.pkl','wb'))

# %% [markdown]
# # win probability (second innings)

# %%
#load data
second_innings_win_portability_df = pickle.load(open('ssf_womens_second_innings_win.pkl','rb'))
second_innings_win_portability_df
# Out:
#             batting_team bowling_team          city  current_score  \
# 0      Central Districts        Otago        Napier              4
# 1      Central Districts        Otago        Napier              5
# 2      Central Districts        Otago        Napier              5
# 3      Central Districts        Otago        Napier              5
# 4      Central Districts        Otago        Napier              5
# ...                  ...          ...           ...            ...
# 10690         Wellington   Canterbury  Christchurch            129
# 10691         Wellington   Canterbury  Christchurch            129
# 10692         Wellington   Canterbury  Christchurch            131
# 10693         Wellington   Canterbury  Christchurch            131
# 10694         Wellington   Canterbury  Christchurch            132
#
#        target_runs  runs_left  balls_left  wickets_left    crr    rrr  result
# 0              182        178         119            10  24.00   8.97       0
# 1              182        177         118            10  15.00   9.00       0
# 2              182        177         117            10  10.00   9.08       0
# 3              182        177         116            10   7.50   9.16       0
# 4              182        177         115            10   6.00   9.23       0
# ...            ...        ...         ...           ...    ...    ...     ...
# 10690          146         17           5             2   6.73  20.40       0
# 10691          146         17           4             2   6.67  25.50       0
# 10692          146         15           3             2   6.72  30.00       0
# 10693          146         15           2             1   6.66  45.00       0
# 10694          146         14           1             1   6.66  84.00       0
#
# [10663 rows x 11 columns]

# %%
second_innings_win_portability_df.to_csv(r'ssf_womens_second_innings_win.csv', index=False, header=True)
second_innings_win_portability_df = pd.read_csv(r'ssf_womens_second_innings_win.csv')
second_innings_win_portability_df
# Out:
#             batting_team bowling_team          city  current_score  \
# 0      Central Districts        Otago        Napier              4
# 1      Central Districts        Otago        Napier              5
# 2      Central Districts        Otago        Napier              5
# 3      Central Districts        Otago        Napier              5
# 4      Central Districts        Otago        Napier              5
# ...                  ...          ...           ...            ...
# 10658         Wellington   Canterbury  Christchurch            129
# 10659         Wellington   Canterbury  Christchurch            129
# 10660         Wellington   Canterbury  Christchurch            131
# 10661         Wellington   Canterbury  Christchurch            131
# 10662         Wellington   Canterbury  Christchurch            132
#
#        target_runs  runs_left  balls_left  wickets_left    crr    rrr  result
# 0              182        178         119            10  24.00   8.97       0
# 1              182        177         118            10  15.00   9.00       0
# 2              182        177         117            10  10.00   9.08       0
# 3              182        177         116            10   7.50   9.16       0
# 4              182        177         115            10   6.00   9.23       0
# ...            ...        ...         ...           ...    ...    ...     ...
# 10658          146         17           5             2   6.73  20.40       0
# 10659          146         17           4             2   6.67  25.50       0
# 10660          146         15           3             2   6.72  30.00       0
# 10661          146         15           2             1   6.66  45.00       0
# 10662          146         14           1             1   6.66  84.00       0
#
# [10663 rows x 11 columns]

# %%
X2 = second_innings_win_portability_df.drop(columns=['result'])
y2 = second_innings_win_portability_df['result'].values

X2_train,X2_test,y2_train,y2_test = train_test_split(X2, y2, test_size=0.1, random_state=1)

# %%
X2_train
# Out:
#             batting_team        bowling_team             city  current_score  \
# 4400          Canterbury          Wellington     Christchurch             69
# 4482            Auckland  Northern Districts         Auckland             38
# 9165            Auckland          Canterbury         Auckland            103
# 5722  Northern Districts          Canterbury  Mount Maunganui              5
# 9664  Northern Districts            Auckland  Mount Maunganui             31
# ...                  ...                 ...              ...            ...
# 2895          Canterbury  Northern Districts         Hamilton            115
# 7813               Otago          Wellington         Hamilton             74
# 905           Wellington            Auckland       Wellington            125
# 5192          Wellington            Auckland         Auckland             43
# 235   Northern Districts          Wellington       Wellington            116
#
#       target_runs  runs_left  balls_left  wickets_left   crr    rrr
# 4400          146         77          42             6  5.31  11.00
# 4482          104         66          78             8  5.43   5.08
# 9165          138         35           9             4  5.57  23.33
# 5722          143        138         112            10  3.75   7.39
# 9664           93         62          89             7  6.00   4.18
# ...           ...        ...         ...           ...   ...    ...
# 2895          125         10          36             7  8.21   1.67
# 7813          176        102          38             2  5.41  16.11
# 905           140         15          24             8  7.81   3.75
# 5192           90         47          91             8  8.90   3.10
# 235           184         68          11             5  6.39  37.09
#
# [9596 rows x 10 columns]

# %%
trf2 = ColumnTransformer([
    ('trf2', OneHotEncoder(sparse=False, drop='first'),['batting_team', 'bowling_team', 'city'])
]
,remainder='passthrough')

# %%
pipe2 = Pipeline(steps=[
    ('step1',trf2),
    ('step2',LogisticRegression()) #solver='liblinear'
])

pipe2.fit(X2_train,y2_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf2',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression())])

# %%
y2_pred = pipe2.predict(X2_test)
print('Accuracy Score: '+str(accuracy_score(y2_test, y2_pred)*100))
# Out:
# Accuracy Score: 89.22211808809747

# %%
confusion_matrix1 = confusion_matrix(y2_test, y2_pred)
confusion_matrix1
# Out:
# array([[563,  56],
#        [ 59, 389]], dtype=int64)

# %%
print(classification_report(y2_test, y2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       619
#            1       0.87      0.87      0.87       448
#
#     accuracy                           0.89      1067
#    macro avg       0.89      0.89      0.89      1067
# weighted avg       0.89      0.89      0.89      1067

# %%
pipe2.predict_proba(X2_test)[10]
# Out:
# array([0.00361209, 0.99638791])

# %%
plt.rcParams["figure.figsize"] = (10, 6) 

ax = sns.heatmap(confusion_matrix1/np.sum(confusion_matrix1), annot=True, fmt='.2%', cmap='Blues')
# ax.set_title('Model-1\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Lose','Win'])
ax.yaxis.set_ticklabels(['Lose','Win'])
## Display the visualization of the Confusion Matrix.
plt.show()

# %%
input_df = pd.DataFrame({'batting_team': ['Peshawar Zalmi'], 'bowling_team': ['Quetta Gladiators'], 'city': ['Sharjah'], 'current_score':[159], 'target_runs':[169], 'runs_left':[10], 'balls_left': [2], 'wickets_left':[7], 'crr':[8.08], 'rrr': [30.0]})
result = pipe2.predict_proba(input_df)

loss = result[0][0]
win = result[0][1]

print('win: '+str(round(win*100))+'%')
print('loss: '+str(round(loss*100))+'%')
# Out:
# win: 5%
# loss: 95%

# %% [markdown]
# # Model Extraction

# %%
#Model Extraction
pickle.dump(pipe2, open('ssf_2nd_innings_win_prediction_final_model.pkl','wb'))
