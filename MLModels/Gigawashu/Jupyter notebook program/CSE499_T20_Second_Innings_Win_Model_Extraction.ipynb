# %%
#Python Library
import warnings
warnings.filterwarnings("ignore")
import math
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# # ML Library

# %%
#ML Library
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score, mean_absolute_error, accuracy_score, confusion_matrix, classification_report

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Dataset

# %%
#load data
second_innings_win_portability_df = pickle.load(open('ipl_mens_second_innings_win.pkl','rb'))
second_innings_win_portability_df
# Out:
#                        batting_team         bowling_team       city  \
# 0       Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 1       Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 2       Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 3       Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 4       Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 112560  Royal Challengers Bangalore  Sunrisers Hyderabad  Bangalore
# 112561  Royal Challengers Bangalore  Sunrisers Hyderabad  Bangalore
# 112562  Royal Challengers Bangalore  Sunrisers Hyderabad  Bangalore
# 112563  Royal Challengers Bangalore  Sunrisers Hyderabad  Bangalore
# 112564  Royal Challengers Bangalore  Sunrisers Hyderabad  Bangalore
#
#         current_score  target_runs  runs_left  balls_left  wickets_left  \
# 0                   1          208        207         119            10
# 1                   1          208        207         118            10
# 2                   1          208        207         117            10
# 3                   3          208        205         116            10
# 4                   7          208        201         115            10
# ...               ...          ...        ...         ...           ...
# 112560            192          209         17           5             4
# 112561            194          209         15           4             4
# 112562            194          209         15           3             3
# 112563            195          209         14           2             3
# 112564            196          209         13           1             3
#
#           crr    rrr  result
# 0        6.00  10.44       0
# 1        3.00  10.53       0
# 2        2.00  10.62       0
# 3        4.50  10.60       0
# 4        8.40  10.49       0
# ...       ...    ...     ...
# 112560  10.02  20.40       0
# 112561  10.03  22.50       0
# 112562   9.95  30.00       0
# 112563   9.92  42.00       0
# 112564   9.88  78.00       0
#
# [112063 rows x 11 columns]

# %% [markdown]
# # Test and Train Split

# %%
#Split
X2 = second_innings_win_portability_df.drop(columns=['result'])
y2 = second_innings_win_portability_df['result'].values

X2_train,X2_test,y2_train,y2_test = train_test_split(X2, y2, test_size=0.1, random_state=1)

# %%
#Display
X2_train
# Out:
#                       batting_team                 bowling_team        city  \
# 41728  Royal Challengers Bangalore               Mumbai Indians   Bengaluru
# 62231        Kolkata Knight Riders          Chennai Super Kings     Kolkata
# 34847        Kolkata Knight Riders               Delhi Capitals      Mumbai
# 20634                 Punjab Kings               Mumbai Indians   Abu Dhabi
# 1009                Mumbai Indians          Sunrisers Hyderabad      Mumbai
# ...                            ...                          ...         ...
# 50294             Rajasthan Royals                 Punjab Kings      Jaipur
# 98490  Royal Challengers Bangalore        Kolkata Knight Riders     Kolkata
# 5210         Kolkata Knight Riders                 Punjab Kings  Chandigarh
# 78066               Delhi Capitals               Mumbai Indians      Mumbai
# 98985          Chennai Super Kings  Royal Challengers Bangalore   Bangalore
#
#        current_score  target_runs  runs_left  balls_left  wickets_left   crr  \
# 41728             12          172        160         109            10  6.55
# 62231             61          165        104          66             5  6.78
# 34847             62          216        154          71             8  7.59
# 20634            105          192         87          36             6  7.50
# 1009              17          159        142         109            10  9.27
# ...              ...          ...        ...         ...           ...   ...
# 50294            159          167          8          14             6  9.00
# 98490             67          196        129          66             9  7.44
# 5210              76          168         92          65             9  8.29
# 78066             30           93         63          91            10  6.21
# 98985             86          155         69          61             8  8.75
#
#          rrr
# 41728   8.81
# 62231   9.45
# 34847  13.01
# 20634  14.50
# 1009    7.82
# ...      ...
# 50294   3.43
# 98490  11.73
# 5210    8.49
# 78066   4.15
# 98985   6.79
#
# [100856 rows x 10 columns]

# %%
#Column Transformation
trf2 = ColumnTransformer([
    ('trf2', OneHotEncoder(sparse=False, drop='first'),['batting_team', 'bowling_team', 'city'])
]
,remainder='passthrough')

# %%
#Pipeline
pipe2 = Pipeline(steps=[
    ('step1',trf2),
    ('step2',LogisticRegression())
])

# %%
#Train Model
pipe2.fit(X2_train,y2_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf2',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression())])

# %%
pipe2.predict_proba(X2_test)[10]
# Out:
# array([0.59633878, 0.40366122])

# %%
#Accuracy on test data
y2_pred = pipe2.predict(X2_test)

# %%
#Confusion Matrix
confusion_matrix(y2_test, y2_pred)
# Out:
# array([[5501, 1119],
#        [1245, 3342]])

# %%
#Classiffication Report
print(classification_report(y2_test, y2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82      6620
#            1       0.75      0.73      0.74      4587
#
#     accuracy                           0.79     11207
#    macro avg       0.78      0.78      0.78     11207
# weighted avg       0.79      0.79      0.79     11207

# %% [markdown]
# # Result Prediction

# %%
#Prediction
input_df = pd.DataFrame({'batting_team': ['Royal Challengers Bangalore'], 'bowling_team': ['Chennai Super Kings'], 'city': ['Kolkata'], 'current_score':[32], 'target_runs':[176], 'runs_left':[144], 'balls_left': [95], 'wickets_left':[10], 'crr':[7.80], 'rrr': [9.29]})
result = pipe2.predict_proba(input_df)

loss = result[0][0]
win = result[0][1]

print('win: '+str(round(win*100))+'%')
print('loss: '+str(round(loss*100))+'%')
# Out:
# win: 64%
# loss: 36%

# %% [markdown]
# # Model Extraction

# %%
#Model Extraction
pickle.dump(pipe2, open('ipl_mens_second_innings_final_model.pkl','wb'))
