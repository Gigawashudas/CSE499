# %% [markdown]
# # Import Library

# %%
import warnings
warnings.filterwarnings("ignore")

import math
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm
import pickle
import csv

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display_html

# %% [markdown]
# # Data Exploration

# %%
filenames = []
for file in os.listdir('F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssm/data/'):
    filenames.append(os.path.join('F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssm/data/', file))

# %%
filenames[0:5]
# Out:
# ['F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssm/data/1118534.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssm/data/1118535.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssm/data/1118537.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssm/data/1118538.yaml',
#  'F:/AI ML DL Projects/CSE499 ML Project/ml project data/ssm/data/1118540.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
# 100%|██████████| 182/182 [00:44<00:00,  4.06it/s]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Central Districts',...               0.91
# 0   [{'1st innings': {'team': 'Canterbury', 'deliv...               0.91
# 0   [{'1st innings': {'team': 'Northern Districts'...               0.91
# 0   [{'1st innings': {'team': 'Central Districts',...               0.91
# 0   [{'1st innings': {'team': 'Northern Districts'...               0.91
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Canterbury', 'deliv...               0.92
# 0   [{'1st innings': {'team': 'Wellington', 'deliv...               0.91
# 0   [{'1st innings': {'team': 'Auckland', 'deliver...               0.91
# 0   [{'1st innings': {'team': 'Northern Districts'...               0.91
# 0   [{'1st innings': {'team': 'Otago', 'deliveries...               0.91
#
#    meta.created  meta.revision  info.balls_per_over        info.city  \
# 0    2021-03-02              1                    6         Auckland
# 0    2021-03-04              1                    6     Christchurch
# 0    2021-03-05              1                    6  Mount Maunganui
# 0    2021-03-05              1                    6           Nelson
# 0    2021-03-05              1                    6       Wellington
# ..          ...            ...                  ...              ...
# 0    2023-02-14              1                    6     Christchurch
# 0    2021-03-05              1                    6          Dunedin
# 0    2021-03-05              1                    6         Auckland
# 0    2021-03-05              1                    6         Hamilton
# 0    2021-03-05              1                    6         Hamilton
#
#    info.competition    info.dates info.gender info.match_type  ...  \
# 0       Super Smash  [2017-12-13]        male             T20  ...
# 0       Super Smash  [2017-12-14]        male             T20  ...
# 0       Super Smash  [2017-12-16]        male             T20  ...
# 0       Super Smash  [2017-12-17]        male             T20  ...
# 0       Super Smash  [2017-12-20]        male             T20  ...
# ..              ...           ...         ...             ...  ...
# 0       Super Smash  [2023-02-11]        male             T20  ...
# 0           HRV Cup  [2013-01-20]        male             T20  ...
# 0      HRV Twenty20  [2014-01-03]        male             T20  ...
# 0      HRV Twenty20  [2014-01-17]        male             T20  ...
# 0      HRV Twenty20  [2014-01-18]        male             T20  ...
#
#    info.registry.people.BJ Diamanti  info.registry.people.BJ Watling  \
# 0                               NaN                              NaN
# 0                               NaN                              NaN
# 0                               NaN                              NaN
# 0                               NaN                              NaN
# 0                               NaN                              NaN
# ..                              ...                              ...
# 0                               NaN                              NaN
# 0                               NaN                              NaN
# 0                               NaN                              NaN
# 0                          549aefcd                         928670cc
# 0                               NaN                         928670cc
#
#     info.registry.people.CP Tremain info.registry.people.DM Quested  \
# 0                               NaN                             NaN
# 0                               NaN                             NaN
# 0                               NaN                             NaN
# 0                               NaN                             NaN
# 0                               NaN                             NaN
# ..                              ...                             ...
# 0                               NaN                             NaN
# 0                               NaN                             NaN
# 0                               NaN                             NaN
# 0                          96824e68                        bb312212
# 0                          96824e68                        bb312212
#
#    info.registry.people.JJ Boult info.registry.people.PD Jones  \
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# ..                           ...                           ...
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                            NaN                           NaN
# 0                       3b298ff2                      169be239
# 0                       3b298ff2                      169be239
#
#    info.registry.people.PG Fulton info.registry.people.SB Styris  \
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# ..                            ...                            ...
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                        10a2a1ff                       57efa3be
# 0                             NaN                       57efa3be
#
#    info.registry.people.JD Hickey info.registry.people.JO Holder
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# ..                            ...                            ...
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                             NaN                            NaN
# 0                        6ce98e65                       0f721006
#
# [182 rows x 300 columns]

# %% [markdown]
# # data store

# %%
#data store as pickle file
pickle.dump(final_df, open('cse499_ssm_male.pkl','wb'))

# %% [markdown]
# # data load

# %%
final_df = pickle.load(open('cse499_ssm_male.pkl','rb'))
final_df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Central Districts',...               0.91
# 0  [{'1st innings': {'team': 'Canterbury', 'deliv...               0.91
# 0  [{'1st innings': {'team': 'Northern Districts'...               0.91
# 0  [{'1st innings': {'team': 'Central Districts',...               0.91
# 0  [{'1st innings': {'team': 'Northern Districts'...               0.91
#
#   meta.created  meta.revision  info.balls_per_over        info.city  \
# 0   2021-03-02              1                    6         Auckland
# 0   2021-03-04              1                    6     Christchurch
# 0   2021-03-05              1                    6  Mount Maunganui
# 0   2021-03-05              1                    6           Nelson
# 0   2021-03-05              1                    6       Wellington
#
#   info.competition    info.dates info.gender info.match_type  ...  \
# 0      Super Smash  [2017-12-13]        male             T20  ...
# 0      Super Smash  [2017-12-14]        male             T20  ...
# 0      Super Smash  [2017-12-16]        male             T20  ...
# 0      Super Smash  [2017-12-17]        male             T20  ...
# 0      Super Smash  [2017-12-20]        male             T20  ...
#
#   info.registry.people.BJ Diamanti  info.registry.people.BJ Watling  \
# 0                              NaN                              NaN
# 0                              NaN                              NaN
# 0                              NaN                              NaN
# 0                              NaN                              NaN
# 0                              NaN                              NaN
#
#    info.registry.people.CP Tremain info.registry.people.DM Quested  \
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
# 0                              NaN                             NaN
#
#   info.registry.people.JJ Boult info.registry.people.PD Jones  \
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
# 0                           NaN                           NaN
#
#   info.registry.people.PG Fulton info.registry.people.SB Styris  \
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
#
#   info.registry.people.JD Hickey info.registry.people.JO Holder
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
# 0                            NaN                            NaN
#
# [5 rows x 300 columns]

# %% [markdown]
# # Data Pre-Processing and Analysis

# %%
final_df = final_df[[
    'match_id',
    'innings',
    'info.dates',
    'info.gender',
    'info.match_type',
    'info.teams',
    'info.toss.winner',
    'info.toss.decision',
    'info.outcome.winner',
    'info.outcome.by.runs',
    'info.outcome.by.wickets',
    'info.overs',
    'info.umpires',
    'info.venue',
    'info.city'
]]

final_df.head()
# Out:
#    match_id                                            innings    info.dates  \
# 0         1  [{'1st innings': {'team': 'Central Districts',...  [2017-12-13]
# 0         2  [{'1st innings': {'team': 'Canterbury', 'deliv...  [2017-12-14]
# 0         3  [{'1st innings': {'team': 'Northern Districts'...  [2017-12-16]
# 0         4  [{'1st innings': {'team': 'Central Districts',...  [2017-12-17]
# 0         5  [{'1st innings': {'team': 'Northern Districts'...  [2017-12-20]
#
#   info.gender info.match_type                        info.teams  \
# 0        male             T20     [Auckland, Central Districts]
# 0        male             T20               [Canterbury, Otago]
# 0        male             T20    [Northern Districts, Auckland]
# 0        male             T20   [Central Districts, Canterbury]
# 0        male             T20  [Northern Districts, Wellington]
#
#      info.toss.winner info.toss.decision info.outcome.winner  \
# 0   Central Districts                bat            Auckland
# 0          Canterbury                bat          Canterbury
# 0  Northern Districts                bat  Northern Districts
# 0   Central Districts                bat   Central Districts
# 0  Northern Districts                bat  Northern Districts
#
#    info.outcome.by.runs  info.outcome.by.wickets  info.overs  \
# 0                   NaN                      5.0          20
# 0                 134.0                      NaN          20
# 0                   7.0                      NaN          20
# 0                   8.0                      NaN          20
# 0                   1.0                      NaN          20
#
#                 info.umpires            info.venue        info.city
# 0      [SB Haig, WR Knights]  Eden Park Outer Oval         Auckland
# 0    [DJ Walker, TJ Parlane]           Hagley Oval     Christchurch
# 0    [BF Bowden, WR Knights]              Bay Oval  Mount Maunganui
# 0  [A Mehrotra, JAK Bromley]           Saxton Oval           Nelson
# 0    [DJ Walker, TJ Parlane]         Basin Reserve       Wellington

# %%
final_df['info.gender'].value_counts()
# Out:
# male    182
# Name: info.gender, dtype: int64

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    182
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    182
# Name: info.overs, dtype: int64

# %%
# Remove 50 over match data
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df.shape
# Out:
# (182, 13)

# %% [markdown]
# # extract first & second innings data

# %%
# No Result Matches
final_df[final_df['info.outcome.winner'].isnull()]
# Out:
#    match_id                                            innings    info.dates  \
# 0        38  [{'1st innings': {'team': 'Auckland', 'deliver...  [2019-01-13]
# 0        59  [{'1st innings': {'team': 'Canterbury', 'deliv...  [2019-12-17]
# 0        61  [{'1st innings': {'team': 'Otago', 'deliveries...  [2019-12-19]
# 0        62  [{'1st innings': {'team': 'Central Districts',...  [2019-12-20]
# 0       122  [{'1st innings': {'team': 'Northern Districts'...  [2021-12-03]
# 0       160  [{'1st innings': {'team': 'Otago', 'deliveries...  [2023-01-02]
#
#   info.gender                               info.teams   info.toss.winner  \
# 0        male                        [Auckland, Otago]              Otago
# 0        male                   [Canterbury, Auckland]           Auckland
# 0        male                        [Otago, Auckland]           Auckland
# 0        male  [Central Districts, Northern Districts]  Central Districts
# 0        male              [Northern Districts, Otago]              Otago
# 0        male                        [Otago, Auckland]           Auckland
#
#   info.toss.decision info.outcome.winner  info.outcome.by.runs  \
# 0              field                 NaN                   NaN
# 0              field                 NaN                   NaN
# 0              field                 NaN                   NaN
# 0                bat                 NaN                   NaN
# 0              field                 NaN                   NaN
# 0              field                 NaN                   NaN
#
#    info.outcome.by.wickets                info.umpires  \
# 0                      NaN       [JM Dempsey, SB Haig]
# 0                      NaN      [JAK Bromley, SB Haig]
# 0                      NaN        [DJ Walker, SB Haig]
# 0                      NaN      [CM Brown, WR Knights]
# 0                      NaN   [CM Brown, Damian Morrow]
# 0                      NaN  [Glen Walklin, WR Knights]
#
#                        info.venue     info.city
# 0                 University Oval       Dunedin
# 0                     Hagley Oval  Christchurch
# 0                 University Oval       Dunedin
# 0                     Seddon Park      Hamilton
# 0           Seddon Park, Hamilton      Hamilton
# 0  Eden Park Outer Oval, Auckland      Auckland

# %% [markdown]
# # remove no result matches

# %%
final_df = final_df.dropna(subset=['info.outcome.winner'])
final_df.shape
# Out:
# (176, 13)

# %%
final_df.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'non_striker': 'GH Worker',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {0.2: {'non_striker': 'GH Worker',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'JD Ryder'}},
#  {0.3: {'non_striker': 'GH Worker',
#    'bowler': 'AT Nidamanuru',
#    'extras': {'wides': 2},
#    'runs': {'extras': 2, 'total': 2, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {0.4: {'non_striker': 'JD Ryder',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'GH Worker'}},
#  {0.5: {'non_striker': 'JD Ryder',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'GH Worker'}},
#  {0.6: {'non_striker': 'JD Ryder',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GH Worker'}},
#  {0.7: {'non_striker': 'JD Ryder',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'GH Worker'}},
#  {1.1: {'non_striker': 'GH Worker',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'JD Ryder'}},
#  {1.2: {'non_striker': 'GH Worker',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {1.3: {'non_striker': 'GH Worker',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {1.4: {'non_striker': 'GH Worker',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'JD Ryder'}},
#  {1.5: {'non_striker': 'GH Worker',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'JD Ryder'}},
#  {1.6: {'non_striker': 'GH Worker',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'JD Ryder'}},
#  {2.1: {'non_striker': 'JD Ryder',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GH Worker'}},
#  {2.2: {'non_striker': 'GH Worker',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {2.3: {'non_striker': 'GH Worker',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {2.4: {'non_striker': 'JD Ryder',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GH Worker'}},
#  {2.5: {'non_striker': 'GH Worker',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {2.6: {'non_striker': 'GH Worker',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {3.1: {'non_striker': 'GH Worker',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {3.2: {'non_striker': 'JD Ryder',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GH Worker'}},
#  {3.3: {'non_striker': 'JD Ryder',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GH Worker'}},
#  {3.4: {'non_striker': 'GH Worker',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'JD Ryder'}},
#  {3.5: {'non_striker': 'GH Worker',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {3.6: {'non_striker': 'GH Worker',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {4.1: {'non_striker': 'JD Ryder',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'GH Worker'}},
#  {4.2: {'non_striker': 'GH Worker',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {4.3: {'non_striker': 'GH Worker',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {4.4: {'non_striker': 'GH Worker',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {4.5: {'non_striker': 'JD Ryder',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'GH Worker'}},
#  {4.6: {'non_striker': 'JD Ryder',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'GH Worker'}},
#  {5.1: {'non_striker': 'GH Worker',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {5.2: {'non_striker': 'GH Worker',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {5.3: {'non_striker': 'GH Worker',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {5.4: {'non_striker': 'JD Ryder',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'GH Worker'}},
#  {5.5: {'non_striker': 'JD Ryder',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'GH Worker'}},
#  {5.6: {'non_striker': 'JD Ryder',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'GH Worker'}},
#  {6.1: {'non_striker': 'GH Worker',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {6.2: {'non_striker': 'JD Ryder',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GH Worker'}},
#  {6.3: {'non_striker': 'JD Ryder',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'GH Worker',
#    'wicket': {'player_out': 'GH Worker',
#     'fielders': ['GD Phillips'],
#     'kind': 'stumped'}}},
#  {6.4: {'non_striker': 'JD Ryder',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'WA Young'}},
#  {6.5: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {6.6: {'non_striker': 'JD Ryder',
#    'bowler': 'TS Nethula',
#    'extras': {'wides': 1},
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'batsman': 'WA Young'}},
#  {6.7: {'non_striker': 'JD Ryder',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'WA Young'}},
#  {7.1: {'non_striker': 'JD Ryder',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'WA Young'}},
#  {7.2: {'non_striker': 'WA Young',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {7.3: {'non_striker': 'WA Young',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {7.4: {'non_striker': 'JD Ryder',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'WA Young'}},
#  {7.5: {'non_striker': 'WA Young',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'JD Ryder'}},
#  {7.6: {'non_striker': 'WA Young',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {8.1: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'JD Ryder'}},
#  {8.2: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {8.3: {'non_striker': 'JD Ryder',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'WA Young'}},
#  {8.4: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {8.5: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'extras': {'wides': 1},
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {8.6: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {8.7: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'JD Ryder'}},
#  {9.1: {'non_striker': 'JD Ryder',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'WA Young'}},
#  {9.2: {'non_striker': 'JD Ryder',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'WA Young'}},
#  {9.3: {'non_striker': 'JD Ryder',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'WA Young'}},
#  {9.4: {'non_striker': 'WA Young',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {9.5: {'non_striker': 'WA Young',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {9.6: {'non_striker': 'JD Ryder',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'WA Young'}},
#  {10.1: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JD Ryder'}},
#  {10.2: {'non_striker': 'JD Ryder',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'WA Young'}},
#  {10.3: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'JD Ryder'}},
#  {10.4: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {10.5: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder'}},
#  {10.6: {'non_striker': 'WA Young',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'JD Ryder',
#    'wicket': {'player_out': 'JD Ryder',
#     'fielders': ["RR O'Donnell"],
#     'kind': 'caught'}}},
#  {11.1: {'non_striker': 'TC Bruce',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'WA Young'}},
#  {11.2: {'non_striker': 'WA Young',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'TC Bruce'}},
#  {11.3: {'non_striker': 'WA Young',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'TC Bruce'}},
#  {11.4: {'non_striker': 'TC Bruce',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'WA Young',
#    'wicket': {'player_out': 'WA Young', 'kind': 'bowled'}}},
#  {11.5: {'non_striker': 'TC Bruce',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'DAJ Bracewell'}},
#  {11.6: {'non_striker': 'TC Bruce',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'DAJ Bracewell'}},
#  {12.1: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'TC Bruce'}},
#  {12.2: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'TC Bruce'}},
#  {12.3: {'non_striker': 'TC Bruce',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'DAJ Bracewell'}},
#  {12.4: {'non_striker': 'TC Bruce',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'DAJ Bracewell'}},
#  {12.5: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'TC Bruce'}},
#  {12.6: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'TS Nethula',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'TC Bruce'}},
#  {13.1: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'C Munro',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'TC Bruce'}},
#  {13.2: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'C Munro',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'TC Bruce'}},
#  {13.3: {'non_striker': 'TC Bruce',
#    'bowler': 'C Munro',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'DAJ Bracewell'}},
#  {13.4: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'C Munro',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'TC Bruce'}},
#  {13.5: {'non_striker': 'TC Bruce',
#    'bowler': 'C Munro',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'DAJ Bracewell'}},
#  {13.6: {'non_striker': 'TC Bruce',
#    'bowler': 'C Munro',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'DAJ Bracewell'}},
#  {14.1: {'non_striker': 'TC Bruce',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'DAJ Bracewell'}},
#  {14.2: {'non_striker': 'TC Bruce',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'DAJ Bracewell'}},
#  {14.3: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'TC Bruce'}},
#  {14.4: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'TC Bruce'}},
#  {14.5: {'non_striker': 'TC Bruce',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'DAJ Bracewell'}},
#  {14.6: {'non_striker': 'TC Bruce',
#    'bowler': 'AT Nidamanuru',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'DAJ Bracewell'}},
#  {15.1: {'non_striker': 'TC Bruce',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'DAJ Bracewell'}},
#  {15.2: {'non_striker': 'TC Bruce',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'DAJ Bracewell'}},
#  {15.3: {'non_striker': 'TC Bruce',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'DAJ Bracewell'}},
#  {15.4: {'non_striker': 'TC Bruce',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'DAJ Bracewell'}},
#  {15.5: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'TC Bruce'}},
#  {15.6: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'LH Ferguson',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'TC Bruce',
#    'wicket': {'player_out': 'TC Bruce',
#     'fielders': ["RR O'Donnell"],
#     'kind': 'caught'}}},
#  {16.1: {'non_striker': 'D Cleaver',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'DAJ Bracewell'}},
#  {16.2: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'D Cleaver'}},
#  {16.3: {'non_striker': 'DAJ Bracewell',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'D Cleaver'}},
#  {16.4: {'non_striker': 'D Cleaver',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'DAJ Bracewell'}},
#  {16.5: {'non_striker': 'D Cleaver',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'DAJ Bracewell'}},
#  {16.6: {'non_striker': 'D Cleaver',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'DAJ Bracewell'}},
#  {17.1: {'non_striker': 'D Cleaver',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'DAJ Bracewell'}},
#  {17.2: {'non_striker': 'D Cleaver',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'DAJ Bracewell',
#    'wicket': {'player_out': 'DAJ Bracewell',
#     'fielders': ['BJ Horne'],
#     'kind': 'caught'}}},
#  {17.3: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D Cleaver'}},
#  {17.4: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'D Cleaver'}},
#  {17.5: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'D Cleaver'}},
#  {17.6: {'non_striker': 'D Cleaver',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'JA Clarkson'}},
#  {18.1: {'non_striker': 'JA Clarkson',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'D Cleaver'}},
#  {18.2: {'non_striker': 'D Cleaver',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JA Clarkson'}},
#  {18.3: {'non_striker': 'JA Clarkson',
#    'bowler': 'BG Lister',
#    'extras': {'legbyes': 1},
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'batsman': 'D Cleaver'}},
#  {18.4: {'non_striker': 'D Cleaver',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JA Clarkson'}},
#  {18.5: {'non_striker': 'JA Clarkson',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'D Cleaver'}},
#  {18.6: {'non_striker': 'D Cleaver',
#    'bowler': 'BG Lister',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'JA Clarkson'}},
#  {19.1: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D Cleaver'}},
#  {19.2: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'D Cleaver'}},
#  {19.3: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'D Cleaver'}},
#  {19.4: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'extras': {'wides': 1},
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'batsman': 'D Cleaver'}},
#  {19.5: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'D Cleaver'}},
#  {19.6: {'non_striker': 'JA Clarkson',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'D Cleaver'}},
#  {19.7: {'non_striker': 'D Cleaver',
#    'bowler': 'SM Curran',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'JA Clarkson'}}]

# %%
count = 0
delivery_df_1st_innings = pd.DataFrame()
for index, row in final_df.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    winner = []
    win_by_runs = []
    win_by_wickets = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            winner.append(row['info.outcome.winner'])
            win_by_runs.append(row['info.outcome.by.runs'])
            win_by_wickets.append(row['info.outcome.by.wickets'])
            ball_of_match.append(key)
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'winner':winner,
            'win_by_runs':win_by_runs,
            'win_by_wickets':win_by_wickets,
            'ball':ball_of_match,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df_1st_innings = delivery_df_1st_innings.append(loop_df)

# %%
delivery_df_1st_innings.head()
# Out:
#    match_id                          teams       batting_team    winner  \
# 0         1  [Auckland, Central Districts]  Central Districts  Auckland
# 1         1  [Auckland, Central Districts]  Central Districts  Auckland
# 2         1  [Auckland, Central Districts]  Central Districts  Auckland
# 3         1  [Auckland, Central Districts]  Central Districts  Auckland
# 4         1  [Auckland, Central Districts]  Central Districts  Auckland
#
#    win_by_runs  win_by_wickets  ball  runs player_dismissed      city  \
# 0          NaN             5.0   0.1     0                0  Auckland
# 1          NaN             5.0   0.2     4                0  Auckland
# 2          NaN             5.0   0.3     2                0  Auckland
# 3          NaN             5.0   0.4     4                0  Auckland
# 4          NaN             5.0   0.5     4                0  Auckland
#
#                   venue
# 0  Eden Park Outer Oval
# 1  Eden Park Outer Oval
# 2  Eden Park Outer Oval
# 3  Eden Park Outer Oval
# 4  Eden Park Outer Oval

# %%
count = 0
delivery_df_2nd_innings = pd.DataFrame()
for index, row in final_df.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    winner = []
    win_by_runs = []
    win_by_wickets = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][1]['2nd innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][1]['2nd innings']['team'])
            teams.append(row['info.teams'])
            winner.append(row['info.outcome.winner'])
            win_by_runs.append(row['info.outcome.by.runs'])
            win_by_wickets.append(row['info.outcome.by.wickets'])
            ball_of_match.append(key)
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'winner':winner,
            'win_by_runs':win_by_runs,
            'win_by_wickets':win_by_wickets,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df_2nd_innings = delivery_df_2nd_innings.append(loop_df)

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id                          teams    winner  win_by_runs  \
# 0         1  [Auckland, Central Districts]  Auckland          NaN
# 1         1  [Auckland, Central Districts]  Auckland          NaN
# 2         1  [Auckland, Central Districts]  Auckland          NaN
# 3         1  [Auckland, Central Districts]  Auckland          NaN
# 4         1  [Auckland, Central Districts]  Auckland          NaN
#
#    win_by_wickets batting_team  ball  runs player_dismissed      city  \
# 0             5.0     Auckland   0.1     0                0  Auckland
# 1             5.0     Auckland   0.2     6                0  Auckland
# 2             5.0     Auckland   0.3     5                0  Auckland
# 3             5.0     Auckland   0.4     0                0  Auckland
# 4             5.0     Auckland   0.5     4                0  Auckland
#
#                   venue
# 0  Eden Park Outer Oval
# 1  Eden Park Outer Oval
# 2  Eden Park Outer Oval
# 3  Eden Park Outer Oval
# 4  Eden Park Outer Oval

# %%
run_data = delivery_df_1st_innings.groupby(['match_id', 'runs'])['runs'].count().reset_index(name="count")

# %%
run_data.head()
# Out:
#    match_id  runs  count
# 0         1     0     38
# 1         1     1     50
# 2         1     2      7
# 3         1     4     23
# 4         1     6      6

# %% [markdown]
# # batting and bowling team separation

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
# First Innings
delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings.apply(bowl,axis=1)

delivery_df_1st_innings.head()
# Out:
#    match_id                          teams       batting_team    winner  \
# 0         1  [Auckland, Central Districts]  Central Districts  Auckland
# 1         1  [Auckland, Central Districts]  Central Districts  Auckland
# 2         1  [Auckland, Central Districts]  Central Districts  Auckland
# 3         1  [Auckland, Central Districts]  Central Districts  Auckland
# 4         1  [Auckland, Central Districts]  Central Districts  Auckland
#
#    win_by_runs  win_by_wickets  ball  runs player_dismissed      city  \
# 0          NaN             5.0   0.1     0                0  Auckland
# 1          NaN             5.0   0.2     4                0  Auckland
# 2          NaN             5.0   0.3     2                0  Auckland
# 3          NaN             5.0   0.4     4                0  Auckland
# 4          NaN             5.0   0.5     4                0  Auckland
#
#                   venue bowling_team
# 0  Eden Park Outer Oval     Auckland
# 1  Eden Park Outer Oval     Auckland
# 2  Eden Park Outer Oval     Auckland
# 3  Eden Park Outer Oval     Auckland
# 4  Eden Park Outer Oval     Auckland

# %%
# Second Innings 
delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings.apply(bowl,axis=1)

delivery_df_2nd_innings.head()
# Out:
#    match_id                          teams    winner  win_by_runs  \
# 0         1  [Auckland, Central Districts]  Auckland          NaN
# 1         1  [Auckland, Central Districts]  Auckland          NaN
# 2         1  [Auckland, Central Districts]  Auckland          NaN
# 3         1  [Auckland, Central Districts]  Auckland          NaN
# 4         1  [Auckland, Central Districts]  Auckland          NaN
#
#    win_by_wickets batting_team  ball  runs player_dismissed      city  \
# 0             5.0     Auckland   0.1     0                0  Auckland
# 1             5.0     Auckland   0.2     6                0  Auckland
# 2             5.0     Auckland   0.3     5                0  Auckland
# 3             5.0     Auckland   0.4     0                0  Auckland
# 4             5.0     Auckland   0.5     4                0  Auckland
#
#                   venue       bowling_team
# 0  Eden Park Outer Oval  Central Districts
# 1  Eden Park Outer Oval  Central Districts
# 2  Eden Park Outer Oval  Central Districts
# 3  Eden Park Outer Oval  Central Districts
# 4  Eden Park Outer Oval  Central Districts

# %%
# Drop columns
delivery_df_1st_innings.drop(columns=['teams'],inplace=True)
delivery_df_2nd_innings.drop(columns=['teams'],inplace=True)

# %%
delivery_df_1st_innings['batting_team'].unique()
# Out:
# array(['Central Districts', 'Canterbury', 'Northern Districts',
#        'Wellington', 'Otago', 'Auckland'], dtype=object)

# %%
# First Innings
# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Thunder','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Thunder','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')

# delivery_df_1st_innings['batting_team'] = delivery_df_1st_innings['batting_team'].str.replace('Sylhet Royals','Sylhet Strikers')
# delivery_df_1st_innings['bowling_team'] = delivery_df_1st_innings['bowling_team'].str.replace('Sylhet Royals','Sylhet Strikers')

# Second Innings
# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Super Stars','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Thunder','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Thunder','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Sunrisers','Sylhet Strikers')

# delivery_df_2nd_innings['batting_team'] = delivery_df_2nd_innings['batting_team'].str.replace('Sylhet Royals','Sylhet Strikers')
# delivery_df_2nd_innings['bowling_team'] = delivery_df_2nd_innings['bowling_team'].str.replace('Sylhet Royals','Sylhet Strikers')

# %%
delivery_df_2nd_innings['batting_team'].unique()
# Out:
# array(['Auckland', 'Otago', 'Canterbury', 'Wellington',
#        'Central Districts', 'Northern Districts'], dtype=object)

# %% [markdown]
# # venue and city

# %%
delivery_df_2nd_innings.isnull().sum()
# Out:
# match_id                0
# winner                  0
# win_by_runs         10608
# win_by_wickets       8915
# batting_team            0
# ball                    0
# runs                    0
# player_dismissed        0
# city                    0
# venue                   0
# bowling_team            0
# dtype: int64

# %%
delivery_df_1st_innings['venue'].unique()
# Out:
# array(['Eden Park Outer Oval', 'Hagley Oval', 'Bay Oval', 'Saxton Oval',
#        'Basin Reserve', 'Mainpower Oval', 'Seddon Park', 'Molyneux Park',
#        'Pukekura Park', 'University Oval', "Queen's Park", 'McLean Park',
#        'Pukekura Park, New Plymouth', 'Hagley Oval, Christchurch',
#        'Eden Park Outer Oval, Auckland', 'University Oval, Dunedin',
#        'Basin Reserve, Wellington', 'Seddon Park, Hamilton',
#        'McLean Park, Napier', 'Bay Oval, Mount Maunganui',
#        'Fitzherbert Park, Palmerston North',
#        'John Davies Oval, Queenstown', 'Eden Park, Auckland',
#        'Cobham Oval (New), Whangarei', 'Saxton Oval, Nelson', 'Eden Park'],
#       dtype=object)

# %%
delivery_df_1st_innings['city'].unique()
# Out:
# array(['Auckland', 'Christchurch', 'Mount Maunganui', 'Nelson',
#        'Wellington', 'Rangiora', 'Hamilton', 'Alexandra', 'New Plymouth',
#        'Dunedin', 'Invercargill', 'Napier', 'Palmerston North',
#        'Queenstown', 'Whangarei'], dtype=object)

# %%
delivery_df_2nd_innings[delivery_df_2nd_innings['city'].isnull()]['venue'].value_counts()
# Out:
# Series([], Name: venue, dtype: int64)

# %%
# First Innings
# cities = np.where(delivery_df_1st_innings['city'].isnull(), delivery_df_1st_innings['venue'].str.split().apply(lambda x:x[0]), delivery_df_1st_innings['city'])
# delivery_df_1st_innings['city'] = cities

# Second Innings
# cities = np.where(delivery_df_2nd_innings['city'].isnull(), delivery_df_2nd_innings['venue'].str.split().apply(lambda x:x[0]), delivery_df_2nd_innings['city'])
# delivery_df_2nd_innings['city'] = cities

# %%
# Drop Venue Column

# First Innings
delivery_df_1st_innings.drop(columns=['venue'],inplace=True)
# Second Innings
delivery_df_2nd_innings.drop(columns=['venue'],inplace=True)

# %%
delivery_df_1st_innings['city'].value_counts()
# Out:
# Wellington          3710
# Auckland            3488
# Christchurch        3358
# Dunedin             2119
# Hamilton            2083
# New Plymouth        1955
# Mount Maunganui     1450
# Napier              1124
# Alexandra            744
# Queenstown           371
# Palmerston North     254
# Nelson               249
# Invercargill         125
# Rangiora             121
# Whangarei            112
# Name: city, dtype: int64

# %%
delivery_df_2nd_innings['city'].value_counts()
# Out:
# Wellington          3469
# Auckland            3110
# Christchurch        3083
# Dunedin             1933
# New Plymouth        1828
# Hamilton            1810
# Mount Maunganui     1416
# Napier              1012
# Alexandra            705
# Queenstown           322
# Nelson               255
# Palmerston North     250
# Rangiora             126
# Whangarei            120
# Invercargill          84
# Name: city, dtype: int64

# %%
# Keeping only those venues where played atleast 5 matches

# First Innings
eligible_cities = delivery_df_1st_innings['city'].value_counts()[delivery_df_1st_innings['city'].value_counts() > 300].index.tolist()
delivery_df_1st_innings = delivery_df_1st_innings[delivery_df_1st_innings['city'].isin(eligible_cities)]

# Second Innings
eligible_cities = delivery_df_2nd_innings['city'].value_counts()[delivery_df_2nd_innings['city'].value_counts() > 300].index.tolist()
delivery_df_2nd_innings = delivery_df_2nd_innings[delivery_df_2nd_innings['city'].isin(eligible_cities)]

# %% [markdown]
# # current score

# %%
# First Innings
delivery_df_1st_innings['current_score'] = delivery_df_1st_innings.groupby('match_id').cumsum()['runs']

# Second Innings
delivery_df_2nd_innings['current_score'] = delivery_df_2nd_innings.groupby('match_id').cumsum()['runs']

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id    winner  win_by_runs  win_by_wickets batting_team  ball  runs  \
# 0         1  Auckland          NaN             5.0     Auckland   0.1     0
# 1         1  Auckland          NaN             5.0     Auckland   0.2     6
# 2         1  Auckland          NaN             5.0     Auckland   0.3     5
# 3         1  Auckland          NaN             5.0     Auckland   0.4     0
# 4         1  Auckland          NaN             5.0     Auckland   0.5     4
#
#   player_dismissed      city       bowling_team  current_score
# 0                0  Auckland  Central Districts              0
# 1                0  Auckland  Central Districts              6
# 2                0  Auckland  Central Districts             11
# 3                0  Auckland  Central Districts             11
# 4                0  Auckland  Central Districts             15

# %% [markdown]
# # wicket left

# %%
# First Innings
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings['player_dismissed'].astype('int')
delivery_df_1st_innings['player_dismissed'] = delivery_df_1st_innings.groupby('match_id').cumsum()['player_dismissed']
delivery_df_1st_innings['wickets_left'] = 10 - delivery_df_1st_innings['player_dismissed']

delivery_df_1st_innings.head()
# Out:
#    match_id       batting_team    winner  win_by_runs  win_by_wickets  ball  \
# 0         1  Central Districts  Auckland          NaN             5.0   0.1
# 1         1  Central Districts  Auckland          NaN             5.0   0.2
# 2         1  Central Districts  Auckland          NaN             5.0   0.3
# 3         1  Central Districts  Auckland          NaN             5.0   0.4
# 4         1  Central Districts  Auckland          NaN             5.0   0.5
#
#    runs  player_dismissed      city bowling_team  current_score  wickets_left
# 0     0                 0  Auckland     Auckland              0            10
# 1     4                 0  Auckland     Auckland              4            10
# 2     2                 0  Auckland     Auckland              6            10
# 3     4                 0  Auckland     Auckland             10            10
# 4     4                 0  Auckland     Auckland             14            10

# %%
# Second Innings
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings['player_dismissed'].astype('int')
delivery_df_2nd_innings['player_dismissed'] = delivery_df_2nd_innings.groupby('match_id').cumsum()['player_dismissed']
delivery_df_2nd_innings['wickets_left'] = 10 - delivery_df_2nd_innings['player_dismissed']

delivery_df_2nd_innings.head()
# Out:
#    match_id    winner  win_by_runs  win_by_wickets batting_team  ball  runs  \
# 0         1  Auckland          NaN             5.0     Auckland   0.1     0
# 1         1  Auckland          NaN             5.0     Auckland   0.2     6
# 2         1  Auckland          NaN             5.0     Auckland   0.3     5
# 3         1  Auckland          NaN             5.0     Auckland   0.4     0
# 4         1  Auckland          NaN             5.0     Auckland   0.5     4
#
#    player_dismissed      city       bowling_team  current_score  wickets_left
# 0                 0  Auckland  Central Districts              0            10
# 1                 0  Auckland  Central Districts              6            10
# 2                 0  Auckland  Central Districts             11            10
# 3                 0  Auckland  Central Districts             11            10
# 4                 0  Auckland  Central Districts             15            10

# %% [markdown]
# # bowl delivered & bowl left

# %%
# First Innings
delivery_df_1st_innings['over'] = delivery_df_1st_innings['ball'].apply(lambda x:str(x).split(".")[0])
delivery_df_1st_innings['ball_no'] = delivery_df_1st_innings['ball'].apply(lambda x:str(x).split(".")[1])
delivery_df_1st_innings['balls_bowled'] = (delivery_df_1st_innings['over'].astype('int')*6) + delivery_df_1st_innings['ball_no'].astype('int')
delivery_df_1st_innings['balls_left'] = 120 - delivery_df_1st_innings['balls_bowled']
delivery_df_1st_innings['balls_left'] = delivery_df_1st_innings['balls_left'].apply(lambda x:0 if x<0 else x)

delivery_df_1st_innings.head()
# Out:
#    match_id       batting_team    winner  win_by_runs  win_by_wickets  ball  \
# 0         1  Central Districts  Auckland          NaN             5.0   0.1
# 1         1  Central Districts  Auckland          NaN             5.0   0.2
# 2         1  Central Districts  Auckland          NaN             5.0   0.3
# 3         1  Central Districts  Auckland          NaN             5.0   0.4
# 4         1  Central Districts  Auckland          NaN             5.0   0.5
#
#    runs  player_dismissed      city bowling_team  current_score  wickets_left  \
# 0     0                 0  Auckland     Auckland              0            10
# 1     4                 0  Auckland     Auckland              4            10
# 2     2                 0  Auckland     Auckland              6            10
# 3     4                 0  Auckland     Auckland             10            10
# 4     4                 0  Auckland     Auckland             14            10
#
#   over ball_no  balls_bowled  balls_left
# 0    0       1             1         119
# 1    0       2             2         118
# 2    0       3             3         117
# 3    0       4             4         116
# 4    0       5             5         115

# %%
# Second Innings
delivery_df_2nd_innings['over'] = delivery_df_2nd_innings['ball'].apply(lambda x:str(x).split(".")[0])
delivery_df_2nd_innings['ball_no'] = delivery_df_2nd_innings['ball'].apply(lambda x:str(x).split(".")[1])
delivery_df_2nd_innings['balls_bowled'] = (delivery_df_2nd_innings['over'].astype('int')*6) + delivery_df_2nd_innings['ball_no'].astype('int')
delivery_df_2nd_innings['balls_left'] = 120 - delivery_df_2nd_innings['balls_bowled']
delivery_df_2nd_innings['balls_left'] = delivery_df_2nd_innings['balls_left'].apply(lambda x:0 if x<0 else x)

delivery_df_2nd_innings.head()
# Out:
#    match_id    winner  win_by_runs  win_by_wickets batting_team  ball  runs  \
# 0         1  Auckland          NaN             5.0     Auckland   0.1     0
# 1         1  Auckland          NaN             5.0     Auckland   0.2     6
# 2         1  Auckland          NaN             5.0     Auckland   0.3     5
# 3         1  Auckland          NaN             5.0     Auckland   0.4     0
# 4         1  Auckland          NaN             5.0     Auckland   0.5     4
#
#    player_dismissed      city       bowling_team  current_score  wickets_left  \
# 0                 0  Auckland  Central Districts              0            10
# 1                 0  Auckland  Central Districts              6            10
# 2                 0  Auckland  Central Districts             11            10
# 3                 0  Auckland  Central Districts             11            10
# 4                 0  Auckland  Central Districts             15            10
#
#   over ball_no  balls_bowled  balls_left
# 0    0       1             1         119
# 1    0       2             2         118
# 2    0       3             3         117
# 3    0       4             4         116
# 4    0       5             5         115

# %% [markdown]
# # current run rate

# %%
# First Innings
delivery_df_1st_innings['crr'] = round((delivery_df_1st_innings['current_score']*6)/delivery_df_1st_innings['balls_bowled'], 2)

# Second Innings
delivery_df_2nd_innings['crr'] = round((delivery_df_2nd_innings['current_score']*6)/delivery_df_2nd_innings['balls_bowled'], 2)

# %%
delivery_df_2nd_innings.head()
# Out:
#    match_id    winner  win_by_runs  win_by_wickets batting_team  ball  runs  \
# 0         1  Auckland          NaN             5.0     Auckland   0.1     0
# 1         1  Auckland          NaN             5.0     Auckland   0.2     6
# 2         1  Auckland          NaN             5.0     Auckland   0.3     5
# 3         1  Auckland          NaN             5.0     Auckland   0.4     0
# 4         1  Auckland          NaN             5.0     Auckland   0.5     4
#
#    player_dismissed      city       bowling_team  current_score  wickets_left  \
# 0                 0  Auckland  Central Districts              0            10
# 1                 0  Auckland  Central Districts              6            10
# 2                 0  Auckland  Central Districts             11            10
# 3                 0  Auckland  Central Districts             11            10
# 4                 0  Auckland  Central Districts             15            10
#
#   over ball_no  balls_bowled  balls_left   crr
# 0    0       1             1         119   0.0
# 1    0       2             2         118  18.0
# 2    0       3             3         117  22.0
# 3    0       4             4         116  16.5
# 4    0       5             5         115  18.0

# %% [markdown]
# # Score and Win Probabilty (before the start of the match and during the first innings)

# %% [markdown]
# # total score counting according to match

# %%
total_df = delivery_df_1st_innings.groupby('match_id').sum()['runs'].reset_index()
score_probability_output = delivery_df_1st_innings.merge(total_df,on='match_id')

score_probability_output.head()
# Out:
#    match_id       batting_team    winner  win_by_runs  win_by_wickets  ball  \
# 0         1  Central Districts  Auckland          NaN             5.0   0.1
# 1         1  Central Districts  Auckland          NaN             5.0   0.2
# 2         1  Central Districts  Auckland          NaN             5.0   0.3
# 3         1  Central Districts  Auckland          NaN             5.0   0.4
# 4         1  Central Districts  Auckland          NaN             5.0   0.5
#
#    runs_x  player_dismissed      city bowling_team  current_score  \
# 0       0                 0  Auckland     Auckland              0
# 1       4                 0  Auckland     Auckland              4
# 2       2                 0  Auckland     Auckland              6
# 3       4                 0  Auckland     Auckland             10
# 4       4                 0  Auckland     Auckland             14
#
#    wickets_left over ball_no  balls_bowled  balls_left   crr  runs_y
# 0            10    0       1             1         119   0.0     192
# 1            10    0       2             2         118  12.0     192
# 2            10    0       3             3         117  12.0     192
# 3            10    0       4             4         116  15.0     192
# 4            10    0       5             5         115  16.8     192

# %% [markdown]
# # counting runs in remaining balls

# %%
score_probability_output['runs_in_remaining_ball'] = score_probability_output['runs_y'] - score_probability_output['current_score']

score_probability_output.head()
# Out:
#    match_id       batting_team    winner  win_by_runs  win_by_wickets  ball  \
# 0         1  Central Districts  Auckland          NaN             5.0   0.1
# 1         1  Central Districts  Auckland          NaN             5.0   0.2
# 2         1  Central Districts  Auckland          NaN             5.0   0.3
# 3         1  Central Districts  Auckland          NaN             5.0   0.4
# 4         1  Central Districts  Auckland          NaN             5.0   0.5
#
#    runs_x  player_dismissed      city bowling_team  current_score  \
# 0       0                 0  Auckland     Auckland              0
# 1       4                 0  Auckland     Auckland              4
# 2       2                 0  Auckland     Auckland              6
# 3       4                 0  Auckland     Auckland             10
# 4       4                 0  Auckland     Auckland             14
#
#    wickets_left over ball_no  balls_bowled  balls_left   crr  runs_y  \
# 0            10    0       1             1         119   0.0     192
# 1            10    0       2             2         118  12.0     192
# 2            10    0       3             3         117  12.0     192
# 3            10    0       4             4         116  15.0     192
# 4            10    0       5             5         115  16.8     192
#
#    runs_in_remaining_ball
# 0                     192
# 1                     188
# 2                     186
# 3                     182
# 4                     178

# %% [markdown]
# # consider batting team win

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

score_probability_output['result_first_innings'] = score_probability_output.apply(result, axis=1)

score_probability_output.head()
# Out:
#    match_id       batting_team    winner  win_by_runs  win_by_wickets  ball  \
# 0         1  Central Districts  Auckland          NaN             5.0   0.1
# 1         1  Central Districts  Auckland          NaN             5.0   0.2
# 2         1  Central Districts  Auckland          NaN             5.0   0.3
# 3         1  Central Districts  Auckland          NaN             5.0   0.4
# 4         1  Central Districts  Auckland          NaN             5.0   0.5
#
#    runs_x  player_dismissed      city bowling_team  current_score  \
# 0       0                 0  Auckland     Auckland              0
# 1       4                 0  Auckland     Auckland              4
# 2       2                 0  Auckland     Auckland              6
# 3       4                 0  Auckland     Auckland             10
# 4       4                 0  Auckland     Auckland             14
#
#    wickets_left over ball_no  balls_bowled  balls_left   crr  runs_y  \
# 0            10    0       1             1         119   0.0     192
# 1            10    0       2             2         118  12.0     192
# 2            10    0       3             3         117  12.0     192
# 3            10    0       4             4         116  15.0     192
# 4            10    0       5             5         115  16.8     192
#
#    runs_in_remaining_ball  result_first_innings
# 0                     192                     0
# 1                     188                     0
# 2                     186                     0
# 3                     182                     0
# 4                     178                     0

# %% [markdown]
# # final data for score probabilty

# %%
final_score_probability_df = score_probability_output[['batting_team','bowling_team','city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left','crr', 'runs_in_remaining_ball']]
final_score_probability_df.head()
# Out:
#         batting_team bowling_team      city  current_score  balls_bowled  \
# 0  Central Districts     Auckland  Auckland              0             1
# 1  Central Districts     Auckland  Auckland              4             2
# 2  Central Districts     Auckland  Auckland              6             3
# 3  Central Districts     Auckland  Auckland             10             4
# 4  Central Districts     Auckland  Auckland             14             5
#
#    balls_left  wickets_left   crr  runs_in_remaining_ball
# 0         119            10   0.0                     192
# 1         118            10  12.0                     188
# 2         117            10  12.0                     186
# 3         116            10  15.0                     182
# 4         115            10  16.8                     178

# %%
final_score_probability_df = final_score_probability_df[final_score_probability_df['balls_left'] != 0]
final_score_probability_df
# Out:
#             batting_team        bowling_team      city  current_score  \
# 0      Central Districts            Auckland  Auckland              0
# 1      Central Districts            Auckland  Auckland              4
# 2      Central Districts            Auckland  Auckland              6
# 3      Central Districts            Auckland  Auckland             10
# 4      Central Districts            Auckland  Auckland             14
# ...                  ...                 ...       ...            ...
# 20396              Otago  Northern Districts  Hamilton            135
# 20397              Otago  Northern Districts  Hamilton            135
# 20398              Otago  Northern Districts  Hamilton            136
# 20399              Otago  Northern Districts  Hamilton            137
# 20400              Otago  Northern Districts  Hamilton            139
#
#        balls_bowled  balls_left  wickets_left    crr  runs_in_remaining_ball
# 0                 1         119            10   0.00                     192
# 1                 2         118            10  12.00                     188
# 2                 3         117            10  12.00                     186
# 3                 4         116            10  15.00                     182
# 4                 5         115            10  16.80                     178
# ...             ...         ...           ...    ...                     ...
# 20396           115           5             5   7.04                       8
# 20397           116           4             5   6.98                       8
# 20398           117           3             5   6.97                       7
# 20399           118           2             5   6.97                       6
# 20400           119           1             5   7.01                       4
#
# [20222 rows x 9 columns]

# %% [markdown]
# # final innings score probability data extraction

# %%
pickle.dump(final_score_probability_df, open('ssm_mens_first_innings_score.pkl','wb'))

# %% [markdown]
# # win probabilty

# %%
final_win_probability_df = score_probability_output[[
    'batting_team',
    'bowling_team',
    'city',
    'runs_y',
    'result_first_innings'
]]

final_win_probability_df.head()
# Out:
#         batting_team bowling_team      city  runs_y  result_first_innings
# 0  Central Districts     Auckland  Auckland     192                     0
# 1  Central Districts     Auckland  Auckland     192                     0
# 2  Central Districts     Auckland  Auckland     192                     0
# 3  Central Districts     Auckland  Auckland     192                     0
# 4  Central Districts     Auckland  Auckland     192                     0

# %% [markdown]
# # final first innings win data extraction

# %%
pickle.dump(final_win_probability_df, open('ssm_mens_first_innings_win.pkl','wb'))

# %% [markdown]
# # Win Probabilty (during the second innings)

# %% [markdown]
# # target runs from first innings

# %%
total_score_df = delivery_df_1st_innings.groupby([
    'match_id',
]).sum()['runs'].reset_index()

total_score_df.head()
# Out:
#    match_id  runs
# 0         1   192
# 1         2   217
# 2         3   214
# 3         5   145
# 4         7   212

# %%
total_score_df['target_runs'] = total_score_df['runs'] + 1
total_score_df.drop(columns=['runs'], inplace=True)

total_score_df.head()
# Out:
#    match_id  target_runs
# 0         1          193
# 1         2          218
# 2         3          215
# 3         5          146
# 4         7          213

# %% [markdown]
# # merge with second innings data

# %%
final_2nd_innings_win_df = delivery_df_2nd_innings.merge(total_score_df, on='match_id')
final_2nd_innings_win_df.head()
# Out:
#    match_id    winner  win_by_runs  win_by_wickets batting_team  ball  runs  \
# 0         1  Auckland          NaN             5.0     Auckland   0.1     0
# 1         1  Auckland          NaN             5.0     Auckland   0.2     6
# 2         1  Auckland          NaN             5.0     Auckland   0.3     5
# 3         1  Auckland          NaN             5.0     Auckland   0.4     0
# 4         1  Auckland          NaN             5.0     Auckland   0.5     4
#
#    player_dismissed      city       bowling_team  current_score  wickets_left  \
# 0                 0  Auckland  Central Districts              0            10
# 1                 0  Auckland  Central Districts              6            10
# 2                 0  Auckland  Central Districts             11            10
# 3                 0  Auckland  Central Districts             11            10
# 4                 0  Auckland  Central Districts             15            10
#
#   over ball_no  balls_bowled  balls_left   crr  target_runs
# 0    0       1             1         119   0.0          193
# 1    0       2             2         118  18.0          193
# 2    0       3             3         117  22.0          193
# 3    0       4             4         116  16.5          193
# 4    0       5             5         115  18.0          193

# %% [markdown]
# # runs left

# %%
final_2nd_innings_win_df['runs_left'] = final_2nd_innings_win_df['target_runs'] - final_2nd_innings_win_df['current_score']
final_2nd_innings_win_df.head()
# Out:
#    match_id    winner  win_by_runs  win_by_wickets batting_team  ball  runs  \
# 0         1  Auckland          NaN             5.0     Auckland   0.1     0
# 1         1  Auckland          NaN             5.0     Auckland   0.2     6
# 2         1  Auckland          NaN             5.0     Auckland   0.3     5
# 3         1  Auckland          NaN             5.0     Auckland   0.4     0
# 4         1  Auckland          NaN             5.0     Auckland   0.5     4
#
#    player_dismissed      city       bowling_team  current_score  wickets_left  \
# 0                 0  Auckland  Central Districts              0            10
# 1                 0  Auckland  Central Districts              6            10
# 2                 0  Auckland  Central Districts             11            10
# 3                 0  Auckland  Central Districts             11            10
# 4                 0  Auckland  Central Districts             15            10
#
#   over ball_no  balls_bowled  balls_left   crr  target_runs  runs_left
# 0    0       1             1         119   0.0          193        193
# 1    0       2             2         118  18.0          193        187
# 2    0       3             3         117  22.0          193        182
# 3    0       4             4         116  16.5          193        182
# 4    0       5             5         115  18.0          193        178

# %% [markdown]
# # required run rate

# %%
final_2nd_innings_win_df['rrr'] = round((final_2nd_innings_win_df['runs_left']*6)/final_2nd_innings_win_df['balls_left'], 2)

final_2nd_innings_win_df.head()
# Out:
#    match_id    winner  win_by_runs  win_by_wickets batting_team  ball  runs  \
# 0         1  Auckland          NaN             5.0     Auckland   0.1     0
# 1         1  Auckland          NaN             5.0     Auckland   0.2     6
# 2         1  Auckland          NaN             5.0     Auckland   0.3     5
# 3         1  Auckland          NaN             5.0     Auckland   0.4     0
# 4         1  Auckland          NaN             5.0     Auckland   0.5     4
#
#    player_dismissed      city       bowling_team  current_score  wickets_left  \
# 0                 0  Auckland  Central Districts              0            10
# 1                 0  Auckland  Central Districts              6            10
# 2                 0  Auckland  Central Districts             11            10
# 3                 0  Auckland  Central Districts             11            10
# 4                 0  Auckland  Central Districts             15            10
#
#   over ball_no  balls_bowled  balls_left   crr  target_runs  runs_left   rrr
# 0    0       1             1         119   0.0          193        193  9.73
# 1    0       2             2         118  18.0          193        187  9.51
# 2    0       3             3         117  22.0          193        182  9.33
# 3    0       4             4         116  16.5          193        182  9.41
# 4    0       5             5         115  18.0          193        178  9.29

# %%
final_2nd_innings_win_df.isnull().sum()
# Out:
# match_id                0
# winner                  0
# win_by_runs         10366
# win_by_wickets       8322
# batting_team            0
# ball                    0
# runs                    0
# player_dismissed        0
# city                    0
# bowling_team            0
# current_score           0
# wickets_left            0
# over                    0
# ball_no                 0
# balls_bowled            0
# balls_left              0
# crr                     0
# target_runs             0
# runs_left               0
# rrr                     1
# dtype: int64

# %%
final_2nd_innings_win_df = final_2nd_innings_win_df[final_2nd_innings_win_df['balls_left'] != 0]

# %%
final_2nd_innings_win_df.isnull().sum()
# Out:
# match_id                0
# winner                  0
# win_by_runs         10360
# win_by_wickets       8267
# batting_team            0
# ball                    0
# runs                    0
# player_dismissed        0
# city                    0
# bowling_team            0
# current_score           0
# wickets_left            0
# over                    0
# ball_no                 0
# balls_bowled            0
# balls_left              0
# crr                     0
# target_runs             0
# runs_left               0
# rrr                     0
# dtype: int64

# %% [markdown]
# # consider batting team win

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

final_2nd_innings_win_df['result'] = final_2nd_innings_win_df.apply(result, axis=1)

final_2nd_innings_win_df.head()
# Out:
#    match_id    winner  win_by_runs  win_by_wickets batting_team  ball  runs  \
# 0         1  Auckland          NaN             5.0     Auckland   0.1     0
# 1         1  Auckland          NaN             5.0     Auckland   0.2     6
# 2         1  Auckland          NaN             5.0     Auckland   0.3     5
# 3         1  Auckland          NaN             5.0     Auckland   0.4     0
# 4         1  Auckland          NaN             5.0     Auckland   0.5     4
#
#    player_dismissed      city       bowling_team  ...  wickets_left  over  \
# 0                 0  Auckland  Central Districts  ...            10     0
# 1                 0  Auckland  Central Districts  ...            10     0
# 2                 0  Auckland  Central Districts  ...            10     0
# 3                 0  Auckland  Central Districts  ...            10     0
# 4                 0  Auckland  Central Districts  ...            10     0
#
#   ball_no balls_bowled  balls_left   crr  target_runs  runs_left   rrr  result
# 0       1            1         119   0.0          193        193  9.73       1
# 1       2            2         118  18.0          193        187  9.51       1
# 2       3            3         117  22.0          193        182  9.33       1
# 3       4            4         116  16.5          193        182  9.41       1
# 4       5            5         115  18.0          193        178  9.29       1
#
# [5 rows x 21 columns]

# %% [markdown]
# # final data for second innings win

# %%
final_2nd_innings_win_df = final_2nd_innings_win_df[[
    'batting_team',
    'bowling_team',
    'city',
    'current_score',
    'target_runs',
    'runs_left',
    'balls_left',
    'wickets_left',
    'crr',
    'rrr',
    'result'
]]

final_2nd_innings_win_df.head()
# Out:
#   batting_team       bowling_team      city  current_score  target_runs  \
# 0     Auckland  Central Districts  Auckland              0          193
# 1     Auckland  Central Districts  Auckland              6          193
# 2     Auckland  Central Districts  Auckland             11          193
# 3     Auckland  Central Districts  Auckland             11          193
# 4     Auckland  Central Districts  Auckland             15          193
#
#    runs_left  balls_left  wickets_left   crr   rrr  result
# 0        193         119            10   0.0  9.73       1
# 1        187         118            10  18.0  9.51       1
# 2        182         117            10  22.0  9.33       1
# 3        182         116            10  16.5  9.41       1
# 4        178         115            10  18.0  9.29       1

# %% [markdown]
# # final second innings win data extraction

# %%
pickle.dump(final_2nd_innings_win_df, open('ssm_mens_second_innings_win.pkl','wb'))

# %% [markdown]
# # Machine Learning Model

# %%
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, accuracy_score, confusion_matrix, classification_report

from sklearn.model_selection import train_test_split

# %% [markdown]
# # score probability

# %%
#load data
score_portability_df = pickle.load(open('ssm_mens_first_innings_score.pkl','rb'))
score_portability_df.shape
# Out:
# (20222, 9)

# %%
score_portability_df.to_csv(r'ssm_mens_first_innings_score.csv', index=False, header=True)
score_portability_df = pd.read_csv(r'ssm_mens_first_innings_score.csv')

# %%
score_portability_df
# Out:
#             batting_team        bowling_team      city  current_score  \
# 0      Central Districts            Auckland  Auckland              0
# 1      Central Districts            Auckland  Auckland              4
# 2      Central Districts            Auckland  Auckland              6
# 3      Central Districts            Auckland  Auckland             10
# 4      Central Districts            Auckland  Auckland             14
# ...                  ...                 ...       ...            ...
# 20217              Otago  Northern Districts  Hamilton            135
# 20218              Otago  Northern Districts  Hamilton            135
# 20219              Otago  Northern Districts  Hamilton            136
# 20220              Otago  Northern Districts  Hamilton            137
# 20221              Otago  Northern Districts  Hamilton            139
#
#        balls_bowled  balls_left  wickets_left    crr  runs_in_remaining_ball
# 0                 1         119            10   0.00                     192
# 1                 2         118            10  12.00                     188
# 2                 3         117            10  12.00                     186
# 3                 4         116            10  15.00                     182
# 4                 5         115            10  16.80                     178
# ...             ...         ...           ...    ...                     ...
# 20217           115           5             5   7.04                       8
# 20218           116           4             5   6.98                       8
# 20219           117           3             5   6.97                       7
# 20220           118           2             5   6.97                       6
# 20221           119           1             5   7.01                       4
#
# [20222 rows x 9 columns]

# %%
score_portability_df.isnull().sum()
# Out:
# batting_team              0
# bowling_team              0
# city                      0
# current_score             0
# balls_bowled              0
# balls_left                0
# wickets_left              0
# crr                       0
# runs_in_remaining_ball    0
# dtype: int64

# %%
X = score_portability_df.drop(columns=['runs_in_remaining_ball'])
y = score_portability_df['runs_in_remaining_ball'].values

# X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.05, random_state=1)

# %%
X
# Out:
#             batting_team        bowling_team      city  current_score  \
# 0      Central Districts            Auckland  Auckland              0
# 1      Central Districts            Auckland  Auckland              4
# 2      Central Districts            Auckland  Auckland              6
# 3      Central Districts            Auckland  Auckland             10
# 4      Central Districts            Auckland  Auckland             14
# ...                  ...                 ...       ...            ...
# 20217              Otago  Northern Districts  Hamilton            135
# 20218              Otago  Northern Districts  Hamilton            135
# 20219              Otago  Northern Districts  Hamilton            136
# 20220              Otago  Northern Districts  Hamilton            137
# 20221              Otago  Northern Districts  Hamilton            139
#
#        balls_bowled  balls_left  wickets_left    crr
# 0                 1         119            10   0.00
# 1                 2         118            10  12.00
# 2                 3         117            10  12.00
# 3                 4         116            10  15.00
# 4                 5         115            10  16.80
# ...             ...         ...           ...    ...
# 20217           115           5             5   7.04
# 20218           116           4             5   6.98
# 20219           117           3             5   6.97
# 20220           118           2             5   6.97
# 20221           119           1             5   7.01
#
# [20222 rows x 8 columns]

# %%
# X.to_csv(r'X_input_ssm_mens_first_innings_score.csv', index=False, header=True)
# X = pd.read_csv(r'X_input_ssm_mens_first_innings_score.csv')
# X

pickle.dump(X, open('X_input_ssm_mens_first_innings_score.pkl','wb'))
X = pickle.load(open('X_input_ssm_mens_first_innings_score.pkl','rb'))
X
# Out:
#             batting_team        bowling_team      city  current_score  \
# 0      Central Districts            Auckland  Auckland              0
# 1      Central Districts            Auckland  Auckland              4
# 2      Central Districts            Auckland  Auckland              6
# 3      Central Districts            Auckland  Auckland             10
# 4      Central Districts            Auckland  Auckland             14
# ...                  ...                 ...       ...            ...
# 20217              Otago  Northern Districts  Hamilton            135
# 20218              Otago  Northern Districts  Hamilton            135
# 20219              Otago  Northern Districts  Hamilton            136
# 20220              Otago  Northern Districts  Hamilton            137
# 20221              Otago  Northern Districts  Hamilton            139
#
#        balls_bowled  balls_left  wickets_left    crr
# 0                 1         119            10   0.00
# 1                 2         118            10  12.00
# 2                 3         117            10  12.00
# 3                 4         116            10  15.00
# 4                 5         115            10  16.80
# ...             ...         ...           ...    ...
# 20217           115           5             5   7.04
# 20218           116           4             5   6.98
# 20219           117           3             5   6.97
# 20220           118           2             5   6.97
# 20221           119           1             5   7.01
#
# [20222 rows x 8 columns]

# %%
# y_train

# %%
# trf = ColumnTransformer([
#     ('trf',OneHotEncoder(sparse=False,drop='first'), ['batting_team','bowling_team','city'])
# ]
# ,remainder='passthrough')

transformer = make_column_transformer(
    (OneHotEncoder(sparse=False, drop='first'), [
      'batting_team','bowling_team','city'
    ]), 
    (StandardScaler(), [
      'current_score', 'balls_bowled', 'balls_left', 'wickets_left', 'crr'
    ])  
)

# %%
transformer.fit(X)
# Out:
# ColumnTransformer(transformers=[('onehotencoder',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  ['batting_team', 'bowling_team', 'city']),
#                                 ('standardscaler', StandardScaler(),
#                                  ['current_score', 'balls_bowled', 'balls_left',
#                                   'wickets_left', 'crr'])])

# %%
X_train,X_test,y_train,y_test = train_test_split(transformer.transform(X), y, test_size=0.05, random_state=1)
X_train
# Out:
# array([[ 0.        ,  0.        ,  0.        , ..., -0.01130109,
#          0.37487034,  0.14542181],
#        [ 0.        ,  1.        ,  0.        , ..., -1.26600178,
#         -0.53516903,  0.56640232],
#        [ 0.        ,  0.        ,  1.        , ..., -1.70368807,
#         -1.44520841,  1.3645112 ],
#        ...,
#        [ 0.        ,  1.        ,  0.        , ...,  0.2221316 ,
#          0.82989002,  0.50500933],
#        [ 1.        ,  0.        ,  0.        , ...,  1.65190681,
#          1.28490971,  0.0138654 ],
#        [ 1.        ,  0.        ,  0.        , ..., -1.41189721,
#         -1.90022809,  1.13648009]])

# %%
y_train
# Out:
# array([127,  24,   1, ...,  82, 149,  27])

# %% [markdown]
# # XgBoosting

# %%
# pipe = Pipeline(steps=[
#     ('step1', trf),
#     ('step2', StandardScaler()),
#     ('step3', XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=20, random_state=1))
# ])

xgb = XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=20, random_state=1)

xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.2, max_delta_step=0,
#              max_depth=20, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
# y_pred = pipe.predict(X_test)
# print('R-Square Score: '+str(r2_score(y_test, y_pred)))
# print('Mean Absolute Error: '+str(mean_absolute_error(y_test, y_pred)))

y_pred = xgb.predict(X_test)
print('R-Square Score: '+str(r2_score(y_test, y_pred)))
print('Mean Absolute Error: '+str(mean_absolute_error(y_test, y_pred)))
# Out:
# R-Square Score: 0.9769418179624366
# Mean Absolute Error: 3.7427340736796735

# %%
# predictions_xgb = pipe.predict(X_test)
# sample_xgb = pd.DataFrame(predictions_xgb, columns=['Predict'])
# sample_xgb['Actual']=y_test
# sample_xgb.head(20)

predictions_xgb = xgb.predict(X_test)
sample_xgb = pd.DataFrame(predictions_xgb, columns=['Predict'])
sample_xgb['Actual']=y_test
sample_xgb.head(20)
# Out:
#        Predict  Actual
# 0    61.338509      61
# 1   188.030823     195
# 2    81.008232      83
# 3    66.269432      65
# 4    79.215179      86
# 5   152.128525     151
# 6   122.976143     130
# 7    40.989964      39
# 8    67.539520      67
# 9   158.819702     162
# 10   48.434109      44
# 11  135.110779     137
# 12   97.849007      99
# 13   96.634705      96
# 14    1.859040       2
# 15  146.843292     149
# 16   44.956860      50
# 17   81.586296      79
# 18  223.999771     224
# 19   59.621273      60

# %%
score_portability_df['city'].unique()
# Out:
# array(['Auckland', 'Christchurch', 'Mount Maunganui', 'Wellington',
#        'Hamilton', 'Alexandra', 'New Plymouth', 'Dunedin', 'Napier',
#        'Queenstown'], dtype=object)

# %%
score_portability_df['batting_team'].unique()
# Out:
# array(['Central Districts', 'Canterbury', 'Northern Districts',
#        'Wellington', 'Otago', 'Auckland'], dtype=object)

# %% [markdown]
# # result count first way

# %%
input_df = pd.DataFrame({'batting_team': ['Auckland'], 'bowling_team': ['Central Districts'], 'city': ['New Plymouth'], 'current_score': [170], 'balls_bowled': [108], 'balls_left': [12], 'wickets_left': [6], 'crr': [9.44]})
result = xgb.predict(transformer.transform(input_df))[0]

#math.floor(result)
print('Probable Score: '+str(math.floor(result + 170)-8)+ ' to '+str(math.floor(result + 170)+4))
# Out:
# Probable Score: 183 to 195

# %% [markdown]
# # result count second way

# %%
input_df = pd.DataFrame([['Auckland', 'Central Districts', 'New Plymouth', 60, 90, 30, 10, 4.0]], columns=['batting_team', 'bowling_team', 'city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left', 'crr'])
result = xgb.predict(transformer.transform(input_df))


#math.floor(result)
print('Probable Score: '+str(math.floor(result + 60)-8)+ ' to '+str(math.floor(result + 60)+2))
# Out:
# Probable Score: 90 to 100

# %% [markdown]
# # Random Forest

# %%
# pipe_rf = Pipeline(steps=[
#     ('step1', trf),
#     ('step2', StandardScaler()),
#     ('step3', RandomForestRegressor())
# ])

rf = RandomForestRegressor()

rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# y_pred_rf = pipe_rf.predict(X_test)
# print('R-Square Score: '+str(r2_score(y_test, y_pred_rf)))
# print('Mean Absolute Error: '+str(mean_absolute_error(y_test, y_pred_rf)))

y_pred_rf = rf.predict(X_test)
print('R-Square Score: '+str(r2_score(y_test, y_pred_rf)))
print('Mean Absolute Error: '+str(mean_absolute_error(y_test, y_pred_rf)))
# Out:
# R-Square Score: 0.9726604559717832
# Mean Absolute Error: 4.616420407491059

# %%
# predictions_rf = pipe_rf.predict(X_test)
# sample_rf = pd.DataFrame(predictions_rf, columns=['Predict'])
# sample_rf['Actual']=y_test
# sample_rf.head(20)

predictions_rf = rf.predict(X_test)
sample_rf = pd.DataFrame(predictions_rf, columns=['Predict'])
sample_rf['Actual']=y_test
sample_rf.head(20)
# Out:
#        Predict  Actual
# 0    59.920000      61
# 1   192.000000     195
# 2    82.300000      83
# 3    64.810000      65
# 4    81.420000      86
# 5   148.360000     151
# 6   123.940000     130
# 7    42.370000      39
# 8    66.420000      67
# 9   158.830000     162
# 10   47.356667      44
# 11  134.275000     137
# 12   99.370000      99
# 13  100.570000      96
# 14    3.060000       2
# 15  146.460000     149
# 16   57.930000      50
# 17   83.180000      79
# 18  223.870000     224
# 19   59.480000      60

# %%
input_df = pd.DataFrame([['Auckland', 'Central Districts', 'New Plymouth', 60, 90, 30, 10, 4.0]], columns=['batting_team', 'bowling_team', 'city', 'current_score', 'balls_bowled', 'balls_left', 'wickets_left', 'crr'])
result = rf.predict(transformer.transform(input_df))

#math.floor(result)
print('Probable Score: '+str(math.floor(result + 60)-8)+ ' to '+str(math.floor(result + 60)+2))
# Out:
# Probable Score: 94 to 104

# %% [markdown]
# # Comparison Tables "Predict and Actual"

# %%
def display_dfs(dfs, gap=50, justify='center'):
    html = ""
    for title, df in dfs.items():  
        df_html = df._repr_html_()
        cur_html = f'<div> <h4>{title}</h4> {df_html}</div>'
        html +=  cur_html
    html= f"""
    <div style="display:flex; gap:{gap}px; justify-content:{justify};">
        {html}
    </div>
    """
    display_html(html, raw=True)


dfs = {'XGBoost Regressor': sample_xgb.head(20), 
       'Random Forest Regressor': sample_rf.head(20)}
# dfs = {'Model-1': sample3.head(20),
#        'Model-2': sample4.head(20),
#        'Model-3': sample5.head(20),
#        'Model-4': sample6.head(20)}
display_dfs(dfs, justify='flex-start')
# Out:
#     <div style="display:flex; gap:50px; justify-content:flex-start;">
#         <div> <h4>XGBoost Regressor</h4> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predict</th>
#       <th>Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>61.338509</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>188.030823</td>
#       <td>195</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>81.008232</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>66.269432</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>79.215179</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>152.128525</td>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>122.976143</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>40.989964</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>67.539520</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>158.819702</td>
#       <td>162</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>48.434109</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>135.110779</td>
#       <td>137</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>97.849007</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>96.634705</td>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1.859040</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>146.843292</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>44.956860</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>81.586296</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>223.999771</td>
#       <td>224</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>59.621273</td>
#       <td>60</td>
#     </tr>
#   </tbody>
# </table>
# </div></div><div> <h4>Random Forest Regressor</h4> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Predict</th>
#       <th>Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>59.920000</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>192.000000</td>
#       <td>195</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>82.300000</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>64.810000</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>81.420000</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>148.360000</td>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>123.940000</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>42.370000</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>66.420000</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>158.830000</td>
#       <td>162</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>47.356667</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>134.275000</td>
#       <td>137</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>99.370000</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>100.570000</td>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>3.060000</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>146.460000</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>57.930000</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>83.180000</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>223.870000</td>
#       <td>224</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>59.480000</td>
#       <td>60</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#     </div>

# %% [markdown]
# # Comparison Graph

# %%
plt.rcParams["figure.figsize"] = (18, 14) 

plt.subplot(2,2,1)
plt.title("XGBoost Regressor", fontsize=16)
plt.scatter(sample_xgb['Actual'], sample_xgb['Predict'], c='g')
plt.grid()

plt.subplot(2,2,2)
plt.title("Random Forest Regressor", fontsize=16)
plt.scatter(sample_rf['Actual'], sample_rf['Predict'], c='g')
plt.grid()

# %% [markdown]
# # model extraction

# %%
#Model Extraction
pickle.dump(xgb, open('ssm_mens_score_prediction_final_model.pkl','wb'))

# %% [markdown]
# # win probability (first innings)

# %%
#load data
first_innings_win_portability_df = pickle.load(open('ssm_mens_first_innings_win.pkl','rb'))
first_innings_win_portability_df
# Out:
#             batting_team        bowling_team      city  runs_y  \
# 0      Central Districts            Auckland  Auckland     192
# 1      Central Districts            Auckland  Auckland     192
# 2      Central Districts            Auckland  Auckland     192
# 3      Central Districts            Auckland  Auckland     192
# 4      Central Districts            Auckland  Auckland     192
# ...                  ...                 ...       ...     ...
# 20397              Otago  Northern Districts  Hamilton     143
# 20398              Otago  Northern Districts  Hamilton     143
# 20399              Otago  Northern Districts  Hamilton     143
# 20400              Otago  Northern Districts  Hamilton     143
# 20401              Otago  Northern Districts  Hamilton     143
#
#        result_first_innings
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 20397                     0
# 20398                     0
# 20399                     0
# 20400                     0
# 20401                     0
#
# [20402 rows x 5 columns]

# %%
first_innings_win_portability_df.to_csv(r'ssm_mens_first_innings_win.csv', index=False, header=True)
first_innings_win_portability_df = pd.read_csv(r'ssm_mens_first_innings_win.csv')
first_innings_win_portability_df
# Out:
#             batting_team        bowling_team      city  runs_y  \
# 0      Central Districts            Auckland  Auckland     192
# 1      Central Districts            Auckland  Auckland     192
# 2      Central Districts            Auckland  Auckland     192
# 3      Central Districts            Auckland  Auckland     192
# 4      Central Districts            Auckland  Auckland     192
# ...                  ...                 ...       ...     ...
# 20397              Otago  Northern Districts  Hamilton     143
# 20398              Otago  Northern Districts  Hamilton     143
# 20399              Otago  Northern Districts  Hamilton     143
# 20400              Otago  Northern Districts  Hamilton     143
# 20401              Otago  Northern Districts  Hamilton     143
#
#        result_first_innings
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 20397                     0
# 20398                     0
# 20399                     0
# 20400                     0
# 20401                     0
#
# [20402 rows x 5 columns]

# %%
X1 = first_innings_win_portability_df.drop(columns=['result_first_innings'])
y1 = first_innings_win_portability_df['result_first_innings'].values

# X1_train,X1_test,y1_train,y1_test = train_test_split(X1, y1, test_size=0.1, random_state=1)

# %%
X1
# Out:
#             batting_team        bowling_team      city  runs_y
# 0      Central Districts            Auckland  Auckland     192
# 1      Central Districts            Auckland  Auckland     192
# 2      Central Districts            Auckland  Auckland     192
# 3      Central Districts            Auckland  Auckland     192
# 4      Central Districts            Auckland  Auckland     192
# ...                  ...                 ...       ...     ...
# 20397              Otago  Northern Districts  Hamilton     143
# 20398              Otago  Northern Districts  Hamilton     143
# 20399              Otago  Northern Districts  Hamilton     143
# 20400              Otago  Northern Districts  Hamilton     143
# 20401              Otago  Northern Districts  Hamilton     143
#
# [20402 rows x 4 columns]

# %%
# X1.to_csv(r'X_input_ssm_mens_first_innings_win.csv', index=False, header=True)
# X1 = pd.read_csv(r'X_input_ssm_mens_first_innings_win.csv')
# X1

pickle.dump(X1, open('X_input_ssm_mens_first_innings_win.pkl','wb'))
X1 = pickle.load(open('X_input_ssm_mens_first_innings_win.pkl','rb'))
X1
# Out:
#             batting_team        bowling_team      city  runs_y
# 0      Central Districts            Auckland  Auckland     192
# 1      Central Districts            Auckland  Auckland     192
# 2      Central Districts            Auckland  Auckland     192
# 3      Central Districts            Auckland  Auckland     192
# 4      Central Districts            Auckland  Auckland     192
# ...                  ...                 ...       ...     ...
# 20397              Otago  Northern Districts  Hamilton     143
# 20398              Otago  Northern Districts  Hamilton     143
# 20399              Otago  Northern Districts  Hamilton     143
# 20400              Otago  Northern Districts  Hamilton     143
# 20401              Otago  Northern Districts  Hamilton     143
#
# [20402 rows x 4 columns]

# %%
# trf1 = ColumnTransformer([
#     ('trf1', OneHotEncoder(sparse=False, drop='first'),['batting_team', 'bowling_team', 'city'])
# ]
# ,remainder='passthrough')

transformer1 = make_column_transformer(
    (OneHotEncoder(sparse=False, drop='first'), [
      'batting_team', 'bowling_team', 'city'
    ]),
    (StandardScaler(), [
      'runs_y'
    ])
)

# %%
transformer1.fit(X1)
# Out:
# ColumnTransformer(transformers=[('onehotencoder',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  ['batting_team', 'bowling_team', 'city']),
#                                 ('standardscaler', StandardScaler(),
#                                  ['runs_y'])])

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(transformer1.transform(X1), y1, test_size=0.1, random_state=1)

# %%
# pipe1 = Pipeline(steps=[
#     ('step1',trf1),
#     ('step2', LogisticRegression()) #solver='liblinear'
# ])

lr1 = LogisticRegression()

lr1.fit(X1_train, y1_train)
# Out:
# LogisticRegression()

# %%
y1_pred = lr1.predict(X1_test)

print('Accuracy Score: '+str(accuracy_score(y1_test,y1_pred)*100))
# Out:
# Accuracy Score: 78.0499755022048

# %%
confusion_matrix_lr = confusion_matrix(y1_test, y1_pred)
confusion_matrix_lr
# Out:
# array([[931, 231],
#        [217, 662]])

# %%
print(classification_report(y1_test, y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81      1162
#            1       0.74      0.75      0.75       879
#
#     accuracy                           0.78      2041
#    macro avg       0.78      0.78      0.78      2041
# weighted avg       0.78      0.78      0.78      2041

# %%
lr1.predict_proba(X1_test)[4]
# Out:
# array([0.14317092, 0.85682908])

# %%
plt.rcParams["figure.figsize"] = (10, 6) 

ax = sns.heatmap(confusion_matrix_lr/np.sum(confusion_matrix_lr), annot=True, fmt='.2%', cmap='Blues')
# ax.set_title('Logistic Regression\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Lose','Win'])
ax.yaxis.set_ticklabels(['Lose','Win'])
## Display the visualization of the Confusion Matrix.
plt.show()

# %%
input_df = pd.DataFrame({'batting_team': ['Northern Districts'], 'bowling_team': ['Otago'], 'city': ['Hamilton'], 'runs_y': [190]})
result = lr1.predict_proba(transformer1.transform(input_df))

loss = result[0][1]
win = result[0][0]

print('win: '+str(round(win*100))+'%')
print('loss: '+str(round(loss*100))+'%')
# Out:
# win: 3%
# loss: 97%

# %% [markdown]
# # Model Extraction

# %%
#Model Extraction
pickle.dump(lr1, open('ssm_1st_innings_win_prediction_final_model.pkl','wb'))

# %% [markdown]
# # win probability (second innings)

# %%
#load data
second_innings_win_portability_df = pickle.load(open('ssm_mens_second_innings_win.pkl','rb'))
second_innings_win_portability_df
# Out:
#              batting_team       bowling_team      city  current_score  \
# 0                Auckland  Central Districts  Auckland              0
# 1                Auckland  Central Districts  Auckland              6
# 2                Auckland  Central Districts  Auckland             11
# 3                Auckland  Central Districts  Auckland             11
# 4                Auckland  Central Districts  Auckland             15
# ...                   ...                ...       ...            ...
# 18683  Northern Districts              Otago  Hamilton            131
# 18684  Northern Districts              Otago  Hamilton            135
# 18685  Northern Districts              Otago  Hamilton            136
# 18686  Northern Districts              Otago  Hamilton            138
# 18687  Northern Districts              Otago  Hamilton            144
#
#        target_runs  runs_left  balls_left  wickets_left    crr   rrr  result
# 0              193        193         119            10   0.00  9.73       1
# 1              193        187         118            10  18.00  9.51       1
# 2              193        182         117            10  22.00  9.33       1
# 3              193        182         116            10  16.50  9.41       1
# 4              193        178         115            10  18.00  9.29       1
# ...            ...        ...         ...           ...    ...   ...     ...
# 18683          144         13          10             5   7.15  7.80       1
# 18684          144          9           9             5   7.30  6.00       1
# 18685          144          8           8             5   7.29  6.00       1
# 18686          144          6           7             5   7.33  5.14       1
# 18687          144          0           6             5   7.58  0.00       1
#
# [18627 rows x 11 columns]

# %%
second_innings_win_portability_df.to_csv(r'ssm_mens_second_innings_win.csv', index=False, header=True)
second_innings_win_portability_df = pd.read_csv(r'ssm_mens_second_innings_win.csv')
second_innings_win_portability_df
# Out:
#              batting_team       bowling_team      city  current_score  \
# 0                Auckland  Central Districts  Auckland              0
# 1                Auckland  Central Districts  Auckland              6
# 2                Auckland  Central Districts  Auckland             11
# 3                Auckland  Central Districts  Auckland             11
# 4                Auckland  Central Districts  Auckland             15
# ...                   ...                ...       ...            ...
# 18622  Northern Districts              Otago  Hamilton            131
# 18623  Northern Districts              Otago  Hamilton            135
# 18624  Northern Districts              Otago  Hamilton            136
# 18625  Northern Districts              Otago  Hamilton            138
# 18626  Northern Districts              Otago  Hamilton            144
#
#        target_runs  runs_left  balls_left  wickets_left    crr   rrr  result
# 0              193        193         119            10   0.00  9.73       1
# 1              193        187         118            10  18.00  9.51       1
# 2              193        182         117            10  22.00  9.33       1
# 3              193        182         116            10  16.50  9.41       1
# 4              193        178         115            10  18.00  9.29       1
# ...            ...        ...         ...           ...    ...   ...     ...
# 18622          144         13          10             5   7.15  7.80       1
# 18623          144          9           9             5   7.30  6.00       1
# 18624          144          8           8             5   7.29  6.00       1
# 18625          144          6           7             5   7.33  5.14       1
# 18626          144          0           6             5   7.58  0.00       1
#
# [18627 rows x 11 columns]

# %%
X2 = second_innings_win_portability_df.drop(columns=['result'])
y2 = second_innings_win_portability_df['result'].values

# X2_train,X2_test,y2_train,y2_test = train_test_split(X2, y2, test_size=0.1, random_state=1)

# %%
X2
# Out:
#              batting_team       bowling_team      city  current_score  \
# 0                Auckland  Central Districts  Auckland              0
# 1                Auckland  Central Districts  Auckland              6
# 2                Auckland  Central Districts  Auckland             11
# 3                Auckland  Central Districts  Auckland             11
# 4                Auckland  Central Districts  Auckland             15
# ...                   ...                ...       ...            ...
# 18622  Northern Districts              Otago  Hamilton            131
# 18623  Northern Districts              Otago  Hamilton            135
# 18624  Northern Districts              Otago  Hamilton            136
# 18625  Northern Districts              Otago  Hamilton            138
# 18626  Northern Districts              Otago  Hamilton            144
#
#        target_runs  runs_left  balls_left  wickets_left    crr   rrr
# 0              193        193         119            10   0.00  9.73
# 1              193        187         118            10  18.00  9.51
# 2              193        182         117            10  22.00  9.33
# 3              193        182         116            10  16.50  9.41
# 4              193        178         115            10  18.00  9.29
# ...            ...        ...         ...           ...    ...   ...
# 18622          144         13          10             5   7.15  7.80
# 18623          144          9           9             5   7.30  6.00
# 18624          144          8           8             5   7.29  6.00
# 18625          144          6           7             5   7.33  5.14
# 18626          144          0           6             5   7.58  0.00
#
# [18627 rows x 10 columns]

# %%
# X2.to_csv(r'X_input_ssm_mens_second_innings_win.csv', index=False, header=True)
# X2 = pd.read_csv(r'X_input_ssm_mens_second_innings_win.csv')
# X2

pickle.dump(X2, open('X_input_ssm_mens_second_innings_win.pkl','wb'))
X2 = pickle.load(open('X_input_ssm_mens_second_innings_win.pkl','rb'))
X2
# Out:
#              batting_team       bowling_team      city  current_score  \
# 0                Auckland  Central Districts  Auckland              0
# 1                Auckland  Central Districts  Auckland              6
# 2                Auckland  Central Districts  Auckland             11
# 3                Auckland  Central Districts  Auckland             11
# 4                Auckland  Central Districts  Auckland             15
# ...                   ...                ...       ...            ...
# 18622  Northern Districts              Otago  Hamilton            131
# 18623  Northern Districts              Otago  Hamilton            135
# 18624  Northern Districts              Otago  Hamilton            136
# 18625  Northern Districts              Otago  Hamilton            138
# 18626  Northern Districts              Otago  Hamilton            144
#
#        target_runs  runs_left  balls_left  wickets_left    crr   rrr
# 0              193        193         119            10   0.00  9.73
# 1              193        187         118            10  18.00  9.51
# 2              193        182         117            10  22.00  9.33
# 3              193        182         116            10  16.50  9.41
# 4              193        178         115            10  18.00  9.29
# ...            ...        ...         ...           ...    ...   ...
# 18622          144         13          10             5   7.15  7.80
# 18623          144          9           9             5   7.30  6.00
# 18624          144          8           8             5   7.29  6.00
# 18625          144          6           7             5   7.33  5.14
# 18626          144          0           6             5   7.58  0.00
#
# [18627 rows x 10 columns]

# %%
# trf2 = ColumnTransformer([
#     ('trf2', OneHotEncoder(sparse=False, drop='first'),['batting_team', 'bowling_team', 'city'])
# ]
# ,remainder='passthrough')

transformer2 = make_column_transformer(
    (OneHotEncoder(sparse=False, drop='first'), [
      'batting_team', 'bowling_team', 'city'
    ]),
    (StandardScaler(), [
      'current_score', 'target_runs', 'runs_left', 'balls_left', 'wickets_left', 'crr', 'rrr'
    ])
)

# %%
transformer2.fit(X2)
# Out:
# ColumnTransformer(transformers=[('onehotencoder',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  ['batting_team', 'bowling_team', 'city']),
#                                 ('standardscaler', StandardScaler(),
#                                  ['current_score', 'target_runs', 'runs_left',
#                                   'balls_left', 'wickets_left', 'crr',
#                                   'rrr'])])

# %%
X2_train,X2_test,y2_train,y2_test = train_test_split(transformer2.transform(X2), y2, test_size=0.1, random_state=1)

# %%
# pipe2 = Pipeline(steps=[
#     ('step1',trf2),
#     ('step2',LogisticRegression()) #solver='liblinear'
# ])

lr2 = LogisticRegression()

lr2.fit(X2_train,y2_train)
# Out:
# LogisticRegression()

# %%
y2_pred = lr2.predict(X2_test)
print('Accuracy Score: '+str(accuracy_score(y2_test, y2_pred)*100))
# Out:
# Accuracy Score: 86.20504562533549

# %%
confusion_matrix1 = confusion_matrix(y2_test, y2_pred)
confusion_matrix1
# Out:
# array([[670, 133],
#        [124, 936]])

# %%
print(classification_report(y2_test, y2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84       803
#            1       0.88      0.88      0.88      1060
#
#     accuracy                           0.86      1863
#    macro avg       0.86      0.86      0.86      1863
# weighted avg       0.86      0.86      0.86      1863

# %%
lr2.predict_proba(X2_test)[10]
# Out:
# array([0.01592501, 0.98407499])

# %%
plt.rcParams["figure.figsize"] = (10, 6) 

ax = sns.heatmap(confusion_matrix1/np.sum(confusion_matrix1), annot=True, fmt='.2%', cmap='Blues')
# ax.set_title('Model-1\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Lose','Win'])
ax.yaxis.set_ticklabels(['Lose','Win'])
## Display the visualization of the Confusion Matrix.
plt.show()

# %%
input_df = pd.DataFrame({'batting_team': ['Northern Districts'], 'bowling_team': ['Auckland'], 'city': ['Hamilton'], 'current_score':[159], 'target_runs':[169], 'runs_left':[10], 'balls_left': [2], 'wickets_left':[7], 'crr':[8.08], 'rrr': [30.0]})
result = lr2.predict_proba(transformer2.transform(input_df))

loss = result[0][0]
win = result[0][1]

print('win: '+str(round(win*100))+'%')
print('loss: '+str(round(loss*100))+'%')
# Out:
# win: 0%
# loss: 100%

# %% [markdown]
# # Model Extraction

# %%
#Model Extraction
pickle.dump(lr2, open('ssm_2nd_innings_win_prediction_final_model.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '1.7.3'
